# %% [markdown]
# ![header](https://i.imgur.com/I4ake6d.jpg)

# %% [markdown]
# # IN SITU BALTIC SEA TRAINING
# <div style="text-align: right"><i> 13-02-Part-two-out-of-five </i></div>

# %% [markdown]
# ***
# # BAL `NRT` Product/dataset Subsetting & Download

# %% [markdown]
# ***
# **General Note 1**: Execute each cell through the <button class="btn btn-default btn-xs"><i class="icon-play fa fa-play"></i></button> button from the top MENU (or keyboard shortcut `Shift` + `Enter`).<br>
# <br>
# **General Note 2**: If, for any reason, the kernel is not working anymore, in the top MENU, click on the <button class="btn btn-default btn-xs"><i class="fa fa-repeat icon-repeat"></i></button> button. Then, in the top MENU, click on "Cell" and select "Run All Above Selected Cell".<br>
# ***

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc">
#     <ul class="toc-item">
#         <li><span><a href="#1.-Introduction" data-toc-modified-id="1.-Introduction">1. Introduction</a></span></li>
#         <li>
#             <span><a href="#2.-Setup" data-toc-modified-id="2.-Setup">2. Setup</a></span>
#             <ul>
#                 <li><span><a href="#2.1.-Python-packages" data-toc-modified-id="2.1.-Python-packages">2.1. Python packages</a></span></li>
#                 <li><span><a href="#2.2.-Copernicus-Database" data-toc-modified-id="2.2.-Copernicus-Database">2.2. Copernicus database</a></span></li>
#                 <li><span><a href="#2.3.-Auxiliary-functions" data-toc-modified-id="2.3.-Auxiliary-functions">2.3. Auxiliary functions</a></span></li>
#             </ul>
#         </li>
#         <li><span><a href="#3.-Getting-started" data-toc-modified-id="3.-Getting-started">3. Getting started</a></span></li>
#         <li><span><a href="#4.-Operations" data-toc-modified-id="4.-Operations">4. Operations</a></span>
#         <ul>
#             <li>
#             <span><a href="#4.1.-Subsetting" data-toc-modified-id="4.1.-Subsetting">4.1.Subsetting</a></span>
#             <ul>
#                 <li><span><a href="#4.1.1.-By-collection" data-toc-modified-id="4.1.1.-By-collection">4.1.1. By collection</a></span></li>
#                 <li><span><a href="#4.1.2.-By-time-range" data-toc-modified-id="4.1.2.-By-time-range">4.1.2. By time range</a></span></li>
#                 <li><span><a href="#4.1.3.-By-bounding-box" data-toc-modified-id="4.1.3.-By-bounding-box">4.1.3. By bounding-box</a></span></li>
#                 <li><span><a href="#4.1.4.-By-last-position" data-toc-modified-id="4.1.4.-By-last-position">4.1.4. By last position</a></span></li>
#                 <li><span><a href="#4.1.5.-By-data-type" data-toc-modified-id="4.1.5.-By-data-type">4.1.5. By data type</a></span></li>
#                 <li><span><a href="#4.1.6.-By-file-type" data-toc-modified-id="4.1.6.-By-file-type">4.1.6. By file type</a></span></li>
#                 <li><span><a href="#4.1.7.-By-parameter" data-toc-modified-id="4.1.7.-By-parameter">4.1.7. By parameter</a></span></li>
#                 <li><span><a href="#4.1.8.-By-platform-code" data-toc-modified-id="4.1.8.-By-platform-code">4.1.8. By platform code</a></span></li>
#                 <li><span><a href="#4.1.9.-By-provider" data-toc-modified-id="4.1.9.-By-provider">4.1.9. By provider</a></span></li>
#                 <li><span><a href="#4.1.10.-Subsetting-by-several-criterias-at-once" data-toc-modified-id="4.1.10.-Subsetting-by-several-criterias-at-once">4.1.10. By several criterias at once</a></span></li>
#             </ul>
#             </li>
#             <li><span><a href="#4.2.-Exporting" data-toc-modified-id="4.2.-Exporting">4.2. Exporting</a></span></li>
#             <li><span><a href="#4.3.-Downloading" data-toc-modified-id="4.3.-Downloading">4.3. Downloading</a></span></li>
#         </ul>
#         </li>
#         <li><span><a href="#5.-Wrap-up" data-toc-modified-id="5.-Wrap-up">5. Wrap-up</a></span></li>
#         <li><span><a href="#6.-Next-tutorial" data-toc-modified-id="6.-Next-tutorial">6. Next tutorial</a></span></li>
#     </ul>
# </div>

# %% [markdown]
# ***

# %% [markdown]
# ## 1. Introduction
#
# This notebook focus on selecting (subsetting) and downloading netCDF files from the available collections (`latest`, `monthly` and `history`) available within the In Situ Near Real Time product/dataset covering the Baltic Sea:`INSITU_BAL_NRT_OBSERVATIONS_013_032`. Click [here](http://marine.copernicus.eu/services-portfolio/access-to-products/?option=com_csw&view=details&product_id=INSITU_BAL_NRT_OBSERVATIONS_013_032) to  view the dedicated section of this product within the [CMEMS Catalog](http://marine.copernicus.eu/services-portfolio/access-to-products/).

# %% [markdown]
# Any In Situ NRT product/dataset is just a bunch of netcdf files produced by the platforms (*drifters, profilers, gliders, moorings, HF-radars, vessels etc*) deployed in a certain area (in this case, the Baltic Sea); so many files that navigation/subsetting can be challenging.

# %% [markdown]
# | ![BAL.gif](img/BAL.gif)|
# |:--:|
# | *GIF of the location (point or trajectory) of the platforms providing near real time data in the BAL area since 1860* |

# %% [markdown]
# To smooth the process of data discovery to users, the In Situ TAC provides a set of `index files` that describe the aforementioned netCDF collections. In addition to these index files, it is also possible to find further info regarding each platform contributting with files on the `index_platform.txt`.

# %% [markdown]
# | Index |  Description |
# | ------- | ----------- |
# | `index_latest.txt`  |  List of available files within the latest collection + metadata |
# | `index_monthly.txt`   | List of available files within the monthly collection + metadata |
# | `index_history.txt`   |  List of available files within the history collection + metadata |
# | `index_platform.txt`   | Full list of platforms + metadata |

# %% [markdown]
# Check more about these files in the <a href="https://archimer.ifremer.fr/doc/00324/43494/" target="_blank">Product User Manual</a>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>OBJECTIVE</b>
#
# ***
# To select and download only those netCDFs matching our needs from the whole original set of files that composes the BAL NRT product/dataset by using the aforementioned index files.

# %% [markdown]
# ## 2. Setup

# %% [markdown]
# ### 2.1. Python packages

# %% [markdown]
# For the notebook to properly run we need to first load the next packages available from the Jupyter Notebook Ecosystem. Please run the `next cell`:

# %%
import warnings
warnings.filterwarnings("ignore")

import IPython
import pandas as pd
import datetime
import random
import os
from collections import namedtuple
import ftputil
from shapely.geometry import box, Point
from urllib.parse import urlparse
import folium
from folium import plugins

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# If any of them raises any error it means you need to install the module first. For doing so please:
# 1. Open a new cell int he notebook
# 2. Run <i>`!conda install packageName --yes`</i> or <i>`!conda install -c conda-forge packageName --yes`</i> or <i>`!pip install packageName`</i>
# 3. Import again!
# <br><br>
# Example: <i>how-to-solve import error for json2html module </i>
#
# ![region.png](img/errorImporting.gif)

# %% [markdown]
# ### 2.2. Copernicus Database

# %% [markdown]
# Please `set next your CMEMS User credentials` in the next cell and `run the cell` afterwards:

# %%
usr = 'inputHereYourCMEMSUser'
pas = 'InputHereYourCMEMSPassword'

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# **Don't you have credentials yet?** <br>Please go [here](https://resources.marine.copernicus.eu/?option=com_sla) to get the above credentials to be able to access CMEMS secured FTP server.

# %% [markdown]
# As stated before, we will focus on the Near Real Time product/dataset covering the Iberian-Biscay-Ireland seas so, please `run the next` to load the info defining such product/dataset:

# %%
dataset = {
    'host': 'nrt.cmems-du.eu',#ftp host => nrt.cmems-du.eu for Near Real Time products
    'product': 'INSITU_BAL_NRT_OBSERVATIONS_013_032',#name of the In Situ Near Real Time product in the BS area
    'name': 'bal_multiparameter_nrt',#name of the dataset available in the above In Situ Near Real Time product
    'index_files': ['index_latest.txt', 'index_monthly.txt', 'index_history.txt'],#files describing the content of the lastest, monthly and history netCDF file collections available withint he above dataset
    'index_platform': 'index_platform.txt',#files describing the netwotk of platforms contributting with files in the abve collections
}

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# In case you want to explore any other In Situ NRT product/dataset just set the above definitions accordingly and you will be able to reproduce the subsetting and downloading we will perform next.

# %% [markdown]
# ### 2.3. Auxiliary functions

# %% [markdown]
# For exploring the product/dataset we will use a set of files called `index files` located in the CMEMS FTP server.

# %% [markdown]
# 1. **Download the index files**.
# In order to download the most updated version of these files we will use the next function. <br>Please `run the next cell` to load it (te funtion) in memory for later use:

# %%
def getIndexFiles(usr,pas,dataset,path2indexes):
    #Provides the index files available at the ftp server
    indexes = dataset['index_files'] + [dataset['index_platform']]
    with ftputil.FTPHost(dataset['host'], usr, pas) as ftp_host:  # connect to CMEMS FTP
        for index in indexes:
            remotefile= "/".join(['Core',dataset['product'],dataset['name'],index])
            print('.....Downloading ' + index)
            localfile = os.path.join(path2indexes,index)
            ftp_host.download(remotefile,localfile)  # remote, local
    print('Ready!')

# %% [markdown]
# 2. **Index files reader**.
# In order to load the information contained in *each* of the files we will use the next function. <br>Please `run the next cell` to load it in memory for later use:

# %%
def readIndexFileFromCWD(path2file):
    #Load as pandas dataframe the file in the provided path
    with open(path2file, 'rb') as f:
        filename = os.path.basename(path2file)
        print('...Loading info from: '+filename)
        raw_index_info = pd.read_csv(path2file, skiprows=5)
    return raw_index_info

# %% [markdown]
# 3. **Index files merger**.
# In order to load the information contained in *all* the indexes in a one single entity we will use the next function. <br>Please `run the next cell` to load it in memory for later use:

# %%
def getIndexFilesInfo(usr, pas, dataset,path2indexes):
    # Load and merge in a single entity all the information contained on each file descriptor of a given dataset
    # 1) Loading the index platform info as dataframe
    path2file = os.path.join(path2indexes, dataset['index_platform'])
    indexPlatform = readIndexFileFromCWD(path2file)
    indexPlatform.rename(columns={indexPlatform.columns[0]: "platform_code" }, inplace = True)
    indexPlatform = indexPlatform.drop_duplicates(subset='platform_code', keep="first")
    # 2) Loading the index files info as dataframes
    netcdf_collections = []
    for filename in dataset['index_files']:
        path2file = os.path.join(path2indexes,filename)
        indexFile = readIndexFileFromCWD(path2file)
        netcdf_collections.append(indexFile)
    netcdf_collections = pd.concat(netcdf_collections)
    # 3) creating new columns: derived info
    netcdf_collections['netcdf'] = netcdf_collections['file_name'].str.split('/').str[-1]
    netcdf_collections['file_type'] = netcdf_collections['netcdf'].str.split('.').str[0].str.split('_').str[1]
    netcdf_collections['data_type'] = netcdf_collections['netcdf'].str.split('.').str[0].str.split('_').str[2]
    netcdf_collections['platform_code'] = netcdf_collections['netcdf'].str.split('.').str[0].str.split('_').str[3]
    # 4) Merging the information of all files
    headers = ['platform_code','wmo_platform_code', 'institution_edmo_code', 'last_latitude_observation', 'last_longitude_observation','last_date_observation']
    result = pd.merge(netcdf_collections,indexPlatform[headers],on='platform_code')
    print('Ready!')
    return result

# %% [markdown]
# Also, let's load also the next functions as the are to be used later in the subsetting processing: `run the next cells`

# %% [markdown]
# <ul><li id="TemporalOverlap"><i>Time-Overlap</i> function definition</li></ul>

# %%
def timeOverlap(row, targeted_range):
    # Checks if a file contains data in the specified time range (targeted_range)
    date_format = "%Y-%m-%dT%H:%M:%SZ"
    targeted_ini = datetime.datetime.strptime(targeted_range.split('/')[0], date_format)
    targeted_end = datetime.datetime.strptime(targeted_range.split('/')[1], date_format)
    time_start = datetime.datetime.strptime(row['time_coverage_start'],date_format)
    time_end = datetime.datetime.strptime(row['time_coverage_end'],date_format)
    Range = namedtuple('Range', ['start', 'end'])
    r1 = Range(start=targeted_ini, end=targeted_end)
    r2 = Range(start=time_start, end=time_end)
    latest_start = max(r1.start, r2.start)
    earliest_end = min(r1.end, r2.end)
    delta = (earliest_end - latest_start).days + 1
    overlap = max(0, delta)
    if overlap != 0:
        return True
    else:
        return False

# %% [markdown]
# <ul><li id="SpatialOverlap"><i>Spatial-Overlap</i> function definition</li></ul>

# %%
def spatialOverlap(row, targeted_bbox):
    # Checks if a file contains data in the specified area (targeted_bbox)
    geospatial_lat_min = float(row['geospatial_lat_min'])
    geospatial_lat_max = float(row['geospatial_lat_max'])
    geospatial_lon_min = float(row['geospatial_lon_min'])
    geospatial_lon_max = float(row['geospatial_lon_max'])
    targeted_bounding_box = box(targeted_bbox[0], targeted_bbox[1],targeted_bbox[2], targeted_bbox[3])
    bounding_box = box(geospatial_lon_min, geospatial_lat_min,geospatial_lon_max, geospatial_lat_max)
    if targeted_bounding_box.intersects(bounding_box):  # check other rules on https://shapely.readthedocs.io/en/stable/manual.html
        return True
    else:
        return False

# %% [markdown]
# <ul><li id="LocationInRange"><i>LocationInRange</i> function definition</li></ul>

# %%
def lastLocationInRange(row, targeted_bbox):
    # Checks if a file has been produced by a platform whose last position is within the specified area (targeted_bbox)
    geospatial_lat = float(row['last_latitude_observation'])
    geospatial_lon = float(row['last_longitude_observation'])
    targeted_bounding_box = box(targeted_bbox[0], targeted_bbox[1],targeted_bbox[2], targeted_bbox[3])
    location = Point(geospatial_lon, geospatial_lat)
    if targeted_bounding_box.contains(location):#check other rules on https://shapely.readthedocs.io/en/stable/manual.html
        return True
    else:
        return False

# %% [markdown]
# ## 3. Getting started

# %% [markdown]
# For the analysis to be carried out we need the most recent version of the index files. By default we will save them into the `index_files` folder available in the `data` folder. Nevertheless if you rather use a different one set it next:

# %%
path2indexes= os.path.join(os.getcwd(),'data','index_files')#default path to save the files

# %% [markdown]
# Although in such folder we have provided already a copy of the files, **if you are running this notebook later than April 2020**  please `Run the next` cell and download again the index files:

# %%
getIndexFiles(usr,pas,dataset,path2indexes)
# Out:
# .....Downloading index_latest.txt
# .....Downloading index_monthly.txt
# .....Downloading index_history.txt
# .....Downloading index_platform.txt
# Ready!

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# **Are you getting a `permission denied` error?**
# <br>Please be aware that no `writes` are authorized in the 'shared_notebook' folder. Make sure you run this on you own space after copying the notebooks form shared_notebooks. If you are still facing a problem contact us trough [Mattermost](https://chat-cmems.mercator-ocean.fr/).

# %% [markdown]
# Let's load now into a dataframe the info contained in such files: `run the next cell!`

# %%
info = getIndexFilesInfo(usr, pas, dataset, path2indexes)
# Out:
# ...Loading info from: index_platform.txt
# ...Loading info from: index_latest.txt
# ...Loading info from: index_monthly.txt
# ...Loading info from: index_history.txt
# Ready!

# %% [markdown]
# `Run now the next cell` to see the information just loaded above:

# %%
info.transpose()
# Out:
#                                                                         0      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3877
# geospatial_lat_max                                                    58.3877
# geospatial_lon_min                                                    11.6267
# geospatial_lon_max                                                    11.6267
# time_coverage_start                                      2021-01-12T16:02:00Z
# time_coverage_end                                        2021-01-12T16:02:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:28Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                   BO_PR_CT_SMHIBJORKHOLMEN_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                 SMHIBJORKHOLMEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3877
# last_longitude_observation                                            11.6267
# last_date_observation                                    2021-02-07T01:09:58Z
#
#                                                                         1      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3877
# geospatial_lat_max                                                    58.3877
# geospatial_lon_min                                                    11.6267
# geospatial_lon_max                                                    11.6267
# time_coverage_start                                      2004-03-03T08:12:00Z
# time_coverage_end                                        2020-11-30T15:30:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:09:58Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                            BO_PR_CT_SMHIBJORKHOLMEN.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                 SMHIBJORKHOLMEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3877
# last_longitude_observation                                            11.6267
# last_date_observation                                    2021-02-07T01:09:58Z
#
#                                                                         2      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    57.3147
# geospatial_lat_max                                                    57.3147
# geospatial_lon_min                                                    20.0803
# geospatial_lon_max                                                    20.0803
# time_coverage_start                                      2021-01-12T00:51:00Z
# time_coverage_end                                        2021-01-12T00:51:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:28Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 PRES SVEL LGHT DOX1
# netcdf                                          BO_PR_CT_SMHIBY15_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY15
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             57.2938
# last_longitude_observation                                            19.9077
# last_date_observation                                    2021-02-07T01:11:06Z
#
#                                                                         3      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    57.2938
# geospatial_lat_max                                                    57.3345
# geospatial_lon_min                                                    19.9077
# geospatial_lon_max                                                    20.0873
# time_coverage_start                                      1978-11-22T00:20:00Z
# time_coverage_end                                        2020-12-11T05:21:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:11:06Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_SMHIBY15.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY15
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             57.2938
# last_longitude_observation                                            19.9077
# last_date_observation                                    2021-02-07T01:11:06Z
#
#                                                                         4      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.8815
# geospatial_lat_max                                                    58.8815
# geospatial_lon_min                                                    20.3282
# geospatial_lon_max                                                    20.3282
# time_coverage_start                                      2021-01-12T12:11:00Z
# time_coverage_end                                        2021-01-12T12:11:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:28Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 PRES SVEL LGHT DOX1
# netcdf                                          BO_PR_CT_SMHIBY29_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY29
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.8748
# last_longitude_observation                                            20.3100
# last_date_observation                                    2021-02-07T01:12:08Z
#
#                                                                         5      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.8748
# geospatial_lat_max                                                    58.8855
# geospatial_lon_min                                                    20.3100
# geospatial_lon_max                                                    20.3358
# time_coverage_start                                      1978-11-21T08:20:00Z
# time_coverage_end                                        2020-12-10T17:55:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:12:08Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_SMHIBY29.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY29
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.8748
# last_longitude_observation                                            20.3100
# last_date_observation                                    2021-02-07T01:12:08Z
#
#                                                                         6      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.5937
# geospatial_lat_max                                                    58.5937
# geospatial_lon_min                                                    18.2363
# geospatial_lon_max                                                    18.2363
# time_coverage_start                                      2021-01-12T19:50:00Z
# time_coverage_end                                        2021-01-12T19:50:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:29Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 PRES SVEL LGHT DOX1
# netcdf                                          BO_PR_CT_SMHIBY31_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY31
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.5772
# last_longitude_observation                                            18.2263
# last_date_observation                                    2021-02-07T01:12:43Z
#
#                                                                         7      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.5772
# geospatial_lat_max                                                    58.6100
# geospatial_lon_min                                                    18.2263
# geospatial_lon_max                                                    18.2387
# time_coverage_start                                      1978-11-16T17:00:00Z
# time_coverage_end                                        2020-12-04T17:04:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:12:43Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_SMHIBY31.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY31
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.5772
# last_longitude_observation                                            18.2263
# last_date_observation                                    2021-02-07T01:12:43Z
#
#                                                                         8      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3333
# geospatial_lat_max                                                    58.3333
# geospatial_lon_min                                                    11.8833
# geospatial_lon_max                                                    11.8833
# time_coverage_start                                      2021-01-12T12:45:00Z
# time_coverage_end                                        2021-01-12T12:45:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:29Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                     BO_PR_CT_SMHIBYFJORDEN_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                   SMHIBYFJORDEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3333
# last_longitude_observation                                            11.8833
# last_date_observation                                    2021-02-08T19:00:46Z
#
#                                                                         9      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3333
# geospatial_lat_max                                                    58.3333
# geospatial_lon_min                                                    11.8833
# geospatial_lon_max                                                    11.8833
# time_coverage_start                                      2021-02-02T12:33:00Z
# time_coverage_end                                        2021-02-02T12:33:00Z
# institution                                                              SMHI
# date_update                                              2021-02-08T19:00:46Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                     BO_PR_CT_SMHIBYFJORDEN_20210202.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                   SMHIBYFJORDEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3333
# last_longitude_observation                                            11.8833
# last_date_observation                                    2021-02-08T19:00:46Z
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
#
#                                                                         22747  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      56.11
# geospatial_lat_max                                                      56.11
# geospatial_lon_min                                                      16.53
# geospatial_lon_max                                                      16.53
# time_coverage_start                                      1996-08-20T18:50:00Z
# time_coverage_end                                        1997-08-22T17:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:49:13Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SHPF.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SHPF
# wmo_platform_code                                                        SHPF
# institution_edmo_code
# last_latitude_observation                                               56.11
# last_longitude_observation                                              16.53
# last_date_observation                                    2019-10-06T06:49:13Z
#
#                                                                         22748  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      58.03
# geospatial_lat_max                                                      58.03
# geospatial_lon_min                                                      17.07
# geospatial_lon_max                                                      17.07
# time_coverage_start                                      1996-08-10T10:30:00Z
# time_coverage_end                                        1998-02-12T13:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:49:13Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SHQP.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SHQP
# wmo_platform_code                                                        SHQP
# institution_edmo_code
# last_latitude_observation                                               58.03
# last_longitude_observation                                              17.07
# last_date_observation                                    2019-10-06T06:49:13Z
#
#                                                                         22749  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      56.66
# geospatial_lat_max                                                      56.66
# geospatial_lon_min                                                      12.11
# geospatial_lon_max                                                      12.11
# time_coverage_start                                      1996-03-02T17:00:00Z
# time_coverage_end                                        1996-03-02T17:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:45Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SJIB.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SJIB
# wmo_platform_code                                                        SJIB
# institution_edmo_code
# last_latitude_observation                                               56.66
# last_longitude_observation                                              12.11
# last_date_observation                                    2019-10-06T06:52:45Z
#
#                                                                         22750  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      62.13
# geospatial_lat_max                                                      62.13
# geospatial_lon_min                                                      17.86
# geospatial_lon_max                                                      17.86
# time_coverage_start                                      1997-07-04T16:30:00Z
# time_coverage_end                                        1997-07-04T16:30:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:45Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SKUP.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SKUP
# wmo_platform_code                                                        SKUP
# institution_edmo_code
# last_latitude_observation                                               62.13
# last_longitude_observation                                              17.86
# last_date_observation                                    2019-10-06T06:52:45Z
#
#                                                                         22751  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      62.13
# geospatial_lat_max                                                      62.13
# geospatial_lon_min                                                      17.86
# geospatial_lon_max                                                      17.86
# time_coverage_start                                      1996-10-25T10:00:00Z
# time_coverage_end                                        1997-09-27T15:45:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:45Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SKVP.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SKVP
# wmo_platform_code                                                        SKVP
# institution_edmo_code
# last_latitude_observation                                               62.13
# last_longitude_observation                                              17.86
# last_date_observation                                    2019-10-06T06:52:45Z
#
#                                                                         22752  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      55.00
# geospatial_lat_max                                                      56.97
# geospatial_lon_min                                                     -60.00
# geospatial_lon_max                                                      14.83
# time_coverage_start                                      1999-07-20T11:00:00Z
# time_coverage_end                                        1999-09-22T11:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:45Z
# data_mode                                                                   R
# parameters                    DC_REFERENCE DATA_MODE DIRECTION DEPH PRES TEMP
# netcdf                                                       GL_PR_XX_SMTZ.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SMTZ
# wmo_platform_code                                                        SMTZ
# institution_edmo_code
# last_latitude_observation                                               55.00
# last_longitude_observation                                             -60.00
# last_date_observation                                    2019-10-06T06:52:45Z
#
#                                                                         22753  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      57.20
# geospatial_lat_max                                                      57.20
# geospatial_lon_min                                                      11.66
# geospatial_lon_max                                                      11.66
# time_coverage_start                                      1996-08-20T12:20:00Z
# time_coverage_end                                        1996-08-20T12:20:00Z
# institution                                               Unknown institution
# date_update                                              2019-10-06T06:52:44Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SMZG.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SMZG
# wmo_platform_code                                                        SMZG
# institution_edmo_code
# last_latitude_observation                                               57.20
# last_longitude_observation                                              11.66
# last_date_observation                                    2019-10-06T06:52:44Z
#
#                                                                         22754  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      56.66
# geospatial_lat_max                                                      57.18
# geospatial_lon_min                                                      11.66
# geospatial_lon_max                                                      12.11
# time_coverage_start                                      1996-01-17T14:15:00Z
# time_coverage_end                                        1998-05-16T13:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:44Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SMZQ.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SMZQ
# wmo_platform_code                                                        SMZQ
# institution_edmo_code
# last_latitude_observation                                               56.66
# last_longitude_observation                                              11.66
# last_date_observation                                    2019-10-06T06:52:44Z
#
#                                                                         22755  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      55.00
# geospatial_lat_max                                                      62.13
# geospatial_lon_min                                                      11.66
# geospatial_lon_max                                                      17.86
# time_coverage_start                                      1996-06-02T18:20:00Z
# time_coverage_end                                        1999-09-07T12:45:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:44Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SMZT.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SMZT
# wmo_platform_code                                                        SMZT
# institution_edmo_code
# last_latitude_observation                                               55.00
# last_longitude_observation                                              11.66
# last_date_observation                                    2019-10-06T06:52:44Z
#
#                                                                         22756
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     57.717
# geospatial_lat_max                                                     65.025
# geospatial_lon_min                                                    -12.979
# geospatial_lon_max                                                      8.983
# time_coverage_start                                      2013-09-21T15:14:00Z
# time_coverage_end                                        2013-10-25T05:34:00Z
# institution                                               Unknown institution
# date_update                                              2019-10-06T08:07:25Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION DEPH TEMP
# netcdf                                                    GL_PR_XX_VOZ2040.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                         VOZ2040
# wmo_platform_code                                                     VOZ2040
# institution_edmo_code
# last_latitude_observation                                              57.717
# last_longitude_observation                                            -12.979
# last_date_observation                                    2019-10-06T08:07:25Z
#
# [21 rows x 22757 columns]

# %% [markdown]
# One of the most important fields in the above info is the `file_name`. This filed contains the full path to the file in the FTP server, saving users from having to know the actual FTP structure. As the above preview does not render such field completely, let's see the first file full path: `Run he next cell`

# %%
info['file_name'].tolist()[0]
# Out:
# 'ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSERVATIONS_013_032/bal_multiparameter_nrt/latest/20210112/BO_PR_CT_SMHIBJORKHOLMEN_20210112.nc'

# %% [markdown]
# Copy the path into the browser....the file will download straightaway!<br>
# Next we will aim:
# <ul><li>the `file_name` field (file path) for downloading operations</li>
#     <li> the other fileds (file metadata) for the subsetting operations</li>
# </ul>

# %% [markdown]
# ## 4. Operations

# %% [markdown]
# ### 4.1. Subsetting

# %% [markdown]
# Prior to <i>download</i> we need to select only those netCDF files that are of our interest.<br>There are many different criterias (if they contain a certain parameter, if they have covered a certain area, if they have data in a specific time range....).<br>Next we will see some examples...

# %% [markdown]
# #### 4.1.1. By collection

# %% [markdown]
# This restrict all available files to just one specific collection.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>IMPORTANT</b>
#
# ***
# Please remember available options:
# <ul>
#     <li><i>latest</i>: daily files from platforms (last 30 days of data)</li>
#     <li><i>monthly</i>: monthly files from platforms (last 5 years of data)</li>
#     <li><i>history</i>: one file per platform (all platform data)</li>
# </ul>

# %% [markdown]
# `Set one collecion` next and `run the cells`:

# %%
targeted_collection = 'history' #try 'latest', 'monthly' or 'history'

# %%
condition = info['file_name'].str.contains(targeted_collection)
subset = info[condition]
subset.transpose()
# Out:
#                                                                         1      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3877
# geospatial_lat_max                                                    58.3877
# geospatial_lon_min                                                    11.6267
# geospatial_lon_max                                                    11.6267
# time_coverage_start                                      2004-03-03T08:12:00Z
# time_coverage_end                                        2020-11-30T15:30:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:09:58Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                            BO_PR_CT_SMHIBJORKHOLMEN.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                 SMHIBJORKHOLMEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3877
# last_longitude_observation                                            11.6267
# last_date_observation                                    2021-02-07T01:09:58Z
#
#                                                                         3      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    57.2938
# geospatial_lat_max                                                    57.3345
# geospatial_lon_min                                                    19.9077
# geospatial_lon_max                                                    20.0873
# time_coverage_start                                      1978-11-22T00:20:00Z
# time_coverage_end                                        2020-12-11T05:21:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:11:06Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_SMHIBY15.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY15
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             57.2938
# last_longitude_observation                                            19.9077
# last_date_observation                                    2021-02-07T01:11:06Z
#
#                                                                         5      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.8748
# geospatial_lat_max                                                    58.8855
# geospatial_lon_min                                                    20.3100
# geospatial_lon_max                                                    20.3358
# time_coverage_start                                      1978-11-21T08:20:00Z
# time_coverage_end                                        2020-12-10T17:55:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:12:08Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_SMHIBY29.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY29
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.8748
# last_longitude_observation                                            20.3100
# last_date_observation                                    2021-02-07T01:12:08Z
#
#                                                                         7      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.5772
# geospatial_lat_max                                                    58.6100
# geospatial_lon_min                                                    18.2263
# geospatial_lon_max                                                    18.2387
# time_coverage_start                                      1978-11-16T17:00:00Z
# time_coverage_end                                        2020-12-04T17:04:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:12:43Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_SMHIBY31.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY31
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.5772
# last_longitude_observation                                            18.2263
# last_date_observation                                    2021-02-07T01:12:43Z
#
#                                                                         10     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3333
# geospatial_lat_max                                                    58.3333
# geospatial_lon_min                                                    11.8833
# geospatial_lon_max                                                    11.8833
# time_coverage_start                                      2004-02-03T16:20:00Z
# time_coverage_end                                        2020-11-30T12:16:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:14:04Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                              BO_PR_CT_SMHIBYFJORDEN.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                   SMHIBYFJORDEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3333
# last_longitude_observation                                            11.8833
# last_date_observation                                    2021-02-08T19:00:46Z
#
#                                                                         13     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    57.6675
# geospatial_lat_max                                                    57.6675
# geospatial_lon_min                                                    11.6867
# geospatial_lon_max                                                    11.6867
# time_coverage_start                                      2004-02-03T08:55:00Z
# time_coverage_end                                        2020-11-30T07:48:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:14:10Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                              BO_PR_CT_SMHIDANAFJORD.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                   SMHIDANAFJORD
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             57.6675
# last_longitude_observation                                            11.6867
# last_date_observation                                    2021-02-08T19:00:46Z
#
#                                                                         16     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.1097
# geospatial_lat_max                                                    58.1097
# geospatial_lon_min                                                    11.8100
# geospatial_lon_max                                                    11.8100
# time_coverage_start                                      2004-02-03T14:20:00Z
# time_coverage_end                                        2020-11-30T10:42:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:14:44Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                BO_PR_CT_SMHIGALTERO.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                     SMHIGALTERO
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.1097
# last_longitude_observation                                            11.8100
# last_date_observation                                    2021-02-08T19:00:46Z
#
#                                                                         18     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3125
# geospatial_lat_max                                                    58.3125
# geospatial_lon_min                                                    11.7733
# geospatial_lon_max                                                    11.7733
# time_coverage_start                                      2004-02-03T17:45:00Z
# time_coverage_end                                        2020-11-30T12:53:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:15:01Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                          BO_PR_CT_SMHIHAVSTENSFJORD.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                               SMHIHAVSTENSFJORD
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3125
# last_longitude_observation                                            11.7733
# last_date_observation                                    2021-02-07T01:15:01Z
#
#                                                                         21     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    57.9017
# geospatial_lat_max                                                    57.9017
# geospatial_lon_min                                                    11.6667
# geospatial_lon_max                                                    11.6667
# time_coverage_start                                      2004-02-03T10:25:00Z
# time_coverage_end                                        2020-11-30T09:20:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:15:07Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                             BO_PR_CT_SMHIINSTORANNA.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                  SMHIINSTORANNA
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             57.9017
# last_longitude_observation                                            11.6667
# last_date_observation                                    2021-02-08T19:00:46Z
#
#                                                                         23     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      53.23
# geospatial_lat_max                                                      58.23
# geospatial_lon_min                                                      11.58
# geospatial_lon_max                                                      11.58
# time_coverage_start                                      2004-02-03T19:15:00Z
# time_coverage_end                                        2020-11-30T14:03:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:15:15Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                             BO_PR_CT_SMHIKOLJOFJORD.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                  SMHIKOLJOFJORD
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                               53.23
# last_longitude_observation                                              11.58
# last_date_observation                                    2021-02-07T01:15:15Z
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
#
#                                                                         22747  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      56.11
# geospatial_lat_max                                                      56.11
# geospatial_lon_min                                                      16.53
# geospatial_lon_max                                                      16.53
# time_coverage_start                                      1996-08-20T18:50:00Z
# time_coverage_end                                        1997-08-22T17:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:49:13Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SHPF.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SHPF
# wmo_platform_code                                                        SHPF
# institution_edmo_code
# last_latitude_observation                                               56.11
# last_longitude_observation                                              16.53
# last_date_observation                                    2019-10-06T06:49:13Z
#
#                                                                         22748  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      58.03
# geospatial_lat_max                                                      58.03
# geospatial_lon_min                                                      17.07
# geospatial_lon_max                                                      17.07
# time_coverage_start                                      1996-08-10T10:30:00Z
# time_coverage_end                                        1998-02-12T13:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:49:13Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SHQP.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SHQP
# wmo_platform_code                                                        SHQP
# institution_edmo_code
# last_latitude_observation                                               58.03
# last_longitude_observation                                              17.07
# last_date_observation                                    2019-10-06T06:49:13Z
#
#                                                                         22749  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      56.66
# geospatial_lat_max                                                      56.66
# geospatial_lon_min                                                      12.11
# geospatial_lon_max                                                      12.11
# time_coverage_start                                      1996-03-02T17:00:00Z
# time_coverage_end                                        1996-03-02T17:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:45Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SJIB.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SJIB
# wmo_platform_code                                                        SJIB
# institution_edmo_code
# last_latitude_observation                                               56.66
# last_longitude_observation                                              12.11
# last_date_observation                                    2019-10-06T06:52:45Z
#
#                                                                         22750  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      62.13
# geospatial_lat_max                                                      62.13
# geospatial_lon_min                                                      17.86
# geospatial_lon_max                                                      17.86
# time_coverage_start                                      1997-07-04T16:30:00Z
# time_coverage_end                                        1997-07-04T16:30:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:45Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SKUP.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SKUP
# wmo_platform_code                                                        SKUP
# institution_edmo_code
# last_latitude_observation                                               62.13
# last_longitude_observation                                              17.86
# last_date_observation                                    2019-10-06T06:52:45Z
#
#                                                                         22751  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      62.13
# geospatial_lat_max                                                      62.13
# geospatial_lon_min                                                      17.86
# geospatial_lon_max                                                      17.86
# time_coverage_start                                      1996-10-25T10:00:00Z
# time_coverage_end                                        1997-09-27T15:45:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:45Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SKVP.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SKVP
# wmo_platform_code                                                        SKVP
# institution_edmo_code
# last_latitude_observation                                               62.13
# last_longitude_observation                                              17.86
# last_date_observation                                    2019-10-06T06:52:45Z
#
#                                                                         22752  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      55.00
# geospatial_lat_max                                                      56.97
# geospatial_lon_min                                                     -60.00
# geospatial_lon_max                                                      14.83
# time_coverage_start                                      1999-07-20T11:00:00Z
# time_coverage_end                                        1999-09-22T11:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:45Z
# data_mode                                                                   R
# parameters                    DC_REFERENCE DATA_MODE DIRECTION DEPH PRES TEMP
# netcdf                                                       GL_PR_XX_SMTZ.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SMTZ
# wmo_platform_code                                                        SMTZ
# institution_edmo_code
# last_latitude_observation                                               55.00
# last_longitude_observation                                             -60.00
# last_date_observation                                    2019-10-06T06:52:45Z
#
#                                                                         22753  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      57.20
# geospatial_lat_max                                                      57.20
# geospatial_lon_min                                                      11.66
# geospatial_lon_max                                                      11.66
# time_coverage_start                                      1996-08-20T12:20:00Z
# time_coverage_end                                        1996-08-20T12:20:00Z
# institution                                               Unknown institution
# date_update                                              2019-10-06T06:52:44Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SMZG.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SMZG
# wmo_platform_code                                                        SMZG
# institution_edmo_code
# last_latitude_observation                                               57.20
# last_longitude_observation                                              11.66
# last_date_observation                                    2019-10-06T06:52:44Z
#
#                                                                         22754  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      56.66
# geospatial_lat_max                                                      57.18
# geospatial_lon_min                                                      11.66
# geospatial_lon_max                                                      12.11
# time_coverage_start                                      1996-01-17T14:15:00Z
# time_coverage_end                                        1998-05-16T13:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:44Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SMZQ.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SMZQ
# wmo_platform_code                                                        SMZQ
# institution_edmo_code
# last_latitude_observation                                               56.66
# last_longitude_observation                                              11.66
# last_date_observation                                    2019-10-06T06:52:44Z
#
#                                                                         22755  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      55.00
# geospatial_lat_max                                                      62.13
# geospatial_lon_min                                                      11.66
# geospatial_lon_max                                                      17.86
# time_coverage_start                                      1996-06-02T18:20:00Z
# time_coverage_end                                        1999-09-07T12:45:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:44Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SMZT.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SMZT
# wmo_platform_code                                                        SMZT
# institution_edmo_code
# last_latitude_observation                                               55.00
# last_longitude_observation                                              11.66
# last_date_observation                                    2019-10-06T06:52:44Z
#
#                                                                         22756
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     57.717
# geospatial_lat_max                                                     65.025
# geospatial_lon_min                                                    -12.979
# geospatial_lon_max                                                      8.983
# time_coverage_start                                      2013-09-21T15:14:00Z
# time_coverage_end                                        2013-10-25T05:34:00Z
# institution                                               Unknown institution
# date_update                                              2019-10-06T08:07:25Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION DEPH TEMP
# netcdf                                                    GL_PR_XX_VOZ2040.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                         VOZ2040
# wmo_platform_code                                                     VOZ2040
# institution_edmo_code
# last_latitude_observation                                              57.717
# last_longitude_observation                                            -12.979
# last_date_observation                                    2019-10-06T08:07:25Z
#
# [21 rows x 2503 columns]

# %% [markdown]
# <div class="alert alert-block alert-info"">
# <b>TIP</b>
#
# ***
# To check if the above output only list the files coming from a certain collection (the one set as targeted_collection') just check the `netcdf` column
# <ul><li>'latest' timestamp: netcdf file name ends with a YYYYMMDD</li></ul>
# <ul><li>'monthly' timestamp: netcdf file name ends with a YYYYMM</li></ul>
# <ul><li>'history' timestamp: netcdf file name ends with a YYYY or none timestamp</li></ul>

# %% [markdown]
# #### 4.1.2. By time range

# %% [markdown]
# Let's select only the files containing data within the next range of dates. <br>Please `set the start/end dates` you are interested in `and run the cells bellow`:

# %%
targeted_range = '2018-01-01T00:00:00Z/2019-01-01T23:59:59Z' #set your own!

# %%
info['timeOverlap'] = info.apply(timeOverlap,targeted_range=targeted_range,axis=1)
condition = info['timeOverlap'] == True
subset = info[condition]
subset.transpose()
# Out:
#                                                                         1      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3877
# geospatial_lat_max                                                    58.3877
# geospatial_lon_min                                                    11.6267
# geospatial_lon_max                                                    11.6267
# time_coverage_start                                      2004-03-03T08:12:00Z
# time_coverage_end                                        2020-11-30T15:30:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:09:58Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                            BO_PR_CT_SMHIBJORKHOLMEN.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                 SMHIBJORKHOLMEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3877
# last_longitude_observation                                            11.6267
# last_date_observation                                    2021-02-07T01:09:58Z
# timeOverlap                                                              True
#
#                                                                         3      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    57.2938
# geospatial_lat_max                                                    57.3345
# geospatial_lon_min                                                    19.9077
# geospatial_lon_max                                                    20.0873
# time_coverage_start                                      1978-11-22T00:20:00Z
# time_coverage_end                                        2020-12-11T05:21:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:11:06Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_SMHIBY15.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY15
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             57.2938
# last_longitude_observation                                            19.9077
# last_date_observation                                    2021-02-07T01:11:06Z
# timeOverlap                                                              True
#
#                                                                         5      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.8748
# geospatial_lat_max                                                    58.8855
# geospatial_lon_min                                                    20.3100
# geospatial_lon_max                                                    20.3358
# time_coverage_start                                      1978-11-21T08:20:00Z
# time_coverage_end                                        2020-12-10T17:55:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:12:08Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_SMHIBY29.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY29
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.8748
# last_longitude_observation                                            20.3100
# last_date_observation                                    2021-02-07T01:12:08Z
# timeOverlap                                                              True
#
#                                                                         7      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.5772
# geospatial_lat_max                                                    58.6100
# geospatial_lon_min                                                    18.2263
# geospatial_lon_max                                                    18.2387
# time_coverage_start                                      1978-11-16T17:00:00Z
# time_coverage_end                                        2020-12-04T17:04:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:12:43Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_SMHIBY31.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY31
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.5772
# last_longitude_observation                                            18.2263
# last_date_observation                                    2021-02-07T01:12:43Z
# timeOverlap                                                              True
#
#                                                                         10     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3333
# geospatial_lat_max                                                    58.3333
# geospatial_lon_min                                                    11.8833
# geospatial_lon_max                                                    11.8833
# time_coverage_start                                      2004-02-03T16:20:00Z
# time_coverage_end                                        2020-11-30T12:16:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:14:04Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                              BO_PR_CT_SMHIBYFJORDEN.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                   SMHIBYFJORDEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3333
# last_longitude_observation                                            11.8833
# last_date_observation                                    2021-02-08T19:00:46Z
# timeOverlap                                                              True
#
#                                                                         13     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    57.6675
# geospatial_lat_max                                                    57.6675
# geospatial_lon_min                                                    11.6867
# geospatial_lon_max                                                    11.6867
# time_coverage_start                                      2004-02-03T08:55:00Z
# time_coverage_end                                        2020-11-30T07:48:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:14:10Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                              BO_PR_CT_SMHIDANAFJORD.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                   SMHIDANAFJORD
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             57.6675
# last_longitude_observation                                            11.6867
# last_date_observation                                    2021-02-08T19:00:46Z
# timeOverlap                                                              True
#
#                                                                         16     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.1097
# geospatial_lat_max                                                    58.1097
# geospatial_lon_min                                                    11.8100
# geospatial_lon_max                                                    11.8100
# time_coverage_start                                      2004-02-03T14:20:00Z
# time_coverage_end                                        2020-11-30T10:42:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:14:44Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                BO_PR_CT_SMHIGALTERO.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                     SMHIGALTERO
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.1097
# last_longitude_observation                                            11.8100
# last_date_observation                                    2021-02-08T19:00:46Z
# timeOverlap                                                              True
#
#                                                                         18     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3125
# geospatial_lat_max                                                    58.3125
# geospatial_lon_min                                                    11.7733
# geospatial_lon_max                                                    11.7733
# time_coverage_start                                      2004-02-03T17:45:00Z
# time_coverage_end                                        2020-11-30T12:53:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:15:01Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                          BO_PR_CT_SMHIHAVSTENSFJORD.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                               SMHIHAVSTENSFJORD
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3125
# last_longitude_observation                                            11.7733
# last_date_observation                                    2021-02-07T01:15:01Z
# timeOverlap                                                              True
#
#                                                                         21     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    57.9017
# geospatial_lat_max                                                    57.9017
# geospatial_lon_min                                                    11.6667
# geospatial_lon_max                                                    11.6667
# time_coverage_start                                      2004-02-03T10:25:00Z
# time_coverage_end                                        2020-11-30T09:20:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:15:07Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                             BO_PR_CT_SMHIINSTORANNA.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                  SMHIINSTORANNA
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             57.9017
# last_longitude_observation                                            11.6667
# last_date_observation                                    2021-02-08T19:00:46Z
# timeOverlap                                                              True
#
#                                                                         23     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      53.23
# geospatial_lat_max                                                      58.23
# geospatial_lon_min                                                      11.58
# geospatial_lon_max                                                      11.58
# time_coverage_start                                      2004-02-03T19:15:00Z
# time_coverage_end                                        2020-11-30T14:03:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:15:15Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                             BO_PR_CT_SMHIKOLJOFJORD.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                  SMHIKOLJOFJORD
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                               53.23
# last_longitude_observation                                              11.58
# last_date_observation                                    2021-02-07T01:15:15Z
# timeOverlap                                                              True
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
# timeOverlap                 ...
#
#                                                                         21810  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    62.5992
# geospatial_lat_max                                                    62.6053
# geospatial_lon_min                                                    20.8273
# geospatial_lon_max                                                    20.8333
# time_coverage_start                                      1980-06-05T12:45:00Z
# time_coverage_end                                        2020-12-06T16:58:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:16:51Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                    BO_PR_CT_SMHIUS7.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                         SMHIUS7
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             62.5992
# last_longitude_observation                                            20.8273
# last_date_observation                                    2021-02-07T01:16:51Z
# timeOverlap                                                              True
#
#                                                                         21873  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    63.5250
# geospatial_lat_max                                                    63.5250
# geospatial_lon_min                                                    19.8082
# geospatial_lon_max                                                    19.8082
# time_coverage_start                                      2015-06-15T09:05:00Z
# time_coverage_end                                        2020-12-11T08:55:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:17:44Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 PRES SVEL LGHT DOX1
# netcdf                                                      BO_PR_CT_UMFB7.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                           UMFB7
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             63.5250
# last_longitude_observation                                            19.8082
# last_date_observation                                    2021-02-07T01:17:44Z
# timeOverlap                                                              True
#
#                                                                         21874  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    62.6528
# geospatial_lat_max                                                    62.6528
# geospatial_lon_min                                                    18.9523
# geospatial_lon_max                                                    18.9523
# time_coverage_start                                      2000-01-24T17:50:00Z
# time_coverage_end                                        2020-10-20T15:00:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:17:46Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 PRES SVEL LGHT DOX1
# netcdf                                                      BO_PR_CT_UMFC3.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                           UMFC3
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             62.6528
# last_longitude_observation                                            18.9523
# last_date_observation                                    2021-02-07T01:17:46Z
# timeOverlap                                                              True
#
#                                                                         21876  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3367
# geospatial_lat_max                                                    64.7083
# geospatial_lon_min                                                    11.0333
# geospatial_lon_max                                                    22.0667
# time_coverage_start                                      1991-05-28T08:30:00Z
# time_coverage_end                                        2019-07-10T07:34:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:17:49Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 PRES SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_UMFF9A13.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        UMFF9A13
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3367
# last_longitude_observation                                            11.0333
# last_date_observation                                    2021-02-07T01:17:49Z
# timeOverlap                                                              True
#
#                                                                         21877  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    62.8627
# geospatial_lat_max                                                    62.8627
# geospatial_lon_min                                                    18.2640
# geospatial_lon_max                                                    18.2640
# time_coverage_start                                      2015-08-03T20:21:00Z
# time_coverage_end                                        2020-12-09T12:22:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:17:50Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 PRES SVEL LGHT DOX1
# netcdf                                                     BO_PR_CT_UMFGA1.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                          UMFGA1
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             62.8627
# last_longitude_observation                                            18.2640
# last_date_observation                                    2021-02-07T01:17:50Z
# timeOverlap                                                              True
#
#                                                                         21879  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    60.6623
# geospatial_lat_max                                                    63.4997
# geospatial_lon_min                                                    17.4072
# geospatial_lon_max                                                    19.8190
# time_coverage_start                                      2015-08-03T13:35:00Z
# time_coverage_end                                        2019-10-22T09:38:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:17:51Z
# data_mode                                                                   M
# parameters                    PSAL PSAL_DM TEMP TUR4 FLU2 PRES SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_UMFNB1B3.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        UMFNB1B3
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             60.6623
# last_longitude_observation                                            17.4072
# last_date_observation                                    2021-02-07T01:17:51Z
# timeOverlap                                                              True
#
#                                                                         21880  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    65.8075
# geospatial_lat_max                                                    65.8075
# geospatial_lon_min                                                    22.3750
# geospatial_lon_max                                                    22.3750
# time_coverage_start                                      2015-08-05T15:28:00Z
# time_coverage_end                                        2020-11-10T10:29:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:17:52Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 PRES SVEL LGHT DOX1
# netcdf                                                     BO_PR_CT_UMFRA1.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                          UMFRA1
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             65.8075
# last_longitude_observation                                            22.3750
# last_date_observation                                    2021-02-07T01:17:52Z
# timeOverlap                                                              True
#
#                                                                         22506  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                   54.00000
# geospatial_lat_max                                                   78.43300
# geospatial_lon_min                                                   -5.34820
# geospatial_lon_max                                                   19.56767
# time_coverage_start                                      1986-04-18T20:30:00Z
# time_coverage_end                                        2018-06-30T20:55:52Z
# institution                                                  Greece (Unknown)
# date_update                                              2020-08-07T16:23:04Z
# data_mode                                                                   R
# parameters                  DC_REFERENCE DATA_MODE DIRECTION DEPH PRES TEM...
# netcdf                                                       GL_PR_CT_SQOC.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            SQOC
# wmo_platform_code                                                        SQOC
# institution_edmo_code
# last_latitude_observation                                            54.00000
# last_longitude_observation                                           -5.34820
# last_date_observation                                    2020-08-07T16:23:04Z
# timeOverlap                                                              True
#
#                                                                         22579  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     -52.35
# geospatial_lat_max                                                      78.25
# geospatial_lon_min                                                    -179.03
# geospatial_lon_max                                                     179.98
# time_coverage_start                                      1928-08-20T14:00:00Z
# time_coverage_end                                        2018-09-11T20:16:12Z
# institution                                           United states (Unknown)
# date_update                                              2020-08-07T20:43:24Z
# data_mode                                                                   R
# parameters                  DC_REFERENCE DATA_MODE DIRECTION DEPH PRES DOX...
# netcdf                                                       GL_PR_CT_WTDO.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            WTDO
# wmo_platform_code                                                        WTDO
# institution_edmo_code
# last_latitude_observation                                              -52.35
# last_longitude_observation                                            -179.03
# last_date_observation                                    2020-08-07T20:43:24Z
# timeOverlap                                                              True
#
#                                                                         22585
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                   -18.0000
# geospatial_lat_max                                                    65.5988
# geospatial_lon_min                                                  -179.9330
# geospatial_lon_max                                                   179.1830
# time_coverage_start                                      1981-05-23T03:00:00Z
# time_coverage_end                                        2018-05-03T22:31:12Z
# institution                                           United states (Unknown)
# date_update                                              2020-01-27T21:27:10Z
# data_mode                                                                   R
# parameters                  DC_REFERENCE DATA_MODE DIRECTION DEPH PRES TEM...
# netcdf                                                       GL_PR_CT_WTED.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            WTED
# wmo_platform_code                                                        WTED
# institution_edmo_code
# last_latitude_observation                                            -18.0000
# last_longitude_observation                                          -179.9330
# last_date_observation                                    2020-01-27T21:27:10Z
# timeOverlap                                                              True
#
# [22 rows x 2910 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the above output only list the files containing data within a certain time range (the one set as 'targeted_range') just check `time_coverage_start` and `time_coverage_end` columns.

# %% [markdown]
# ####  4.1.3. By bounding-box

# %% [markdown]
# Let's look for files containing data from a specific area.<br>`Please set your own area limits` next `and run the cell`:

# %%
targeted_geospatial_lat_min = 64.0  # enter min latitude of your bounding box
targeted_geospatial_lat_max = 66.0  # enter max latitude of your bounding box
targeted_geospatial_lon_min = 20.0  # enter min longitude of your bounding box
targeted_geospatial_lon_max = 28.0  # enter max longitude of your bounding box
targeted_bbox = [targeted_geospatial_lon_min, targeted_geospatial_lat_min, targeted_geospatial_lon_max, targeted_geospatial_lat_max]  # (minx, miny, maxx, maxy)

# %% [markdown]
# Let's see the area you have set before: `run the next cell`

# %%
m = folium.Map(location=[39.0, 0], zoom_start=4)
upper_left = [targeted_geospatial_lat_max, targeted_geospatial_lon_min]
upper_right = [targeted_geospatial_lat_max, targeted_geospatial_lon_max]
lower_right = [targeted_geospatial_lat_min, targeted_geospatial_lon_max]
lower_left = [targeted_geospatial_lat_min, targeted_geospatial_lon_min]
edges_ = [upper_left, upper_right, lower_right, lower_left]
m.add_child(folium.vector_layers.Polygon(locations=edges_))
#Zooming closer
m.fit_bounds(edges_, max_zoom=5)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a1055fbfd963430f9aca702fa4ac788c%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a1055fbfd963430f9aca702fa4ac788c%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a1055fbfd963430f9aca702fa4ac788c%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_a1055fbfd963430f9aca702fa4ac788c%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.0%2C%200.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# If you do not see any map when running the next cell please change your navigator (try chrome!).

# %% [markdown]
# `Run the next cell` to obtain the subset of files with data in such area:

# %%
info['spatialOverlap'] = info.apply(spatialOverlap,targeted_bbox=targeted_bbox,axis=1)
condition = info['spatialOverlap'] == True
subset = info[condition]
subset.transpose()
# Out:
#                                                                         32     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    65.4735
# geospatial_lat_max                                                    65.5716
# geospatial_lon_min                                                    22.1705
# geospatial_lon_max                                                    22.4552
# time_coverage_start                                      2021-01-12T00:00:00Z
# time_coverage_end                                        2021-01-12T23:50:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:35Z
# data_mode                                                                   R
# parameters                                 TEMP RELH WDIR WSPD DEPH DRYT ATMP
# netcdf                                               BO_TS_FB_Ale_20210112.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                             Ale
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3733
# last_longitude_observation                                            12.3099
# last_date_observation                                    2021-02-12T01:00:44Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         33     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    65.4193
# geospatial_lat_max                                                    65.5698
# geospatial_lon_min                                                    22.1724
# geospatial_lon_max                                                    22.5770
# time_coverage_start                                      2021-01-13T00:00:00Z
# time_coverage_end                                        2021-01-13T23:50:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:35Z
# data_mode                                                                   R
# parameters                                 TEMP RELH WDIR WSPD DEPH DRYT ATMP
# netcdf                                               BO_TS_FB_Ale_20210113.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                             Ale
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3733
# last_longitude_observation                                            12.3099
# last_date_observation                                    2021-02-12T01:00:44Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         34     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    65.3225
# geospatial_lat_max                                                    65.7544
# geospatial_lon_min                                                    22.1725
# geospatial_lon_max                                                    23.4802
# time_coverage_start                                      2021-01-14T00:00:00Z
# time_coverage_end                                        2021-01-14T23:50:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:36Z
# data_mode                                                                   R
# parameters                                 TEMP RELH WDIR WSPD DEPH DRYT ATMP
# netcdf                                               BO_TS_FB_Ale_20210114.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                             Ale
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3733
# last_longitude_observation                                            12.3099
# last_date_observation                                    2021-02-12T01:00:44Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         35     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    65.5705
# geospatial_lat_max                                                    65.7566
# geospatial_lon_min                                                    23.3278
# geospatial_lon_max                                                    23.4901
# time_coverage_start                                      2021-01-15T00:00:00Z
# time_coverage_end                                        2021-01-15T23:50:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:36Z
# data_mode                                                                   R
# parameters                                 TEMP RELH WDIR WSPD DEPH DRYT ATMP
# netcdf                                               BO_TS_FB_Ale_20210115.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                             Ale
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3733
# last_longitude_observation                                            12.3099
# last_date_observation                                    2021-02-12T01:00:44Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         36     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    65.6364
# geospatial_lat_max                                                    65.7216
# geospatial_lon_min                                                    23.4090
# geospatial_lon_max                                                    23.4862
# time_coverage_start                                      2021-01-16T00:00:00Z
# time_coverage_end                                        2021-01-16T23:50:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:36Z
# data_mode                                                                   R
# parameters                                 TEMP RELH WDIR WSPD DEPH DRYT ATMP
# netcdf                                               BO_TS_FB_Ale_20210116.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                             Ale
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3733
# last_longitude_observation                                            12.3099
# last_date_observation                                    2021-02-12T01:00:44Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         37     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    65.6421
# geospatial_lat_max                                                    65.7579
# geospatial_lon_min                                                    23.3275
# geospatial_lon_max                                                    23.4830
# time_coverage_start                                      2021-01-17T00:00:00Z
# time_coverage_end                                        2021-01-17T23:50:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:36Z
# data_mode                                                                   R
# parameters                                 TEMP RELH WDIR WSPD DEPH DRYT ATMP
# netcdf                                               BO_TS_FB_Ale_20210117.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                             Ale
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3733
# last_longitude_observation                                            12.3099
# last_date_observation                                    2021-02-12T01:00:44Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         38     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    65.6504
# geospatial_lat_max                                                    65.6504
# geospatial_lon_min                                                    23.4675
# geospatial_lon_max                                                    23.4675
# time_coverage_start                                      2021-01-18T00:00:00Z
# time_coverage_end                                        2021-01-18T23:50:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:36Z
# data_mode                                                                   R
# parameters                                 TEMP RELH WDIR WSPD DEPH DRYT ATMP
# netcdf                                               BO_TS_FB_Ale_20210118.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                             Ale
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3733
# last_longitude_observation                                            12.3099
# last_date_observation                                    2021-02-12T01:00:44Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         39     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    64.4652
# geospatial_lat_max                                                    65.7553
# geospatial_lon_min                                                    21.4743
# geospatial_lon_max                                                    23.4897
# time_coverage_start                                      2021-01-19T00:00:00Z
# time_coverage_end                                        2021-01-19T23:50:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:36Z
# data_mode                                                                   R
# parameters                                 TEMP RELH WDIR WSPD DEPH DRYT ATMP
# netcdf                                               BO_TS_FB_Ale_20210119.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                             Ale
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3733
# last_longitude_observation                                            12.3099
# last_date_observation                                    2021-02-12T01:00:44Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         40     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    64.6047
# geospatial_lat_max                                                    64.6791
# geospatial_lon_min                                                    21.3018
# geospatial_lon_max                                                    21.4475
# time_coverage_start                                      2021-01-20T00:00:00Z
# time_coverage_end                                        2021-01-20T23:50:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:36Z
# data_mode                                                                   R
# parameters                                 TEMP RELH WDIR WSPD DEPH DRYT ATMP
# netcdf                                               BO_TS_FB_Ale_20210120.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                             Ale
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3733
# last_longitude_observation                                            12.3099
# last_date_observation                                    2021-02-12T01:00:44Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         41     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    64.6090
# geospatial_lat_max                                                    64.6710
# geospatial_lon_min                                                    21.2759
# geospatial_lon_max                                                    21.4264
# time_coverage_start                                      2021-01-21T00:00:00Z
# time_coverage_end                                        2021-01-21T23:50:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:37Z
# data_mode                                                                   R
# parameters                                 TEMP RELH WDIR WSPD DEPH DRYT ATMP
# netcdf                                               BO_TS_FB_Ale_20210121.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                             Ale
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3733
# last_longitude_observation                                            12.3099
# last_date_observation                                    2021-02-12T01:00:44Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
# timeOverlap                 ...
# spatialOverlap              ...
#
#                                                                         22589  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                   -24.0320
# geospatial_lat_max                                                    64.8332
# geospatial_lon_min                                                   -81.2961
# geospatial_lon_max                                                   136.1333
# time_coverage_start                                      1977-08-08T09:24:00Z
# time_coverage_end                                        2011-08-02T06:37:12Z
# institution                                           United states (Unknown)
# date_update                                              2020-08-07T20:43:24Z
# data_mode                                                                   R
# parameters                  DC_REFERENCE DATA_MODE DIRECTION DEPH PRES DOX...
# netcdf                                                       GL_PR_CT_WXAQ.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            WXAQ
# wmo_platform_code                                                        WXAQ
# institution_edmo_code
# last_latitude_observation                                            -24.0320
# last_longitude_observation                                           -81.2961
# last_date_observation                                    2020-08-07T20:43:24Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         22593  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                   -22.5500
# geospatial_lat_max                                                    64.3050
# geospatial_lon_min                                                   -30.8200
# geospatial_lon_max                                                    41.8873
# time_coverage_start                                      1970-07-17T23:00:00Z
# time_coverage_end                                        2003-08-02T20:21:00Z
# institution                                                 Germany (Unknown)
# date_update                                              2020-08-07T20:43:23Z
# data_mode                                                                   R
# parameters                  DC_REFERENCE DATA_MODE DIRECTION DEPH PRES TEM...
# netcdf                                                       GL_PR_CT_Y3CW.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            Y3CW
# wmo_platform_code                                                        Y3CW
# institution_edmo_code
# last_latitude_observation                                            -22.5500
# last_longitude_observation                                           -30.8200
# last_date_observation                                    2020-08-07T20:43:23Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         22596  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    38.8550
# geospatial_lat_max                                                    78.0033
# geospatial_lon_min                                                   -57.6217
# geospatial_lon_max                                                    40.0000
# time_coverage_start                                      1957-07-10T11:00:00Z
# time_coverage_end                                        2006-10-14T11:10:00Z
# institution                                               Unknown institution
# date_update                                              2020-08-07T21:09:24Z
# data_mode                                                                   R
# parameters                  DC_REFERENCE DATA_MODE DIRECTION DEPH PRES PSA...
# netcdf                                                       GL_PR_CT_Y7BO.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            Y7BO
# wmo_platform_code                                                        Y7BO
# institution_edmo_code
# last_latitude_observation                                             38.8550
# last_longitude_observation                                           -57.6217
# last_date_observation                                    2020-08-07T21:09:24Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         22600  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     59.943
# geospatial_lat_max                                                     84.344
# geospatial_lon_min                                                   -179.993
# geospatial_lon_max                                                    179.993
# time_coverage_start                                      2008-03-25T10:49:00Z
# time_coverage_end                                        2016-03-06T05:00:00Z
# institution                                               Unknown institution
# date_update                                              2019-05-06T07:17:22Z
# data_mode                                                                   R
# parameters                  POSITIONING_SYSTEM DC_REFERENCE DEPH DEPH_DM D...
# netcdf                                                      GL_TS_DB_48512.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                           48512
# wmo_platform_code                                                       48512
# institution_edmo_code
# last_latitude_observation                                              59.943
# last_longitude_observation                                           -179.993
# last_date_observation                                    2019-05-06T07:17:22Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         22608  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     55.921
# geospatial_lat_max                                                     65.632
# geospatial_lon_min                                                     15.690
# geospatial_lon_max                                                     25.874
# time_coverage_start                                      2010-08-16T07:00:00Z
# time_coverage_end                                        2013-05-18T14:05:00Z
# institution                                               Unknown institution
# date_update                                              2019-05-06T22:57:45Z
# data_mode                                                                   R
# parameters                  POSITIONING_SYSTEM DC_REFERENCE DEPH DEPH_DM A...
# netcdf                                                      GL_TS_DB_66864.nc
# file_type                                                                  TS
# data_type                                                                  DB
# platform_code                                                           66864
# wmo_platform_code                                                       66864
# institution_edmo_code
# last_latitude_observation                                              55.921
# last_longitude_observation                                             15.690
# last_date_observation                                    2019-05-06T22:57:45Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         22714  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     -34.55
# geospatial_lat_max                                                      67.54
# geospatial_lon_min                                                     -97.05
# geospatial_lon_max                                                      34.00
# time_coverage_start                                      1990-01-01T02:00:00Z
# time_coverage_end                                        1996-09-19T18:00:00Z
# institution                 IRD  Institut de recherche pour le developpeme...
# date_update                                              2019-05-09T18:14:33Z
# data_mode                                                                   R
# parameters                  POSITIONING_SYSTEM DC_REFERENCE DEPH DEPH_DM T...
# netcdf                                                   GL_TS_TS_IF000088.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                        IF000088
# wmo_platform_code
# institution_edmo_code                                                     440
# last_latitude_observation                                              -34.55
# last_longitude_observation                                             -97.05
# last_date_observation                                    2019-05-09T18:14:33Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         22717  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                   -55.9500
# geospatial_lat_max                                                    69.4500
# geospatial_lon_min                                                   -91.5333
# geospatial_lon_max                                                    29.4000
# time_coverage_start                                      2009-05-19T18:00:00Z
# time_coverage_end                                        2012-12-11T15:00:00Z
# institution                                               Unknown institution
# date_update                                              2019-05-09T18:18:33Z
# data_mode                                                                   R
# parameters                  POSITIONING_SYSTEM DC_REFERENCE DEPH DEPH_DM T...
# netcdf                                                      GL_TS_TS_KS089.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                           KS089
# wmo_platform_code                                                       KS089
# institution_edmo_code
# last_latitude_observation                                            -55.9500
# last_longitude_observation                                           -91.5333
# last_date_observation                                    2019-05-09T18:18:33Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         22722  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    11.8333
# geospatial_lat_max                                                    69.4167
# geospatial_lon_min                                                   -77.9000
# geospatial_lon_max                                                    60.5000
# time_coverage_start                                      1990-01-21T05:00:00Z
# time_coverage_end                                        1990-11-08T13:40:00Z
# institution                                               Unknown institution
# date_update                                              2019-09-08T04:51:59Z
# data_mode                                                                   R
# parameters                  DC_REFERENCE DATA_MODE DIRECTION DEPH PRES TEM...
# netcdf                                                   GL_PR_XB_18189002.nc
# file_type                                                                  PR
# data_type                                                                  XB
# platform_code                                                        18189002
# wmo_platform_code                                                    18189002
# institution_edmo_code
# last_latitude_observation                                             11.8333
# last_longitude_observation                                           -77.9000
# last_date_observation                                    2019-09-08T04:51:59Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         22724  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     2.9800
# geospatial_lat_max                                                    67.7167
# geospatial_lon_min                                                  -178.8000
# geospatial_lon_max                                                   179.1667
# time_coverage_start                                      1991-06-13T23:30:00Z
# time_coverage_end                                        1991-12-13T11:59:00Z
# institution                                               Unknown institution
# date_update                                              2019-05-11T18:41:09Z
# data_mode                                                                   R
# parameters                  DC_REFERENCE DATA_MODE DIRECTION DEPH PRES TEM...
# netcdf                                                   GL_PR_XB_18189102.nc
# file_type                                                                  PR
# data_type                                                                  XB
# platform_code                                                        18189102
# wmo_platform_code                                                    18189102
# institution_edmo_code
# last_latitude_observation                                              2.9800
# last_longitude_observation                                          -178.8000
# last_date_observation                                    2019-05-11T18:41:09Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
#                                                                         22743
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      63.16
# geospatial_lat_max                                                      64.70
# geospatial_lon_min                                                      18.91
# geospatial_lon_max                                                      22.06
# time_coverage_start                                      1996-08-05T21:00:00Z
# time_coverage_end                                        1996-10-14T20:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:10:18Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SEXN.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SEXN
# wmo_platform_code                                                        SEXN
# institution_edmo_code
# last_latitude_observation                                               63.16
# last_longitude_observation                                              18.91
# last_date_observation                                    2019-10-06T06:10:18Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
#
# [23 rows x 1360 columns]

# %% [markdown]
# Let's check now if the bbox of the above files truely overlaps with the targeted area!: `run the next cells`

# %%
numberOfFiles = 500 #we will check just a sample of files not all

# %%
m = folium.Map(location=[39.0, 0], zoom_start=6)
m.add_child(folium.vector_layers.Polygon(locations=edges_))
for platform, files in subset[:numberOfFiles].groupby(['platform_code', 'data_type']):
    color = "%06x" % random.randint(0, 0xFFFFFF)
    for i in range(0, len(files)):
        netcdf = files.iloc[i]['file_name'].split('/')[-1]
        upper_left = [
            files.iloc[i]['geospatial_lat_max'],
            files.iloc[i]['geospatial_lon_min']
        ]
        upper_right = [
            files.iloc[i]['geospatial_lat_max'],
            files.iloc[i]['geospatial_lon_max']
        ]
        lower_right = [
            files.iloc[i]['geospatial_lat_min'],
            files.iloc[i]['geospatial_lon_max']
        ]
        lower_left = [
            files.iloc[i]['geospatial_lat_min'],
            files.iloc[i]['geospatial_lon_min']
        ]
        edges = [upper_left, upper_right, lower_right, lower_left]
        popup_info = '<b>netcdf</b>: ' + files.iloc[i]['netcdf']
        m.add_child(folium.vector_layers.Polygon(locations=edges,color='#' + color,popup=(folium.Popup(popup_info))))
        m.fit_bounds(edges, max_zoom=6)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_204bb82d2b094a45b9fff99700eaed63%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_204bb82d2b094a45b9fff99700eaed63%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_204bb82d2b094a45b9fff99700eaed63%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_204bb82d2b094a45b9fff99700eaed63%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.0%2C%200.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# If you do not see any map when running the next cell please change your navigator (try chrome!).

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if everything went well, just check if the files bbox is indeed at some point within the one you were interested in (targeted bbox)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>IMPORTANT</b>
#
# ***
# If you are not satisfied with the resulting output (i.e you want to get only the files whose bbox is completely within the targeted area) please revisit the [definition of the SpatialOverlap](#SpatialOverlap) function and replace the rule applied (`intersects`) by any of the available ones [here](https://shapely.readthedocs.io/en/stable/manual.html)

# %% [markdown]
# #### 4.1.4. By last position

# %% [markdown]
# Let's look for files produced by a platform whose last position is within a specific area.<br>`Please set your own area limits` next `and run the cell`:

# %%
targeted_geospatial_lat_min = 58.0  # enter min latitude of your bounding box
targeted_geospatial_lat_max = 61.0  # enter max latitude of your bounding box
targeted_geospatial_lon_min = 20.0  # enter min longitude of your bounding box
targeted_geospatial_lon_max = 28.0  # enter max longitude of your bounding box
targeted_bbox = [targeted_geospatial_lon_min, targeted_geospatial_lat_min, targeted_geospatial_lon_max, targeted_geospatial_lat_max]  # (minx, miny, maxx, maxy)

# %% [markdown]
# Let's see the area you have set before: `run the next cell`

# %%
m = folium.Map(location=[39.0, 0], zoom_start=4)
upper_left = [targeted_geospatial_lat_max, targeted_geospatial_lon_min]
upper_right = [targeted_geospatial_lat_max, targeted_geospatial_lon_max]
lower_right = [targeted_geospatial_lat_min, targeted_geospatial_lon_max]
lower_left = [targeted_geospatial_lat_min, targeted_geospatial_lon_min]
edges_ = [upper_left, upper_right, lower_right, lower_left]
m.add_child(folium.vector_layers.Polygon(locations=edges_))
#Zooming closer
m.fit_bounds(edges_, max_zoom=5)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_69fe043b7b6249d0b2b3723e458bcf60%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_69fe043b7b6249d0b2b3723e458bcf60%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_69fe043b7b6249d0b2b3723e458bcf60%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_69fe043b7b6249d0b2b3723e458bcf60%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.0%2C%200.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# If you do not see any map when running the next cell please change your navigator (try chrome!).

# %% [markdown]
# `Run the next cell` to obtain the subset of files with data in such area:

# %%
info['lastLocationInRange'] = info.apply(lastLocationInRange,targeted_bbox=targeted_bbox,axis=1)
condition = info['lastLocationInRange'] == True
subset = info[condition]
subset.transpose()
# Out:
#                                                                         4      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.8815
# geospatial_lat_max                                                    58.8815
# geospatial_lon_min                                                    20.3282
# geospatial_lon_max                                                    20.3282
# time_coverage_start                                      2021-01-12T12:11:00Z
# time_coverage_end                                        2021-01-12T12:11:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:28Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 PRES SVEL LGHT DOX1
# netcdf                                          BO_PR_CT_SMHIBY29_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY29
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.8748
# last_longitude_observation                                            20.3100
# last_date_observation                                    2021-02-07T01:12:08Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         5      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.8748
# geospatial_lat_max                                                    58.8855
# geospatial_lon_min                                                    20.3100
# geospatial_lon_max                                                    20.3358
# time_coverage_start                                      1978-11-21T08:20:00Z
# time_coverage_end                                        2020-12-10T17:55:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:12:08Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_SMHIBY29.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY29
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.8748
# last_longitude_observation                                            20.3100
# last_date_observation                                    2021-02-07T01:12:08Z
# timeOverlap                                                              True
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         2946   \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    59.7572
# geospatial_lat_max                                                    59.7572
# geospatial_lon_min                                                    23.2196
# geospatial_lon_max                                                    23.2196
# time_coverage_start                                      2021-01-12T00:00:00Z
# time_coverage_end                                        2021-01-12T23:00:00Z
# institution                                                               FMI
# date_update                                              2021-02-07T01:03:30Z
# data_mode                                                                   R
# parameters                                                          TEMP DEPH
# netcdf                                      BO_TS_MO_HankoLangden_20210112.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                    HankoLangden
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1725
# last_latitude_observation                                             59.7572
# last_longitude_observation                                            23.2196
# last_date_observation                                    2021-02-08T01:01:02Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         2947   \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    59.7572
# geospatial_lat_max                                                    59.7572
# geospatial_lon_min                                                    23.2196
# geospatial_lon_max                                                    23.2196
# time_coverage_start                                      2021-01-13T00:00:00Z
# time_coverage_end                                        2021-01-13T23:00:00Z
# institution                                                               FMI
# date_update                                              2021-02-07T01:03:30Z
# data_mode                                                                   R
# parameters                                                          TEMP DEPH
# netcdf                                      BO_TS_MO_HankoLangden_20210113.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                    HankoLangden
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1725
# last_latitude_observation                                             59.7572
# last_longitude_observation                                            23.2196
# last_date_observation                                    2021-02-08T01:01:02Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         2948   \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    59.7572
# geospatial_lat_max                                                    59.7572
# geospatial_lon_min                                                    23.2196
# geospatial_lon_max                                                    23.2196
# time_coverage_start                                      2021-01-14T00:00:00Z
# time_coverage_end                                        2021-01-14T23:00:00Z
# institution                                                               FMI
# date_update                                              2021-02-07T01:03:31Z
# data_mode                                                                   R
# parameters                                                          TEMP DEPH
# netcdf                                      BO_TS_MO_HankoLangden_20210114.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                    HankoLangden
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1725
# last_latitude_observation                                             59.7572
# last_longitude_observation                                            23.2196
# last_date_observation                                    2021-02-08T01:01:02Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         2949   \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    59.7572
# geospatial_lat_max                                                    59.7572
# geospatial_lon_min                                                    23.2196
# geospatial_lon_max                                                    23.2196
# time_coverage_start                                      2021-01-15T00:00:00Z
# time_coverage_end                                        2021-01-15T23:00:00Z
# institution                                                               FMI
# date_update                                              2021-02-07T01:03:31Z
# data_mode                                                                   R
# parameters                                                          TEMP DEPH
# netcdf                                      BO_TS_MO_HankoLangden_20210115.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                    HankoLangden
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1725
# last_latitude_observation                                             59.7572
# last_longitude_observation                                            23.2196
# last_date_observation                                    2021-02-08T01:01:02Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         2950   \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    59.7572
# geospatial_lat_max                                                    59.7572
# geospatial_lon_min                                                    23.2196
# geospatial_lon_max                                                    23.2196
# time_coverage_start                                      2021-01-16T00:00:00Z
# time_coverage_end                                        2021-01-16T23:00:00Z
# institution                                                               FMI
# date_update                                              2021-02-07T01:03:31Z
# data_mode                                                                   R
# parameters                                                          TEMP DEPH
# netcdf                                      BO_TS_MO_HankoLangden_20210116.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                    HankoLangden
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1725
# last_latitude_observation                                             59.7572
# last_longitude_observation                                            23.2196
# last_date_observation                                    2021-02-08T01:01:02Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         2951   \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    59.7572
# geospatial_lat_max                                                    59.7572
# geospatial_lon_min                                                    23.2196
# geospatial_lon_max                                                    23.2196
# time_coverage_start                                      2021-01-17T00:00:00Z
# time_coverage_end                                        2021-01-17T23:00:00Z
# institution                                                               FMI
# date_update                                              2021-02-07T01:03:31Z
# data_mode                                                                   R
# parameters                                                          TEMP DEPH
# netcdf                                      BO_TS_MO_HankoLangden_20210117.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                    HankoLangden
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1725
# last_latitude_observation                                             59.7572
# last_longitude_observation                                            23.2196
# last_date_observation                                    2021-02-08T01:01:02Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         2952   \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    59.7572
# geospatial_lat_max                                                    59.7572
# geospatial_lon_min                                                    23.2196
# geospatial_lon_max                                                    23.2196
# time_coverage_start                                      2021-01-18T00:00:00Z
# time_coverage_end                                        2021-01-18T23:00:00Z
# institution                                                               FMI
# date_update                                              2021-02-07T01:03:31Z
# data_mode                                                                   R
# parameters                                                          TEMP DEPH
# netcdf                                      BO_TS_MO_HankoLangden_20210118.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                    HankoLangden
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1725
# last_latitude_observation                                             59.7572
# last_longitude_observation                                            23.2196
# last_date_observation                                    2021-02-08T01:01:02Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         2953   \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    59.7572
# geospatial_lat_max                                                    59.7572
# geospatial_lon_min                                                    23.2196
# geospatial_lon_max                                                    23.2196
# time_coverage_start                                      2021-01-19T00:00:00Z
# time_coverage_end                                        2021-01-19T23:00:00Z
# institution                                                               FMI
# date_update                                              2021-02-07T01:03:31Z
# data_mode                                                                   R
# parameters                                                          TEMP DEPH
# netcdf                                      BO_TS_MO_HankoLangden_20210119.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                    HankoLangden
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                    1725
# last_latitude_observation                                             59.7572
# last_longitude_observation                                            23.2196
# last_date_observation                                    2021-02-08T01:01:02Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
# timeOverlap                 ...
# spatialOverlap              ...
# lastLocationInRange         ...
#
#                                                                         22612  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    59.4800
# geospatial_lat_max                                                    60.1200
# geospatial_lon_min                                                    19.2763
# geospatial_lon_max                                                    24.9346
# time_coverage_start                                      2010-01-14T11:28:00Z
# time_coverage_end                                        2010-12-31T17:16:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T01:21:57Z
# data_mode                                                                   R
# parameters                                                PSAL TEMP FLU2 DEPH
# netcdf                                        BO_TS_FB_BalticPrincess_2010.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                  BalticPrincess
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                             59.4800
# last_longitude_observation                                            24.6539
# last_date_observation                                    2021-02-07T01:22:07Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         22613  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    59.4800
# geospatial_lat_max                                                    60.1199
# geospatial_lon_min                                                    24.6299
# geospatial_lon_max                                                    24.9408
# time_coverage_start                                      2011-01-01T11:26:00Z
# time_coverage_end                                        2011-12-30T19:39:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T01:22:00Z
# data_mode                                                                   R
# parameters                                                PSAL TEMP FLU2 DEPH
# netcdf                                        BO_TS_FB_BalticPrincess_2011.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                  BalticPrincess
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                             59.4800
# last_longitude_observation                                            24.6539
# last_date_observation                                    2021-02-07T01:22:07Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         22614  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    59.4800
# geospatial_lat_max                                                    60.1200
# geospatial_lon_min                                                    24.6084
# geospatial_lon_max                                                    24.9350
# time_coverage_start                                      2012-01-01T11:25:00Z
# time_coverage_end                                        2012-12-23T19:01:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T01:22:06Z
# data_mode                                                                   R
# parameters                                                PSAL TEMP FLU2 DEPH
# netcdf                                        BO_TS_FB_BalticPrincess_2012.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                  BalticPrincess
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                             59.4800
# last_longitude_observation                                            24.6539
# last_date_observation                                    2021-02-07T01:22:07Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         22615  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    59.4800
# geospatial_lat_max                                                    60.1200
# geospatial_lon_min                                                    24.6539
# geospatial_lon_max                                                    24.9189
# time_coverage_start                                      2013-01-03T11:22:00Z
# time_coverage_end                                        2013-01-21T19:32:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T01:22:07Z
# data_mode                                                                   R
# parameters                                                PSAL TEMP FLU2 DEPH
# netcdf                                        BO_TS_FB_BalticPrincess_2013.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                  BalticPrincess
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                             59.4800
# last_longitude_observation                                            24.6539
# last_date_observation                                    2021-02-07T01:22:07Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         22617  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    59.4801
# geospatial_lat_max                                                    60.1189
# geospatial_lon_min                                                    24.6483
# geospatial_lon_max                                                    24.9087
# time_coverage_start                                      2008-06-01T10:59:00Z
# time_coverage_end                                        2008-07-13T18:38:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:36:07Z
# data_mode                                                                   R
# parameters                                                     PSAL TEMP DEPH
# netcdf                                                BO_TS_FB_Galaxy_2008.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                          Galaxy
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             59.4801
# last_longitude_observation                                            24.6483
# last_date_observation                                    2021-02-07T01:36:07Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         22618  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    59.4800
# geospatial_lat_max                                                    60.1200
# geospatial_lon_min                                                    24.6355
# geospatial_lon_max                                                    24.9443
# time_coverage_start                                      2013-07-15T10:30:00Z
# time_coverage_end                                        2013-12-31T19:26:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T01:37:05Z
# data_mode                                                                   R
# parameters                                                PSAL TEMP FLU2 DEPH
# netcdf                                           BO_TS_FB_SiljaEuropa_2013.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                     SiljaEuropa
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                             59.4801
# last_longitude_observation                                            24.6446
# last_date_observation                                    2021-02-07T01:37:08Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         22619  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    59.4801
# geospatial_lat_max                                                    60.1200
# geospatial_lon_min                                                    24.6446
# geospatial_lon_max                                                    24.9137
# time_coverage_start                                      2014-01-01T10:48:00Z
# time_coverage_end                                        2014-07-22T18:36:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T01:37:08Z
# data_mode                                                                   R
# parameters                                                PSAL TEMP FLU2 DEPH
# netcdf                                           BO_TS_FB_SiljaEuropa_2014.nc
# file_type                                                                  TS
# data_type                                                                  FB
# platform_code                                                     SiljaEuropa
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                             59.4801
# last_longitude_observation                                            24.6446
# last_date_observation                                    2021-02-07T01:37:08Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         22630  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    60.8833
# geospatial_lat_max                                                    60.8833
# geospatial_lon_min                                                    20.7500
# geospatial_lon_max                                                    20.7500
# time_coverage_start                                      1989-08-02T09:00:00Z
# time_coverage_end                                        1989-12-19T10:00:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:36:44Z
# data_mode                                                                   M
# parameters                                                VZMX DEPH VTZA VHM0
# netcdf                                               BO_TS_MO_FinskaEnskar.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                    FinskaEnskar
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             60.8833
# last_longitude_observation                                            20.7500
# last_date_observation                                    2021-02-07T01:36:44Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         22665  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    59.4667
# geospatial_lat_max                                                    59.4667
# geospatial_lon_min                                                    20.3500
# geospatial_lon_max                                                    20.3500
# time_coverage_start                                      1982-11-01T04:00:00Z
# time_coverage_end                                        1994-02-08T09:00:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T02:01:48Z
# data_mode                                                                   M
# parameters                       VZMX DEPH TEMP WDIR WSPD DRYT ATMP VTZA VHM0
# netcdf                                              BO_TS_MO_SvenskaBjorn2.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                   SvenskaBjorn2
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             59.4667
# last_longitude_observation                                            20.3500
# last_date_observation                                    2021-02-07T02:01:48Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         22670
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    59.6867
# geospatial_lat_max                                                    59.6867
# geospatial_lon_min                                                    24.6283
# geospatial_lon_max                                                    24.6283
# time_coverage_start                                      2011-08-16T09:00:00Z
# time_coverage_end                                        2013-10-04T12:00:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T02:05:17Z
# data_mode                                                                   R
# parameters                                                PSAL DEPH TEMP FLU2
# netcdf                                                   BO_TS_MO_Uusmadal.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                        Uusmadal
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                             59.6867
# last_longitude_observation                                            24.6283
# last_date_observation                                    2021-02-07T02:05:17Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
# [24 rows x 2439 columns]

# %% [markdown]
# Let's check now if the bbox of the above files truely overlaps with the targeted area!: `run the next cells`

# %%
numberOfFiles = 200 #we will check just a sample of files not all

# %%
m = folium.Map(location=[39.3, 0], zoom_start=5)
m.add_child(folium.vector_layers.Polygon(locations=edges_))
for platform, files in subset[:numberOfFiles].groupby(['platform_code', 'data_type']):
    color = "%06x" % random.randint(0, 0xFFFFFF)
    #Last reported position to map as marker
    i = len(files)-1
    m.add_child(folium.Marker([files.iloc[i]['last_latitude_observation'], files.iloc[i]['last_longitude_observation']], popup=files.iloc[i]['platform_code']+' last position' ))
#Zooming closer
m.fit_bounds(edges_, max_zoom=5)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_cf7b1bb6c3f74e3f924102d8d8b3d7c7%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_cf7b1bb6c3f74e3f924102d8d8b3d7c7%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_cf7b1bb6c3f74e3f924102d8d8b3d7c7%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_cf7b1bb6c3f74e3f924102d8d8b3d7c7%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.3%2C%200.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# If you do not see any map when running the next cell please change your navigator (try chrome!).

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if everything went well, just check if the markers (last platform position) is indeed within the one you were interested in (targeted bbox)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>IMPORTANT</b>
#
# ***
# If you are not satisfied with the resulting output please revisit the [definition of the lastLocationInRange](#LocationInRange) function and replace the rule applied (`contains`) by any of the available ones [here](https://shapely.readthedocs.io/en/stable/manual.html)

# %% [markdown]
# #### 4.1.5. By data type

# %% [markdown]
# Let's look for files produced by a certain data type.<br>`Please set a data type` next `and run the cell`:

# %%
targeted_data_type = 'CT' # try others: TG for Tide Gauges, PF for profilers etc =>Product User Manual: https://archimer.ifremer.fr/doc/00324/43494/

# %% [markdown]
# `Run the next cell` to obtain just the files reported by such data type:

# %%
condition = info['data_type'] == targeted_data_type
subset = info[condition]
subset.transpose()
# Out:
#                                                                         0      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3877
# geospatial_lat_max                                                    58.3877
# geospatial_lon_min                                                    11.6267
# geospatial_lon_max                                                    11.6267
# time_coverage_start                                      2021-01-12T16:02:00Z
# time_coverage_end                                        2021-01-12T16:02:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:28Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                   BO_PR_CT_SMHIBJORKHOLMEN_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                 SMHIBJORKHOLMEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3877
# last_longitude_observation                                            11.6267
# last_date_observation                                    2021-02-07T01:09:58Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         1      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3877
# geospatial_lat_max                                                    58.3877
# geospatial_lon_min                                                    11.6267
# geospatial_lon_max                                                    11.6267
# time_coverage_start                                      2004-03-03T08:12:00Z
# time_coverage_end                                        2020-11-30T15:30:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:09:58Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                            BO_PR_CT_SMHIBJORKHOLMEN.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                 SMHIBJORKHOLMEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3877
# last_longitude_observation                                            11.6267
# last_date_observation                                    2021-02-07T01:09:58Z
# timeOverlap                                                              True
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         2      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    57.3147
# geospatial_lat_max                                                    57.3147
# geospatial_lon_min                                                    20.0803
# geospatial_lon_max                                                    20.0803
# time_coverage_start                                      2021-01-12T00:51:00Z
# time_coverage_end                                        2021-01-12T00:51:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:28Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 PRES SVEL LGHT DOX1
# netcdf                                          BO_PR_CT_SMHIBY15_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY15
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             57.2938
# last_longitude_observation                                            19.9077
# last_date_observation                                    2021-02-07T01:11:06Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         3      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    57.2938
# geospatial_lat_max                                                    57.3345
# geospatial_lon_min                                                    19.9077
# geospatial_lon_max                                                    20.0873
# time_coverage_start                                      1978-11-22T00:20:00Z
# time_coverage_end                                        2020-12-11T05:21:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:11:06Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_SMHIBY15.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY15
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             57.2938
# last_longitude_observation                                            19.9077
# last_date_observation                                    2021-02-07T01:11:06Z
# timeOverlap                                                              True
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         4      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.8815
# geospatial_lat_max                                                    58.8815
# geospatial_lon_min                                                    20.3282
# geospatial_lon_max                                                    20.3282
# time_coverage_start                                      2021-01-12T12:11:00Z
# time_coverage_end                                        2021-01-12T12:11:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:28Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 PRES SVEL LGHT DOX1
# netcdf                                          BO_PR_CT_SMHIBY29_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY29
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.8748
# last_longitude_observation                                            20.3100
# last_date_observation                                    2021-02-07T01:12:08Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         5      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.8748
# geospatial_lat_max                                                    58.8855
# geospatial_lon_min                                                    20.3100
# geospatial_lon_max                                                    20.3358
# time_coverage_start                                      1978-11-21T08:20:00Z
# time_coverage_end                                        2020-12-10T17:55:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:12:08Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_SMHIBY29.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY29
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.8748
# last_longitude_observation                                            20.3100
# last_date_observation                                    2021-02-07T01:12:08Z
# timeOverlap                                                              True
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         6      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.5937
# geospatial_lat_max                                                    58.5937
# geospatial_lon_min                                                    18.2363
# geospatial_lon_max                                                    18.2363
# time_coverage_start                                      2021-01-12T19:50:00Z
# time_coverage_end                                        2021-01-12T19:50:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:29Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 PRES SVEL LGHT DOX1
# netcdf                                          BO_PR_CT_SMHIBY31_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY31
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.5772
# last_longitude_observation                                            18.2263
# last_date_observation                                    2021-02-07T01:12:43Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         7      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.5772
# geospatial_lat_max                                                    58.6100
# geospatial_lon_min                                                    18.2263
# geospatial_lon_max                                                    18.2387
# time_coverage_start                                      1978-11-16T17:00:00Z
# time_coverage_end                                        2020-12-04T17:04:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:12:43Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_SMHIBY31.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY31
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.5772
# last_longitude_observation                                            18.2263
# last_date_observation                                    2021-02-07T01:12:43Z
# timeOverlap                                                              True
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         8      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3333
# geospatial_lat_max                                                    58.3333
# geospatial_lon_min                                                    11.8833
# geospatial_lon_max                                                    11.8833
# time_coverage_start                                      2021-01-12T12:45:00Z
# time_coverage_end                                        2021-01-12T12:45:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:29Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                     BO_PR_CT_SMHIBYFJORDEN_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                   SMHIBYFJORDEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3333
# last_longitude_observation                                            11.8833
# last_date_observation                                    2021-02-08T19:00:46Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         9      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3333
# geospatial_lat_max                                                    58.3333
# geospatial_lon_min                                                    11.8833
# geospatial_lon_max                                                    11.8833
# time_coverage_start                                      2021-02-02T12:33:00Z
# time_coverage_end                                        2021-02-02T12:33:00Z
# institution                                                              SMHI
# date_update                                              2021-02-08T19:00:46Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                     BO_PR_CT_SMHIBYFJORDEN_20210202.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                   SMHIBYFJORDEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3333
# last_longitude_observation                                            11.8833
# last_date_observation                                    2021-02-08T19:00:46Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
# timeOverlap                 ...
# spatialOverlap              ...
# lastLocationInRange         ...
#
#                                                                         22588  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                   -12.0659
# geospatial_lat_max                                                    65.6135
# geospatial_lon_min                                                   -77.1462
# geospatial_lon_max                                                    24.3465
# time_coverage_start                                      1995-06-07T08:45:00Z
# time_coverage_end                                        1995-06-14T08:30:00Z
# institution                                               Unknown institution
# date_update                                              2020-01-27T22:17:51Z
# data_mode                                                                   R
# parameters                  DC_REFERENCE DATA_MODE DIRECTION DEPH CHLT NTR...
# netcdf                                                   GL_PR_CT_WUUY7620.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        WUUY7620
# wmo_platform_code                                                    WUUY7620
# institution_edmo_code
# last_latitude_observation                                            -12.0659
# last_longitude_observation                                           -77.1462
# last_date_observation                                    2020-01-27T22:17:51Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                         22589  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                   -24.0320
# geospatial_lat_max                                                    64.8332
# geospatial_lon_min                                                   -81.2961
# geospatial_lon_max                                                   136.1333
# time_coverage_start                                      1977-08-08T09:24:00Z
# time_coverage_end                                        2011-08-02T06:37:12Z
# institution                                           United states (Unknown)
# date_update                                              2020-08-07T20:43:24Z
# data_mode                                                                   R
# parameters                  DC_REFERENCE DATA_MODE DIRECTION DEPH PRES DOX...
# netcdf                                                       GL_PR_CT_WXAQ.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            WXAQ
# wmo_platform_code                                                        WXAQ
# institution_edmo_code
# last_latitude_observation                                            -24.0320
# last_longitude_observation                                           -81.2961
# last_date_observation                                    2020-08-07T20:43:24Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                         22590  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    54.4288
# geospatial_lat_max                                                    57.7822
# geospatial_lon_min                                                     9.4700
# geospatial_lon_max                                                    16.7500
# time_coverage_start                                      1971-06-06T00:00:00Z
# time_coverage_end                                        2015-03-13T11:49:48Z
# institution                                               Unknown institution
# date_update                                              2020-01-27T22:17:52Z
# data_mode                                                                   R
# parameters                  DC_REFERENCE DATA_MODE DIRECTION DEPH PRES TEM...
# netcdf                                                     GL_PR_CT_XP2175.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                          XP2175
# wmo_platform_code                                                      XP2175
# institution_edmo_code
# last_latitude_observation                                             54.4288
# last_longitude_observation                                             9.4700
# last_date_observation                                    2020-01-27T22:17:52Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         22591  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    53.9500
# geospatial_lat_max                                                    59.9167
# geospatial_lon_min                                                    10.4463
# geospatial_lon_max                                                    25.6000
# time_coverage_start                                      1978-02-03T21:00:00Z
# time_coverage_end                                        2008-07-30T23:42:00Z
# institution                                                 Germany (Unknown)
# date_update                                              2020-01-27T22:17:51Z
# data_mode                                                                   R
# parameters                  DC_REFERENCE DATA_MODE DIRECTION DEPH PRES PSA...
# netcdf                                                       GL_PR_CT_Y3CH.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            Y3CH
# wmo_platform_code                                                        Y3CH
# institution_edmo_code
# last_latitude_observation                                             54.9100
# last_longitude_observation                                            15.9800
# last_date_observation                                    2020-01-28T05:19:35Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         22593  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                   -22.5500
# geospatial_lat_max                                                    64.3050
# geospatial_lon_min                                                   -30.8200
# geospatial_lon_max                                                    41.8873
# time_coverage_start                                      1970-07-17T23:00:00Z
# time_coverage_end                                        2003-08-02T20:21:00Z
# institution                                                 Germany (Unknown)
# date_update                                              2020-08-07T20:43:23Z
# data_mode                                                                   R
# parameters                  DC_REFERENCE DATA_MODE DIRECTION DEPH PRES TEM...
# netcdf                                                       GL_PR_CT_Y3CW.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            Y3CW
# wmo_platform_code                                                        Y3CW
# institution_edmo_code
# last_latitude_observation                                            -22.5500
# last_longitude_observation                                           -30.8200
# last_date_observation                                    2020-08-07T20:43:23Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                         22595  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     53.807
# geospatial_lat_max                                                     54.762
# geospatial_lon_min                                                     11.175
# geospatial_lon_max                                                     14.235
# time_coverage_start                                      1999-01-04T13:22:12Z
# time_coverage_end                                        2002-12-19T15:00:00Z
# institution                                               Unknown institution
# date_update                                              2020-01-27T22:17:50Z
# data_mode                                                                   R
# parameters                  DC_REFERENCE DATA_MODE DIRECTION PRES TEMP PSA...
# netcdf                                                       GL_PR_CT_Y3OE.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            Y3OE
# wmo_platform_code                                                        Y3OE
# institution_edmo_code
# last_latitude_observation                                              53.807
# last_longitude_observation                                             11.175
# last_date_observation                                    2020-01-27T22:17:50Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         22596  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    38.8550
# geospatial_lat_max                                                    78.0033
# geospatial_lon_min                                                   -57.6217
# geospatial_lon_max                                                    40.0000
# time_coverage_start                                      1957-07-10T11:00:00Z
# time_coverage_end                                        2006-10-14T11:10:00Z
# institution                                               Unknown institution
# date_update                                              2020-08-07T21:09:24Z
# data_mode                                                                   R
# parameters                  DC_REFERENCE DATA_MODE DIRECTION DEPH PRES PSA...
# netcdf                                                       GL_PR_CT_Y7BO.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            Y7BO
# wmo_platform_code                                                        Y7BO
# institution_edmo_code
# last_latitude_observation                                             38.8550
# last_longitude_observation                                           -57.6217
# last_date_observation                                    2020-08-07T21:09:24Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                         22597  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    56.0715
# geospatial_lat_max                                                    57.9558
# geospatial_lon_min                                                    20.9372
# geospatial_lon_max                                                    24.3770
# time_coverage_start                                      1995-01-26T12:04:48Z
# time_coverage_end                                        2005-06-05T00:00:00Z
# institution                                               Unknown institution
# date_update                                              2020-01-27T22:44:21Z
# data_mode                                                                   R
# parameters                  DC_REFERENCE DATA_MODE DIRECTION DEPH PSAL PHP...
# netcdf                                                     GL_PR_CT_YL2025.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                          YL2025
# wmo_platform_code                                                      YL2025
# institution_edmo_code
# last_latitude_observation                                             56.0715
# last_longitude_observation                                            20.9372
# last_date_observation                                    2020-01-27T22:44:21Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         22598  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    57.2987
# geospatial_lat_max                                                    57.4142
# geospatial_lon_min                                                    23.7747
# geospatial_lon_max                                                    23.8520
# time_coverage_start                                      2012-07-18T05:30:00Z
# time_coverage_end                                        2012-07-18T07:40:12Z
# institution                                               Unknown institution
# date_update                                              2020-01-27T22:44:21Z
# data_mode                                                                   R
# parameters                  DC_REFERENCE DATA_MODE DIRECTION DEPH DOX1 PHP...
# netcdf                                                     GL_PR_CT_YL2132.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                          YL2132
# wmo_platform_code                                                      YL2132
# institution_edmo_code
# last_latitude_observation                                             57.2987
# last_longitude_observation                                            23.7747
# last_date_observation                                    2020-01-27T22:44:21Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         22599
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    56.0367
# geospatial_lat_max                                                    58.2000
# geospatial_lon_min                                                    19.8653
# geospatial_lon_max                                                    24.3740
# time_coverage_start                                      2005-08-04T00:00:00Z
# time_coverage_end                                        2014-11-12T19:13:00Z
# institution                 Latvian Environment Geology and Meteorology Ag...
# date_update                                              2020-08-06T11:07:27Z
# data_mode                                                                   R
# parameters                  DC_REFERENCE DATA_MODE DIRECTION DEPH PRES CHL...
# netcdf                                                       GL_PR_CT_YLNU.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                            YLNU
# wmo_platform_code                                                        YLNU
# institution_edmo_code                                                     892
# last_latitude_observation                                             56.0367
# last_longitude_observation                                            19.8653
# last_date_observation                                    2020-08-06T11:07:27Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
# [24 rows x 1821 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the subset only contains the aimed data type (targeted_data_type) just check the `data_type` column of the above output.

# %% [markdown]
# #### 4.1.6. By file type

# %% [markdown]
# Let's look for certain types of files.<br>`Please set a file type` next `and run the cell`:

# %%
targeted_file_type = 'PR' # try others: TS for Time Series...=>Product User Manual: https://archimer.ifremer.fr/doc/00324/43494/

# %% [markdown]
# `Run the next cell` to obtain just the above type of files:

# %%
condition = info['file_type'] == targeted_file_type
subset = info[condition]
subset.transpose()
# Out:
#                                                                         0      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3877
# geospatial_lat_max                                                    58.3877
# geospatial_lon_min                                                    11.6267
# geospatial_lon_max                                                    11.6267
# time_coverage_start                                      2021-01-12T16:02:00Z
# time_coverage_end                                        2021-01-12T16:02:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:28Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                   BO_PR_CT_SMHIBJORKHOLMEN_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                 SMHIBJORKHOLMEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3877
# last_longitude_observation                                            11.6267
# last_date_observation                                    2021-02-07T01:09:58Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         1      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3877
# geospatial_lat_max                                                    58.3877
# geospatial_lon_min                                                    11.6267
# geospatial_lon_max                                                    11.6267
# time_coverage_start                                      2004-03-03T08:12:00Z
# time_coverage_end                                        2020-11-30T15:30:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:09:58Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                            BO_PR_CT_SMHIBJORKHOLMEN.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                 SMHIBJORKHOLMEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3877
# last_longitude_observation                                            11.6267
# last_date_observation                                    2021-02-07T01:09:58Z
# timeOverlap                                                              True
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         2      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    57.3147
# geospatial_lat_max                                                    57.3147
# geospatial_lon_min                                                    20.0803
# geospatial_lon_max                                                    20.0803
# time_coverage_start                                      2021-01-12T00:51:00Z
# time_coverage_end                                        2021-01-12T00:51:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:28Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 PRES SVEL LGHT DOX1
# netcdf                                          BO_PR_CT_SMHIBY15_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY15
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             57.2938
# last_longitude_observation                                            19.9077
# last_date_observation                                    2021-02-07T01:11:06Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         3      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    57.2938
# geospatial_lat_max                                                    57.3345
# geospatial_lon_min                                                    19.9077
# geospatial_lon_max                                                    20.0873
# time_coverage_start                                      1978-11-22T00:20:00Z
# time_coverage_end                                        2020-12-11T05:21:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:11:06Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_SMHIBY15.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY15
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             57.2938
# last_longitude_observation                                            19.9077
# last_date_observation                                    2021-02-07T01:11:06Z
# timeOverlap                                                              True
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         4      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.8815
# geospatial_lat_max                                                    58.8815
# geospatial_lon_min                                                    20.3282
# geospatial_lon_max                                                    20.3282
# time_coverage_start                                      2021-01-12T12:11:00Z
# time_coverage_end                                        2021-01-12T12:11:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:28Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 PRES SVEL LGHT DOX1
# netcdf                                          BO_PR_CT_SMHIBY29_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY29
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.8748
# last_longitude_observation                                            20.3100
# last_date_observation                                    2021-02-07T01:12:08Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         5      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.8748
# geospatial_lat_max                                                    58.8855
# geospatial_lon_min                                                    20.3100
# geospatial_lon_max                                                    20.3358
# time_coverage_start                                      1978-11-21T08:20:00Z
# time_coverage_end                                        2020-12-10T17:55:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:12:08Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_SMHIBY29.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY29
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.8748
# last_longitude_observation                                            20.3100
# last_date_observation                                    2021-02-07T01:12:08Z
# timeOverlap                                                              True
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         6      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.5937
# geospatial_lat_max                                                    58.5937
# geospatial_lon_min                                                    18.2363
# geospatial_lon_max                                                    18.2363
# time_coverage_start                                      2021-01-12T19:50:00Z
# time_coverage_end                                        2021-01-12T19:50:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:29Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 PRES SVEL LGHT DOX1
# netcdf                                          BO_PR_CT_SMHIBY31_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY31
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.5772
# last_longitude_observation                                            18.2263
# last_date_observation                                    2021-02-07T01:12:43Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         7      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.5772
# geospatial_lat_max                                                    58.6100
# geospatial_lon_min                                                    18.2263
# geospatial_lon_max                                                    18.2387
# time_coverage_start                                      1978-11-16T17:00:00Z
# time_coverage_end                                        2020-12-04T17:04:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:12:43Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_SMHIBY31.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY31
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.5772
# last_longitude_observation                                            18.2263
# last_date_observation                                    2021-02-07T01:12:43Z
# timeOverlap                                                              True
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         8      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3333
# geospatial_lat_max                                                    58.3333
# geospatial_lon_min                                                    11.8833
# geospatial_lon_max                                                    11.8833
# time_coverage_start                                      2021-01-12T12:45:00Z
# time_coverage_end                                        2021-01-12T12:45:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:29Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                     BO_PR_CT_SMHIBYFJORDEN_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                   SMHIBYFJORDEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3333
# last_longitude_observation                                            11.8833
# last_date_observation                                    2021-02-08T19:00:46Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         9      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3333
# geospatial_lat_max                                                    58.3333
# geospatial_lon_min                                                    11.8833
# geospatial_lon_max                                                    11.8833
# time_coverage_start                                      2021-02-02T12:33:00Z
# time_coverage_end                                        2021-02-02T12:33:00Z
# institution                                                              SMHI
# date_update                                              2021-02-08T19:00:46Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                     BO_PR_CT_SMHIBYFJORDEN_20210202.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                   SMHIBYFJORDEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3333
# last_longitude_observation                                            11.8833
# last_date_observation                                    2021-02-08T19:00:46Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
# timeOverlap                 ...
# spatialOverlap              ...
# lastLocationInRange         ...
#
#                                                                         22747  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      56.11
# geospatial_lat_max                                                      56.11
# geospatial_lon_min                                                      16.53
# geospatial_lon_max                                                      16.53
# time_coverage_start                                      1996-08-20T18:50:00Z
# time_coverage_end                                        1997-08-22T17:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:49:13Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SHPF.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SHPF
# wmo_platform_code                                                        SHPF
# institution_edmo_code
# last_latitude_observation                                               56.11
# last_longitude_observation                                              16.53
# last_date_observation                                    2019-10-06T06:49:13Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         22748  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      58.03
# geospatial_lat_max                                                      58.03
# geospatial_lon_min                                                      17.07
# geospatial_lon_max                                                      17.07
# time_coverage_start                                      1996-08-10T10:30:00Z
# time_coverage_end                                        1998-02-12T13:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:49:13Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SHQP.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SHQP
# wmo_platform_code                                                        SHQP
# institution_edmo_code
# last_latitude_observation                                               58.03
# last_longitude_observation                                              17.07
# last_date_observation                                    2019-10-06T06:49:13Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         22749  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      56.66
# geospatial_lat_max                                                      56.66
# geospatial_lon_min                                                      12.11
# geospatial_lon_max                                                      12.11
# time_coverage_start                                      1996-03-02T17:00:00Z
# time_coverage_end                                        1996-03-02T17:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:45Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SJIB.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SJIB
# wmo_platform_code                                                        SJIB
# institution_edmo_code
# last_latitude_observation                                               56.66
# last_longitude_observation                                              12.11
# last_date_observation                                    2019-10-06T06:52:45Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         22750  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      62.13
# geospatial_lat_max                                                      62.13
# geospatial_lon_min                                                      17.86
# geospatial_lon_max                                                      17.86
# time_coverage_start                                      1997-07-04T16:30:00Z
# time_coverage_end                                        1997-07-04T16:30:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:45Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SKUP.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SKUP
# wmo_platform_code                                                        SKUP
# institution_edmo_code
# last_latitude_observation                                               62.13
# last_longitude_observation                                              17.86
# last_date_observation                                    2019-10-06T06:52:45Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         22751  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      62.13
# geospatial_lat_max                                                      62.13
# geospatial_lon_min                                                      17.86
# geospatial_lon_max                                                      17.86
# time_coverage_start                                      1996-10-25T10:00:00Z
# time_coverage_end                                        1997-09-27T15:45:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:45Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SKVP.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SKVP
# wmo_platform_code                                                        SKVP
# institution_edmo_code
# last_latitude_observation                                               62.13
# last_longitude_observation                                              17.86
# last_date_observation                                    2019-10-06T06:52:45Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         22752  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      55.00
# geospatial_lat_max                                                      56.97
# geospatial_lon_min                                                     -60.00
# geospatial_lon_max                                                      14.83
# time_coverage_start                                      1999-07-20T11:00:00Z
# time_coverage_end                                        1999-09-22T11:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:45Z
# data_mode                                                                   R
# parameters                    DC_REFERENCE DATA_MODE DIRECTION DEPH PRES TEMP
# netcdf                                                       GL_PR_XX_SMTZ.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SMTZ
# wmo_platform_code                                                        SMTZ
# institution_edmo_code
# last_latitude_observation                                               55.00
# last_longitude_observation                                             -60.00
# last_date_observation                                    2019-10-06T06:52:45Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         22753  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      57.20
# geospatial_lat_max                                                      57.20
# geospatial_lon_min                                                      11.66
# geospatial_lon_max                                                      11.66
# time_coverage_start                                      1996-08-20T12:20:00Z
# time_coverage_end                                        1996-08-20T12:20:00Z
# institution                                               Unknown institution
# date_update                                              2019-10-06T06:52:44Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SMZG.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SMZG
# wmo_platform_code                                                        SMZG
# institution_edmo_code
# last_latitude_observation                                               57.20
# last_longitude_observation                                              11.66
# last_date_observation                                    2019-10-06T06:52:44Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         22754  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      56.66
# geospatial_lat_max                                                      57.18
# geospatial_lon_min                                                      11.66
# geospatial_lon_max                                                      12.11
# time_coverage_start                                      1996-01-17T14:15:00Z
# time_coverage_end                                        1998-05-16T13:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:44Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SMZQ.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SMZQ
# wmo_platform_code                                                        SMZQ
# institution_edmo_code
# last_latitude_observation                                               56.66
# last_longitude_observation                                              11.66
# last_date_observation                                    2019-10-06T06:52:44Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         22755  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      55.00
# geospatial_lat_max                                                      62.13
# geospatial_lon_min                                                      11.66
# geospatial_lon_max                                                      17.86
# time_coverage_start                                      1996-06-02T18:20:00Z
# time_coverage_end                                        1999-09-07T12:45:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:44Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SMZT.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SMZT
# wmo_platform_code                                                        SMZT
# institution_edmo_code
# last_latitude_observation                                               55.00
# last_longitude_observation                                              11.66
# last_date_observation                                    2019-10-06T06:52:44Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         22756
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     57.717
# geospatial_lat_max                                                     65.025
# geospatial_lon_min                                                    -12.979
# geospatial_lon_max                                                      8.983
# time_coverage_start                                      2013-09-21T15:14:00Z
# time_coverage_end                                        2013-10-25T05:34:00Z
# institution                                               Unknown institution
# date_update                                              2019-10-06T08:07:25Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION DEPH TEMP
# netcdf                                                    GL_PR_XX_VOZ2040.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                         VOZ2040
# wmo_platform_code                                                     VOZ2040
# institution_edmo_code
# last_latitude_observation                                              57.717
# last_longitude_observation                                            -12.979
# last_date_observation                                    2019-10-06T08:07:25Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
# [24 rows x 2488 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the subset matches the aimed file type (targeted_file_type) just check the `file_type` column of the above output.

# %% [markdown]
# #### 4.1.7. By parameter

# %% [markdown]
# Let's look for files containing a certain parameter.<br>`Please set a parameter code` next `and run the cell`:

# %%
targeted_parameter = 'PSAL' #try others: TEMP, SLEV etc => In Situ parameter list: https://archimer.ifremer.fr/doc/00422/53381/

# %% [markdown]
# Run the next cell to obtain just the files reporting such parameter:

# %%
condition = info['parameters'].str.contains(targeted_parameter)
subset = info[condition]
subset.transpose()
# Out:
#                                                                         0      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3877
# geospatial_lat_max                                                    58.3877
# geospatial_lon_min                                                    11.6267
# geospatial_lon_max                                                    11.6267
# time_coverage_start                                      2021-01-12T16:02:00Z
# time_coverage_end                                        2021-01-12T16:02:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:28Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                   BO_PR_CT_SMHIBJORKHOLMEN_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                 SMHIBJORKHOLMEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3877
# last_longitude_observation                                            11.6267
# last_date_observation                                    2021-02-07T01:09:58Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         1      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3877
# geospatial_lat_max                                                    58.3877
# geospatial_lon_min                                                    11.6267
# geospatial_lon_max                                                    11.6267
# time_coverage_start                                      2004-03-03T08:12:00Z
# time_coverage_end                                        2020-11-30T15:30:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:09:58Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                            BO_PR_CT_SMHIBJORKHOLMEN.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                 SMHIBJORKHOLMEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3877
# last_longitude_observation                                            11.6267
# last_date_observation                                    2021-02-07T01:09:58Z
# timeOverlap                                                              True
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         2      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    57.3147
# geospatial_lat_max                                                    57.3147
# geospatial_lon_min                                                    20.0803
# geospatial_lon_max                                                    20.0803
# time_coverage_start                                      2021-01-12T00:51:00Z
# time_coverage_end                                        2021-01-12T00:51:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:28Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 PRES SVEL LGHT DOX1
# netcdf                                          BO_PR_CT_SMHIBY15_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY15
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             57.2938
# last_longitude_observation                                            19.9077
# last_date_observation                                    2021-02-07T01:11:06Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         3      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    57.2938
# geospatial_lat_max                                                    57.3345
# geospatial_lon_min                                                    19.9077
# geospatial_lon_max                                                    20.0873
# time_coverage_start                                      1978-11-22T00:20:00Z
# time_coverage_end                                        2020-12-11T05:21:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:11:06Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_SMHIBY15.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY15
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             57.2938
# last_longitude_observation                                            19.9077
# last_date_observation                                    2021-02-07T01:11:06Z
# timeOverlap                                                              True
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         4      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.8815
# geospatial_lat_max                                                    58.8815
# geospatial_lon_min                                                    20.3282
# geospatial_lon_max                                                    20.3282
# time_coverage_start                                      2021-01-12T12:11:00Z
# time_coverage_end                                        2021-01-12T12:11:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:28Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 PRES SVEL LGHT DOX1
# netcdf                                          BO_PR_CT_SMHIBY29_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY29
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.8748
# last_longitude_observation                                            20.3100
# last_date_observation                                    2021-02-07T01:12:08Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         5      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.8748
# geospatial_lat_max                                                    58.8855
# geospatial_lon_min                                                    20.3100
# geospatial_lon_max                                                    20.3358
# time_coverage_start                                      1978-11-21T08:20:00Z
# time_coverage_end                                        2020-12-10T17:55:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:12:08Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_SMHIBY29.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY29
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.8748
# last_longitude_observation                                            20.3100
# last_date_observation                                    2021-02-07T01:12:08Z
# timeOverlap                                                              True
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                         6      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.5937
# geospatial_lat_max                                                    58.5937
# geospatial_lon_min                                                    18.2363
# geospatial_lon_max                                                    18.2363
# time_coverage_start                                      2021-01-12T19:50:00Z
# time_coverage_end                                        2021-01-12T19:50:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:29Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 PRES SVEL LGHT DOX1
# netcdf                                          BO_PR_CT_SMHIBY31_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY31
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.5772
# last_longitude_observation                                            18.2263
# last_date_observation                                    2021-02-07T01:12:43Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         7      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.5772
# geospatial_lat_max                                                    58.6100
# geospatial_lon_min                                                    18.2263
# geospatial_lon_max                                                    18.2387
# time_coverage_start                                      1978-11-16T17:00:00Z
# time_coverage_end                                        2020-12-04T17:04:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:12:43Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_SMHIBY31.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY31
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.5772
# last_longitude_observation                                            18.2263
# last_date_observation                                    2021-02-07T01:12:43Z
# timeOverlap                                                              True
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         8      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3333
# geospatial_lat_max                                                    58.3333
# geospatial_lon_min                                                    11.8833
# geospatial_lon_max                                                    11.8833
# time_coverage_start                                      2021-01-12T12:45:00Z
# time_coverage_end                                        2021-01-12T12:45:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:29Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                     BO_PR_CT_SMHIBYFJORDEN_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                   SMHIBYFJORDEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3333
# last_longitude_observation                                            11.8833
# last_date_observation                                    2021-02-08T19:00:46Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         9      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3333
# geospatial_lat_max                                                    58.3333
# geospatial_lon_min                                                    11.8833
# geospatial_lon_max                                                    11.8833
# time_coverage_start                                      2021-02-02T12:33:00Z
# time_coverage_end                                        2021-02-02T12:33:00Z
# institution                                                              SMHI
# date_update                                              2021-02-08T19:00:46Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                     BO_PR_CT_SMHIBYFJORDEN_20210202.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                   SMHIBYFJORDEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3333
# last_longitude_observation                                            11.8833
# last_date_observation                                    2021-02-08T19:00:46Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
# timeOverlap                 ...
# spatialOverlap              ...
# lastLocationInRange         ...
#
#                                                                         22713  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     -35.16
# geospatial_lat_max                                                      54.02
# geospatial_lon_min                                                     -97.88
# geospatial_lon_max                                                       9.91
# time_coverage_start                                      2002-07-19T11:32:00Z
# time_coverage_end                                        2006-09-29T00:00:00Z
# institution                 IRD  Institut de recherche pour le developpeme...
# date_update                                              2020-03-06T06:27:04Z
# data_mode                                                                   M
# parameters                  POSITIONING_SYSTEM DC_REFERENCE DEPH DEPH_DM P...
# netcdf                                                      GL_TS_TS_ELWT7.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                           ELWT7
# wmo_platform_code                                                       ELWT7
# institution_edmo_code                                                     440
# last_latitude_observation                                              -35.16
# last_longitude_observation                                             -97.88
# last_date_observation                                    2020-03-06T06:27:04Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         22714  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     -34.55
# geospatial_lat_max                                                      67.54
# geospatial_lon_min                                                     -97.05
# geospatial_lon_max                                                      34.00
# time_coverage_start                                      1990-01-01T02:00:00Z
# time_coverage_end                                        1996-09-19T18:00:00Z
# institution                 IRD  Institut de recherche pour le developpeme...
# date_update                                              2019-05-09T18:14:33Z
# data_mode                                                                   R
# parameters                  POSITIONING_SYSTEM DC_REFERENCE DEPH DEPH_DM T...
# netcdf                                                   GL_TS_TS_IF000088.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                        IF000088
# wmo_platform_code
# institution_edmo_code                                                     440
# last_latitude_observation                                              -34.55
# last_longitude_observation                                             -97.05
# last_date_observation                                    2019-05-09T18:14:33Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                         22715  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                   -32.8500
# geospatial_lat_max                                                    60.1500
# geospatial_lon_min                                                  -169.9667
# geospatial_lon_max                                                   179.9167
# time_coverage_start                                      2008-09-25T15:00:00Z
# time_coverage_end                                        2012-11-09T14:00:00Z
# institution                                               Unknown institution
# date_update                                              2020-01-19T22:55:37Z
# data_mode                                                                   R
# parameters                  POSITIONING_SYSTEM DC_REFERENCE DEPH DEPH_DM T...
# netcdf                                                      GL_TS_TS_KS077.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                           KS077
# wmo_platform_code                                                       KS077
# institution_edmo_code
# last_latitude_observation                                            -32.8500
# last_longitude_observation                                          -169.9667
# last_date_observation                                    2020-01-19T22:55:37Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         22716  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                   -33.8667
# geospatial_lat_max                                                    53.7000
# geospatial_lon_min                                                  -179.8500
# geospatial_lon_max                                                   179.6667
# time_coverage_start                                      2009-08-01T12:00:00Z
# time_coverage_end                                        2011-09-08T18:00:00Z
# institution                                               Unknown institution
# date_update                                              2020-01-19T22:57:07Z
# data_mode                                                                   R
# parameters                  POSITIONING_SYSTEM DC_REFERENCE DEPH DEPH_DM T...
# netcdf                                                      GL_TS_TS_KS086.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                           KS086
# wmo_platform_code                                                       KS086
# institution_edmo_code
# last_latitude_observation                                            -33.8667
# last_longitude_observation                                          -179.8500
# last_date_observation                                    2020-01-19T22:57:07Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         22717  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                   -55.9500
# geospatial_lat_max                                                    69.4500
# geospatial_lon_min                                                   -91.5333
# geospatial_lon_max                                                    29.4000
# time_coverage_start                                      2009-05-19T18:00:00Z
# time_coverage_end                                        2012-12-11T15:00:00Z
# institution                                               Unknown institution
# date_update                                              2019-05-09T18:18:33Z
# data_mode                                                                   R
# parameters                  POSITIONING_SYSTEM DC_REFERENCE DEPH DEPH_DM T...
# netcdf                                                      GL_TS_TS_KS089.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                           KS089
# wmo_platform_code                                                       KS089
# institution_edmo_code
# last_latitude_observation                                            -55.9500
# last_longitude_observation                                           -91.5333
# last_date_observation                                    2019-05-09T18:18:33Z
# timeOverlap                                                             False
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                         22718  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                   -65.2167
# geospatial_lat_max                                                    60.4500
# geospatial_lon_min                                                  -151.7500
# geospatial_lon_max                                                    30.1167
# time_coverage_start                                      2010-11-01T18:00:00Z
# time_coverage_end                                        2012-03-21T02:00:00Z
# institution                                               Unknown institution
# date_update                                              2020-01-19T22:57:38Z
# data_mode                                                                   R
# parameters                  POSITIONING_SYSTEM DC_REFERENCE DEPH DEPH_DM T...
# netcdf                                                      GL_TS_TS_KS094.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                           KS094
# wmo_platform_code                                                       KS094
# institution_edmo_code
# last_latitude_observation                                            -65.2167
# last_longitude_observation                                          -151.7500
# last_date_observation                                    2020-01-19T22:57:38Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         22719  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                  -34.99083
# geospatial_lat_max                                                   54.04550
# geospatial_lon_min                                                  -18.08350
# geospatial_lon_max                                                   31.34933
# time_coverage_start                                      2005-11-13T23:59:00Z
# time_coverage_end                                        2011-07-24T01:00:00Z
# institution                                                  Panama (Unknown)
# date_update                                              2019-05-12T19:19:09Z
# data_mode                                                                   R
# parameters                  POSITIONING_SYSTEM DC_REFERENCE DEPH DEPH_DM S...
# netcdf                                                      GL_TS_TS_MGJS8.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                           MGJS8
# wmo_platform_code                                                       MGJS8
# institution_edmo_code
# last_latitude_observation                                           -34.99083
# last_longitude_observation                                          -18.08350
# last_date_observation                                    2019-05-17T11:39:31Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         22720  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    42.3315
# geospatial_lat_max                                                    68.6455
# geospatial_lon_min                                                   -70.2382
# geospatial_lon_max                                                    15.4035
# time_coverage_start                                      2014-03-16T01:15:52Z
# time_coverage_end                                        2016-03-01T14:07:45Z
# institution                 Atlantic Oceanographic and Meteorological Labo...
# date_update                                              2020-10-22T10:35:05Z
# data_mode                                                                   R
# parameters                  POSITIONING_SYSTEM DC_REFERENCE DEPH DEPH_DM S...
# netcdf                                                      GL_TS_TS_V2EF3.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                           V2EF3
# wmo_platform_code                                                       V2EF3
# institution_edmo_code                                                    1799
# last_latitude_observation                                             42.3315
# last_longitude_observation                                           -70.2382
# last_date_observation                                    2020-10-22T10:35:05Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         22721  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                   19.05950
# geospatial_lat_max                                                   53.99867
# geospatial_lon_min                                                 -123.20000
# geospatial_lon_max                                                   14.72950
# time_coverage_start                                      2002-05-21T03:16:12Z
# time_coverage_end                                        2013-10-07T15:29:43Z
# institution                                          United Kingdom (Unknown)
# date_update                                              2020-10-22T14:59:02Z
# data_mode                                                                   R
# parameters                  POSITIONING_SYSTEM DC_REFERENCE DEPH DEPH_DM S...
# netcdf                                                      GL_TS_TS_ZCDJ6.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                           ZCDJ6
# wmo_platform_code                                                       ZCDJ6
# institution_edmo_code
# last_latitude_observation                                            19.05950
# last_longitude_observation                                         -123.20000
# last_date_observation                                    2020-10-22T14:59:02Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         22735
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                   -21.7520
# geospatial_lat_max                                                    54.0800
# geospatial_lon_min                                                    14.1700
# geospatial_lon_max                                                   -16.1333
# time_coverage_start                                      2001-05-15T20:26:00Z
# time_coverage_end                                        2013-02-04T17:04:00Z
# institution                                           United states (Unknown)
# date_update                                              2021-01-25T00:39:38Z
# data_mode                                                                   R
# parameters                  DC_REFERENCE DIRECTION DEPH PRES TEMP PSAL HCD...
# netcdf                                                     GL_PR_XX_NOCALL.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                          NOCALL
# wmo_platform_code                                                      NOCALL
# institution_edmo_code
# last_latitude_observation                                            -21.7520
# last_longitude_observation                                            14.1700
# last_date_observation                                    2021-01-25T00:39:38Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
# [24 rows x 3885 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the subset only contains the aimed parameter (targeted_parameter) just check the `parameters` column of the above output.

# %% [markdown]
# #### 4.1.8. By platform code

# %% [markdown]
# Let's look for files produced by a certain platform.<br>`Please set a platform code` next `and run the cell`:

# %%
targeted_platform_code = 'Eisma'

# %% [markdown]
# Run the next cell to obtain just the files reported by such platform:

# %%
condition = info['platform_code']==targeted_platform_code
subset = info[condition]
subset.transpose()
# Out:
#                                                                          5563  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     59.568
# geospatial_lat_max                                                     59.568
# geospatial_lon_min                                                     26.305
# geospatial_lon_max                                                     26.305
# time_coverage_start                                      2021-01-12T00:00:00Z
# time_coverage_end                                        2021-01-12T23:00:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T01:05:01Z
# data_mode                                                                   R
# parameters                                                     TEMP SLEV DEPH
# netcdf                                             BO_TS_TG_Eisma_20210112.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                           Eisma
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                              59.568
# last_longitude_observation                                             26.305
# last_date_observation                                    2021-02-12T01:01:04Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          5564  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     59.568
# geospatial_lat_max                                                     59.568
# geospatial_lon_min                                                     26.305
# geospatial_lon_max                                                     26.305
# time_coverage_start                                      2021-01-13T00:00:00Z
# time_coverage_end                                        2021-01-13T23:00:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T01:05:01Z
# data_mode                                                                   R
# parameters                                                     TEMP SLEV DEPH
# netcdf                                             BO_TS_TG_Eisma_20210113.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                           Eisma
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                              59.568
# last_longitude_observation                                             26.305
# last_date_observation                                    2021-02-12T01:01:04Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          5565  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     59.568
# geospatial_lat_max                                                     59.568
# geospatial_lon_min                                                     26.305
# geospatial_lon_max                                                     26.305
# time_coverage_start                                      2021-01-14T00:00:00Z
# time_coverage_end                                        2021-01-14T23:00:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T01:05:01Z
# data_mode                                                                   R
# parameters                                                     TEMP SLEV DEPH
# netcdf                                             BO_TS_TG_Eisma_20210114.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                           Eisma
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                              59.568
# last_longitude_observation                                             26.305
# last_date_observation                                    2021-02-12T01:01:04Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          5566  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     59.568
# geospatial_lat_max                                                     59.568
# geospatial_lon_min                                                     26.305
# geospatial_lon_max                                                     26.305
# time_coverage_start                                      2021-01-15T00:00:00Z
# time_coverage_end                                        2021-01-15T23:00:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T01:05:01Z
# data_mode                                                                   R
# parameters                                                     TEMP SLEV DEPH
# netcdf                                             BO_TS_TG_Eisma_20210115.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                           Eisma
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                              59.568
# last_longitude_observation                                             26.305
# last_date_observation                                    2021-02-12T01:01:04Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          5567  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     59.568
# geospatial_lat_max                                                     59.568
# geospatial_lon_min                                                     26.305
# geospatial_lon_max                                                     26.305
# time_coverage_start                                      2021-01-16T00:00:00Z
# time_coverage_end                                        2021-01-16T23:00:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T01:05:01Z
# data_mode                                                                   R
# parameters                                                     TEMP SLEV DEPH
# netcdf                                             BO_TS_TG_Eisma_20210116.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                           Eisma
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                              59.568
# last_longitude_observation                                             26.305
# last_date_observation                                    2021-02-12T01:01:04Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          5568  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     59.568
# geospatial_lat_max                                                     59.568
# geospatial_lon_min                                                     26.305
# geospatial_lon_max                                                     26.305
# time_coverage_start                                      2021-01-17T00:00:00Z
# time_coverage_end                                        2021-01-17T23:00:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T01:05:02Z
# data_mode                                                                   R
# parameters                                                     TEMP SLEV DEPH
# netcdf                                             BO_TS_TG_Eisma_20210117.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                           Eisma
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                              59.568
# last_longitude_observation                                             26.305
# last_date_observation                                    2021-02-12T01:01:04Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          5569  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     59.568
# geospatial_lat_max                                                     59.568
# geospatial_lon_min                                                     26.305
# geospatial_lon_max                                                     26.305
# time_coverage_start                                      2021-01-18T00:00:00Z
# time_coverage_end                                        2021-01-18T23:00:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T01:05:02Z
# data_mode                                                                   R
# parameters                                                     TEMP SLEV DEPH
# netcdf                                             BO_TS_TG_Eisma_20210118.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                           Eisma
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                              59.568
# last_longitude_observation                                             26.305
# last_date_observation                                    2021-02-12T01:01:04Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          5570  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     59.568
# geospatial_lat_max                                                     59.568
# geospatial_lon_min                                                     26.305
# geospatial_lon_max                                                     26.305
# time_coverage_start                                      2021-01-19T00:00:00Z
# time_coverage_end                                        2021-01-19T23:00:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T01:05:02Z
# data_mode                                                                   R
# parameters                                                     TEMP SLEV DEPH
# netcdf                                             BO_TS_TG_Eisma_20210119.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                           Eisma
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                              59.568
# last_longitude_observation                                             26.305
# last_date_observation                                    2021-02-12T01:01:04Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          5571  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     59.568
# geospatial_lat_max                                                     59.568
# geospatial_lon_min                                                     26.305
# geospatial_lon_max                                                     26.305
# time_coverage_start                                      2021-01-20T00:00:00Z
# time_coverage_end                                        2021-01-20T23:00:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T01:05:02Z
# data_mode                                                                   R
# parameters                                                     TEMP SLEV DEPH
# netcdf                                             BO_TS_TG_Eisma_20210120.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                           Eisma
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                              59.568
# last_longitude_observation                                             26.305
# last_date_observation                                    2021-02-12T01:01:04Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          5572  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     59.568
# geospatial_lat_max                                                     59.568
# geospatial_lon_min                                                     26.305
# geospatial_lon_max                                                     26.305
# time_coverage_start                                      2021-01-21T00:00:00Z
# time_coverage_end                                        2021-01-21T23:00:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T01:05:02Z
# data_mode                                                                   R
# parameters                                                     TEMP SLEV DEPH
# netcdf                                             BO_TS_TG_Eisma_20210121.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                           Eisma
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                              59.568
# last_longitude_observation                                             26.305
# last_date_observation                                    2021-02-12T01:01:04Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
# timeOverlap                 ...
# spatialOverlap              ...
# lastLocationInRange         ...
#
#                                                                          5625  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     59.568
# geospatial_lat_max                                                     59.568
# geospatial_lon_min                                                     26.305
# geospatial_lon_max                                                     26.305
# time_coverage_start                                      2019-09-01T00:00:00Z
# time_coverage_end                                        2019-09-30T23:00:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T02:06:00Z
# data_mode                                                                   R
# parameters                                                     SLEV DEPH TEMP
# netcdf                                               BO_TS_TG_Eisma_201909.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                           Eisma
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                              59.568
# last_longitude_observation                                             26.305
# last_date_observation                                    2021-02-12T01:01:04Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          5626  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     59.568
# geospatial_lat_max                                                     59.568
# geospatial_lon_min                                                     26.305
# geospatial_lon_max                                                     26.305
# time_coverage_start                                      2019-10-01T00:00:00Z
# time_coverage_end                                        2019-10-31T23:00:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T02:09:36Z
# data_mode                                                                   R
# parameters                                                     SLEV DEPH TEMP
# netcdf                                               BO_TS_TG_Eisma_201910.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                           Eisma
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                              59.568
# last_longitude_observation                                             26.305
# last_date_observation                                    2021-02-12T01:01:04Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          5627  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     59.568
# geospatial_lat_max                                                     59.568
# geospatial_lon_min                                                     26.305
# geospatial_lon_max                                                     26.305
# time_coverage_start                                      2019-11-01T00:00:00Z
# time_coverage_end                                        2019-11-30T23:00:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T02:11:59Z
# data_mode                                                                   R
# parameters                                                     SLEV DEPH TEMP
# netcdf                                               BO_TS_TG_Eisma_201911.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                           Eisma
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                              59.568
# last_longitude_observation                                             26.305
# last_date_observation                                    2021-02-12T01:01:04Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          5628  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     59.568
# geospatial_lat_max                                                     59.568
# geospatial_lon_min                                                     26.305
# geospatial_lon_max                                                     26.305
# time_coverage_start                                      2019-12-01T00:00:00Z
# time_coverage_end                                        2019-12-31T23:00:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T02:13:11Z
# data_mode                                                                   R
# parameters                                                     SLEV DEPH TEMP
# netcdf                                               BO_TS_TG_Eisma_201912.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                           Eisma
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                              59.568
# last_longitude_observation                                             26.305
# last_date_observation                                    2021-02-12T01:01:04Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          5629  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     59.568
# geospatial_lat_max                                                     59.568
# geospatial_lon_min                                                     26.305
# geospatial_lon_max                                                     26.305
# time_coverage_start                                      2020-09-08T12:00:00Z
# time_coverage_end                                        2020-09-30T23:00:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T02:04:50Z
# data_mode                                                                   R
# parameters                                                     SLEV DEPH TEMP
# netcdf                                               BO_TS_TG_Eisma_202009.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                           Eisma
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                              59.568
# last_longitude_observation                                             26.305
# last_date_observation                                    2021-02-12T01:01:04Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          5630  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     59.568
# geospatial_lat_max                                                     59.568
# geospatial_lon_min                                                     26.305
# geospatial_lon_max                                                     26.305
# time_coverage_start                                      2020-10-01T00:00:00Z
# time_coverage_end                                        2020-10-31T23:00:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T02:07:47Z
# data_mode                                                                   R
# parameters                                                     SLEV DEPH TEMP
# netcdf                                               BO_TS_TG_Eisma_202010.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                           Eisma
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                              59.568
# last_longitude_observation                                             26.305
# last_date_observation                                    2021-02-12T01:01:04Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          5631  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     59.568
# geospatial_lat_max                                                     59.568
# geospatial_lon_min                                                     26.305
# geospatial_lon_max                                                     26.305
# time_coverage_start                                      2020-11-01T00:00:00Z
# time_coverage_end                                        2020-11-30T23:00:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T02:09:08Z
# data_mode                                                                   R
# parameters                                                     SLEV DEPH TEMP
# netcdf                                               BO_TS_TG_Eisma_202011.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                           Eisma
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                              59.568
# last_longitude_observation                                             26.305
# last_date_observation                                    2021-02-12T01:01:04Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          5632  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     59.568
# geospatial_lat_max                                                     59.568
# geospatial_lon_min                                                     26.305
# geospatial_lon_max                                                     26.305
# time_coverage_start                                      2020-12-01T00:00:00Z
# time_coverage_end                                        2020-12-31T23:00:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T02:14:23Z
# data_mode                                                                   R
# parameters                                                     SLEV DEPH TEMP
# netcdf                                               BO_TS_TG_Eisma_202012.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                           Eisma
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                              59.568
# last_longitude_observation                                             26.305
# last_date_observation                                    2021-02-12T01:01:04Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          5633  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     59.568
# geospatial_lat_max                                                     59.568
# geospatial_lon_min                                                     26.305
# geospatial_lon_max                                                     26.305
# time_coverage_start                                      2021-01-01T00:00:00Z
# time_coverage_end                                        2021-01-31T23:00:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T02:15:36Z
# data_mode                                                                   R
# parameters                                                     SLEV DEPH TEMP
# netcdf                                               BO_TS_TG_Eisma_202101.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                           Eisma
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                              59.568
# last_longitude_observation                                             26.305
# last_date_observation                                    2021-02-12T01:01:04Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
#                                                                          5634
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     59.568
# geospatial_lat_max                                                     59.568
# geospatial_lon_min                                                     26.305
# geospatial_lon_max                                                     26.305
# time_coverage_start                                      2017-02-07T00:00:00Z
# time_coverage_end                                        2020-12-17T07:00:00Z
# institution                                                               MSI
# date_update                                              2021-02-07T02:26:53Z
# data_mode                                                                   R
# parameters                                                     SLEV DEPH TEMP
# netcdf                                                      BO_TS_TG_Eisma.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                           Eisma
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     713
# last_latitude_observation                                              59.568
# last_longitude_observation                                             26.305
# last_date_observation                                    2021-02-12T01:01:04Z
# timeOverlap                                                              True
# spatialOverlap                                                          False
# lastLocationInRange                                                      True
#
# [24 rows x 72 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the subset matches the aimed platform (targeted_platform_code) just check the `platform_code` column of the above output.

# %% [markdown]
# #### 4.1.9. By provider

# %% [markdown]
# Let's look for files produced by a certain provider.<br>`Please set a provider code` next `and run the cell`:

# %%
targeted_provider_code = '1850'

# %% [markdown]
# Run the next cell to obtain just the files reported by such platform:

# %%
info['institution_edmo_code'] = ' '+info['institution_edmo_code']+' '

# %%
condition = info['institution_edmo_code'].str.contains(targeted_provider_code, na=False)
subset = info[condition]
subset.transpose()
# Out:
#                                                                         2274   \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    54.8833
# geospatial_lat_max                                                    54.8833
# geospatial_lon_min                                                    13.8667
# geospatial_lon_max                                                    13.8667
# time_coverage_start                                      2021-01-12T00:00:00Z
# time_coverage_end                                        2021-01-12T23:00:00Z
# institution                                                               BSH
# date_update                                              2021-02-07T01:03:02Z
# data_mode                                                                   R
# parameters                       PSAL TEMP RELH WDIR OSAT WSPD DEPH DRYT ATMP
# netcdf                                            BO_TS_MO_Arkona_20210112.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                          Arkona
# wmo_platform_code                                                       66021
# institution_edmo_code                                                   1850
# last_latitude_observation                                             54.8833
# last_longitude_observation                                            13.8667
# last_date_observation                                    2021-02-12T01:00:56Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         2275   \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    54.8833
# geospatial_lat_max                                                    54.8833
# geospatial_lon_min                                                    13.8667
# geospatial_lon_max                                                    13.8667
# time_coverage_start                                      2021-01-13T00:00:00Z
# time_coverage_end                                        2021-01-13T02:00:00Z
# institution                                                               BSH
# date_update                                              2021-02-07T01:03:02Z
# data_mode                                                                   R
# parameters                       PSAL TEMP RELH WDIR OSAT WSPD DEPH DRYT ATMP
# netcdf                                            BO_TS_MO_Arkona_20210113.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                          Arkona
# wmo_platform_code                                                       66021
# institution_edmo_code                                                   1850
# last_latitude_observation                                             54.8833
# last_longitude_observation                                            13.8667
# last_date_observation                                    2021-02-12T01:00:56Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         2276   \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    54.8833
# geospatial_lat_max                                                    54.8833
# geospatial_lon_min                                                    13.8667
# geospatial_lon_max                                                    13.8667
# time_coverage_start                                      2021-01-17T00:00:00Z
# time_coverage_end                                        2021-01-17T23:00:00Z
# institution                                                               BSH
# date_update                                              2021-02-07T01:03:02Z
# data_mode                                                                   R
# parameters                       PSAL TEMP RELH WDIR OSAT WSPD DEPH DRYT ATMP
# netcdf                                            BO_TS_MO_Arkona_20210117.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                          Arkona
# wmo_platform_code                                                       66021
# institution_edmo_code                                                   1850
# last_latitude_observation                                             54.8833
# last_longitude_observation                                            13.8667
# last_date_observation                                    2021-02-12T01:00:56Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         2277   \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    54.8833
# geospatial_lat_max                                                    54.8833
# geospatial_lon_min                                                    13.8667
# geospatial_lon_max                                                    13.8667
# time_coverage_start                                      2021-01-18T00:00:00Z
# time_coverage_end                                        2021-01-18T23:00:00Z
# institution                                                               BSH
# date_update                                              2021-02-07T01:03:02Z
# data_mode                                                                   R
# parameters                       PSAL TEMP RELH WDIR OSAT WSPD DEPH DRYT ATMP
# netcdf                                            BO_TS_MO_Arkona_20210118.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                          Arkona
# wmo_platform_code                                                       66021
# institution_edmo_code                                                   1850
# last_latitude_observation                                             54.8833
# last_longitude_observation                                            13.8667
# last_date_observation                                    2021-02-12T01:00:56Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         2278   \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    54.8833
# geospatial_lat_max                                                    54.8833
# geospatial_lon_min                                                    13.8667
# geospatial_lon_max                                                    13.8667
# time_coverage_start                                      2021-01-19T00:00:00Z
# time_coverage_end                                        2021-01-19T23:00:00Z
# institution                                                               BSH
# date_update                                              2021-02-07T01:03:02Z
# data_mode                                                                   R
# parameters                       PSAL TEMP RELH WDIR OSAT WSPD DEPH DRYT ATMP
# netcdf                                            BO_TS_MO_Arkona_20210119.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                          Arkona
# wmo_platform_code                                                       66021
# institution_edmo_code                                                   1850
# last_latitude_observation                                             54.8833
# last_longitude_observation                                            13.8667
# last_date_observation                                    2021-02-12T01:00:56Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         2279   \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    54.8833
# geospatial_lat_max                                                    54.8833
# geospatial_lon_min                                                    13.8667
# geospatial_lon_max                                                    13.8667
# time_coverage_start                                      2021-01-20T00:00:00Z
# time_coverage_end                                        2021-01-20T23:00:00Z
# institution                                                               BSH
# date_update                                              2021-02-07T01:03:02Z
# data_mode                                                                   R
# parameters                       PSAL TEMP RELH WDIR OSAT WSPD DEPH DRYT ATMP
# netcdf                                            BO_TS_MO_Arkona_20210120.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                          Arkona
# wmo_platform_code                                                       66021
# institution_edmo_code                                                   1850
# last_latitude_observation                                             54.8833
# last_longitude_observation                                            13.8667
# last_date_observation                                    2021-02-12T01:00:56Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         2280   \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    54.8833
# geospatial_lat_max                                                    54.8833
# geospatial_lon_min                                                    13.8667
# geospatial_lon_max                                                    13.8667
# time_coverage_start                                      2021-01-21T00:00:00Z
# time_coverage_end                                        2021-01-21T23:00:00Z
# institution                                                               BSH
# date_update                                              2021-02-07T01:03:02Z
# data_mode                                                                   R
# parameters                       PSAL TEMP RELH WDIR OSAT WSPD DEPH DRYT ATMP
# netcdf                                            BO_TS_MO_Arkona_20210121.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                          Arkona
# wmo_platform_code                                                       66021
# institution_edmo_code                                                   1850
# last_latitude_observation                                             54.8833
# last_longitude_observation                                            13.8667
# last_date_observation                                    2021-02-12T01:00:56Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         2281   \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    54.8833
# geospatial_lat_max                                                    54.8833
# geospatial_lon_min                                                    13.8667
# geospatial_lon_max                                                    13.8667
# time_coverage_start                                      2021-01-22T00:00:00Z
# time_coverage_end                                        2021-01-22T23:00:00Z
# institution                                                               BSH
# date_update                                              2021-02-07T01:03:03Z
# data_mode                                                                   R
# parameters                       PSAL TEMP RELH WDIR OSAT WSPD DEPH DRYT ATMP
# netcdf                                            BO_TS_MO_Arkona_20210122.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                          Arkona
# wmo_platform_code                                                       66021
# institution_edmo_code                                                   1850
# last_latitude_observation                                             54.8833
# last_longitude_observation                                            13.8667
# last_date_observation                                    2021-02-12T01:00:56Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         2282   \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    54.8833
# geospatial_lat_max                                                    54.8833
# geospatial_lon_min                                                    13.8667
# geospatial_lon_max                                                    13.8667
# time_coverage_start                                      2021-01-23T00:00:00Z
# time_coverage_end                                        2021-01-23T23:00:00Z
# institution                                                               BSH
# date_update                                              2021-02-07T01:03:03Z
# data_mode                                                                   R
# parameters                       PSAL TEMP RELH WDIR OSAT WSPD DEPH DRYT ATMP
# netcdf                                            BO_TS_MO_Arkona_20210123.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                          Arkona
# wmo_platform_code                                                       66021
# institution_edmo_code                                                   1850
# last_latitude_observation                                             54.8833
# last_longitude_observation                                            13.8667
# last_date_observation                                    2021-02-12T01:00:56Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         2283   \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    54.8833
# geospatial_lat_max                                                    54.8833
# geospatial_lon_min                                                    13.8667
# geospatial_lon_max                                                    13.8667
# time_coverage_start                                      2021-01-24T00:00:00Z
# time_coverage_end                                        2021-01-24T23:00:00Z
# institution                                                               BSH
# date_update                                              2021-02-07T01:03:03Z
# data_mode                                                                   R
# parameters                       PSAL TEMP RELH WDIR OSAT WSPD DEPH DRYT ATMP
# netcdf                                            BO_TS_MO_Arkona_20210124.nc
# file_type                                                                  TS
# data_type                                                                  MO
# platform_code                                                          Arkona
# wmo_platform_code                                                       66021
# institution_edmo_code                                                   1850
# last_latitude_observation                                             54.8833
# last_longitude_observation                                            13.8667
# last_date_observation                                    2021-02-12T01:00:56Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
# timeOverlap                 ...
# spatialOverlap              ...
# lastLocationInRange         ...
#
#                                                                         20740  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    54.5003
# geospatial_lat_max                                                    54.5003
# geospatial_lon_min                                                    10.2750
# geospatial_lon_max                                                    10.2750
# time_coverage_start                                      2020-08-01T00:00:00Z
# time_coverage_end                                        2020-08-31T23:45:00Z
# institution                                                               BSH
# date_update                                              2021-02-07T02:02:39Z
# data_mode                                                                   R
# parameters                                                          SLEV DEPH
# netcdf                                              BO_TS_TG_KielTG_202008.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                          KielTG
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                   1850
# last_latitude_observation                                             54.5003
# last_longitude_observation                                            10.2750
# last_date_observation                                    2021-02-07T03:15:20Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         20741  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    54.5003
# geospatial_lat_max                                                    54.5003
# geospatial_lon_min                                                    10.2750
# geospatial_lon_max                                                    10.2750
# time_coverage_start                                      2020-09-01T00:00:00Z
# time_coverage_end                                        2020-09-30T23:45:00Z
# institution                                                               BSH
# date_update                                              2021-02-07T02:05:19Z
# data_mode                                                                   R
# parameters                                                          SLEV DEPH
# netcdf                                              BO_TS_TG_KielTG_202009.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                          KielTG
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                   1850
# last_latitude_observation                                             54.5003
# last_longitude_observation                                            10.2750
# last_date_observation                                    2021-02-07T03:15:20Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         20742  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    54.5003
# geospatial_lat_max                                                    54.5003
# geospatial_lon_min                                                    10.2750
# geospatial_lon_max                                                    10.2750
# time_coverage_start                                      2020-10-01T00:00:00Z
# time_coverage_end                                        2020-10-31T23:45:00Z
# institution                                                               BSH
# date_update                                              2021-02-07T02:08:23Z
# data_mode                                                                   R
# parameters                                                          SLEV DEPH
# netcdf                                              BO_TS_TG_KielTG_202010.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                          KielTG
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                   1850
# last_latitude_observation                                             54.5003
# last_longitude_observation                                            10.2750
# last_date_observation                                    2021-02-07T03:15:20Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         20743  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    54.5003
# geospatial_lat_max                                                    54.5003
# geospatial_lon_min                                                    10.2750
# geospatial_lon_max                                                    10.2750
# time_coverage_start                                      2020-11-01T00:00:00Z
# time_coverage_end                                        2020-11-30T23:45:00Z
# institution                                                               BSH
# date_update                                              2021-02-07T02:10:25Z
# data_mode                                                                   R
# parameters                                                          SLEV DEPH
# netcdf                                              BO_TS_TG_KielTG_202011.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                          KielTG
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                   1850
# last_latitude_observation                                             54.5003
# last_longitude_observation                                            10.2750
# last_date_observation                                    2021-02-07T03:15:20Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         20744  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    54.5003
# geospatial_lat_max                                                    54.5003
# geospatial_lon_min                                                    10.2750
# geospatial_lon_max                                                    10.2750
# time_coverage_start                                      2020-12-01T00:00:00Z
# time_coverage_end                                        2020-12-31T23:45:00Z
# institution                                                               BSH
# date_update                                              2021-02-07T02:14:54Z
# data_mode                                                                   R
# parameters                                                          SLEV DEPH
# netcdf                                              BO_TS_TG_KielTG_202012.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                          KielTG
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                   1850
# last_latitude_observation                                             54.5003
# last_longitude_observation                                            10.2750
# last_date_observation                                    2021-02-07T03:15:20Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         20745  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    54.5003
# geospatial_lat_max                                                    54.5003
# geospatial_lon_min                                                    10.2750
# geospatial_lon_max                                                    10.2750
# time_coverage_start                                      2021-01-01T00:00:00Z
# time_coverage_end                                        2021-01-08T07:30:00Z
# institution                                                               BSH
# date_update                                              2021-02-07T02:16:07Z
# data_mode                                                                   R
# parameters                                                          SLEV DEPH
# netcdf                                              BO_TS_TG_KielTG_202101.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                          KielTG
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                   1850
# last_latitude_observation                                             54.5003
# last_longitude_observation                                            10.2750
# last_date_observation                                    2021-02-07T03:15:20Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         20746  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    54.5003
# geospatial_lat_max                                                    54.5003
# geospatial_lon_min                                                    10.2750
# geospatial_lon_max                                                    10.2750
# time_coverage_start                                      2011-01-27T17:00:00Z
# time_coverage_end                                        2020-12-14T09:30:00Z
# institution                                                               BSH
# date_update                                              2021-02-07T03:15:20Z
# data_mode                                                                   R
# parameters                                                          SLEV DEPH
# netcdf                                                     BO_TS_TG_KielTG.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                          KielTG
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                   1850
# last_latitude_observation                                             54.5003
# last_longitude_observation                                            10.2750
# last_date_observation                                    2021-02-07T03:15:20Z
# timeOverlap                                                              True
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         21315  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    54.6958
# geospatial_lat_max                                                    54.6958
# geospatial_lon_min                                                    12.7057
# geospatial_lon_max                                                    12.7057
# time_coverage_start                                      2001-03-23T16:59:00Z
# time_coverage_end                                        2012-11-03T17:57:00Z
# institution                                                               BSH
# date_update                                              2021-02-07T01:00:58Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 PRES SVEL LGHT DOX1
# netcdf                                                BO_PR_CT_BSHDarsserS.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                     BSHDarsserS
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                   1850
# last_latitude_observation                                             54.6958
# last_longitude_observation                                            12.7057
# last_date_observation                                    2021-02-07T01:00:58Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         22701  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    54.5575
# geospatial_lat_max                                                    54.5575
# geospatial_lon_min                                                    13.2450
# geospatial_lon_max                                                    13.2450
# time_coverage_start                                      2011-01-27T17:00:00Z
# time_coverage_end                                        2012-08-27T16:00:00Z
# institution                                                               BSH
# date_update                                              2021-02-07T04:33:15Z
# data_mode                                                                   R
# parameters                                                          SLEV DEPH
# netcdf                                              BO_TS_TG_WittowerFahre.nc
# file_type                                                                  TS
# data_type                                                                  TG
# platform_code                                                   WittowerFahre
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                   1850
# last_latitude_observation                                             54.5575
# last_longitude_observation                                            13.2450
# last_date_observation                                    2021-02-07T04:33:15Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
#                                                                         22734
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                       54.7
# geospatial_lat_max                                                       54.7
# geospatial_lon_min                                                       12.7
# geospatial_lon_max                                                       12.7
# time_coverage_start                                      2001-01-17T18:00:00Z
# time_coverage_end                                        2014-04-20T18:00:00Z
# institution                 Bundesamt fur Seeschifffahrt und Hydrographie ...
# date_update                                              2019-09-28T15:42:33Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION DEPH TEMP
# netcdf                                          GL_PR_XX_MeasPileDarssSill.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                               MeasPileDarssSill
# wmo_platform_code                                                       66024
# institution_edmo_code                                                   1850
# last_latitude_observation                                                54.7
# last_longitude_observation                                               12.7
# last_date_observation                                    2019-09-28T15:42:33Z
# timeOverlap                                                             False
# spatialOverlap                                                          False
# lastLocationInRange                                                     False
#
# [24 rows x 3913 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the subset matches the aimed provider (targeted_provider_code) just check the `insitution_edmo_code` column of the above output.

# %% [markdown]
# #### 4.1.10. Subsetting by several criterias at once

# %% [markdown]
# Set the collection of interest, range of time and bbox to find only the files that matches:

# %%
targeted_collection = 'history'
targeted_range = '2019-01-01T00:00:00Z/2019-12-01T23:59:59Z'
targeted_parameter = 'PSAL'
targeted_data_type = 'TS'
targeted_geospatial_lat_min = 50.0  # enter min latitude of your bounding box
targeted_geospatial_lat_max = 65.0  # enter max latitude of your bounding box
targeted_geospatial_lon_min = 15.0  # enter min longitude of your bounding box
targeted_geospatial_lon_max = 28.0  # enter max longitude of your bounding box
targeted_bbox = [targeted_geospatial_lon_min, targeted_geospatial_lat_min, targeted_geospatial_lon_max, targeted_geospatial_lat_max]  # (minx, miny, maxx, maxy)

# %% [markdown]
# Run the next cell to apply yhe above filters:

# %%
info['timeOverlap'] = info.apply(timeOverlap,targeted_range=targeted_range,axis=1)
condition1 = info['timeOverlap'] == True
info['spatialOverlap'] = info.apply(spatialOverlap,targeted_bbox=targeted_bbox,axis=1)
condition2 = info['spatialOverlap'] == True

condition3 = info['data_type'] == targeted_data_type
condition4 = info['file_name'].str.contains(targeted_collection)
condition5 = info['parameters'].str.contains(targeted_parameter)

subset = info[condition1 & condition2 & condition3 & condition4 & condition5]
subset.transpose()
# Out:
#                                                                         18148  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    -8.8000
# geospatial_lat_max                                                    57.8167
# geospatial_lon_min                                                   -19.1667
# geospatial_lon_max                                                    19.0333
# time_coverage_start                                      2017-10-26T09:56:00Z
# time_coverage_end                                        2020-12-30T12:56:00Z
# institution                                               Unknown institution
# date_update                                              2021-01-06T11:47:43Z
# data_mode                                                                   R
# parameters                                        DC_REFERENCE DEPH PSAL SSJT
# netcdf                                                      GL_TS_TS_A8RH6.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                           A8RH6
# wmo_platform_code                                                       A8RH6
# institution_edmo_code
# last_latitude_observation                                             53.6333
# last_longitude_observation                                             7.8000
# last_date_observation                                    2021-02-05T14:23:53Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                         18653  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    4.08550
# geospatial_lat_max                                                   60.21133
# geospatial_lon_min                                                  -80.12000
# geospatial_lon_max                                                   30.22234
# time_coverage_start                                      2002-04-13T05:00:00Z
# time_coverage_end                                        2020-11-25T05:57:00Z
# institution                 IRD  Institut de recherche pour le developpeme...
# date_update                                              2021-01-06T12:57:03Z
# data_mode                                                                   M
# parameters                  DC_REFERENCE DEPH DEPH_DM PSAL PSAL_DM PSAL_AD...
# netcdf                                                       GL_TS_TS_FNAV.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                            FNAV
# wmo_platform_code                                                        FNAV
# institution_edmo_code                                                    440
# last_latitude_observation                                            16.58330
# last_longitude_observation                                          -40.15000
# last_date_observation                                    2021-01-08T12:36:08Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                         21029  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    4.84833
# geospatial_lat_max                                                   71.74900
# geospatial_lon_min                                                  -80.12000
# geospatial_lon_max                                                   30.22484
# time_coverage_start                                      2001-12-21T22:48:00Z
# time_coverage_end                                        2020-12-06T06:06:00Z
# institution                 IRD  Institut de recherche pour le developpeme...
# date_update                                              2021-01-06T14:34:40Z
# data_mode                                                                   M
# parameters                  DC_REFERENCE DEPH DEPH_DM PSAL PSAL_DM PSAL_AD...
# netcdf                                                       GL_TS_TS_FNHO.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                            FNHO
# wmo_platform_code                                                        FNHO
# institution_edmo_code                                                    440
# last_latitude_observation                                             4.84833
# last_longitude_observation                                          -80.12000
# last_date_observation                                    2021-01-06T14:34:40Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False
#
#                                                                         21032
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                   -50.6833
# geospatial_lat_max                                                    63.8000
# geospatial_lon_min                                                  -176.5500
# geospatial_lon_max                                                   170.6500
# time_coverage_start                                      2006-05-11T00:00:00Z
# time_coverage_end                                        2020-07-31T20:15:00Z
# institution                                               Unknown institution
# date_update                                              2020-08-07T02:25:55Z
# data_mode                                                                   R
# parameters                  POSITIONING_SYSTEM DC_REFERENCE DEPH DEPH_DM T...
# netcdf                                                       GL_TS_TS_SHIP.nc
# file_type                                                                  TS
# data_type                                                                  TS
# platform_code                                                            SHIP
# wmo_platform_code                                                        SHIP
# institution_edmo_code
# last_latitude_observation                                            -64.7833
# last_longitude_observation                                             0.0100
# last_date_observation                                    2021-01-25T01:20:02Z
# timeOverlap                                                              True
# spatialOverlap                                                           True
# lastLocationInRange                                                     False

# %% [markdown]
# ### 4.2. Exporting

# %% [markdown]
# If you just want to export the above table containing ftp link to download each file in subset and some more metadata as excel for sharing it (a lot more compact than sharing the actual files), just run the next cell:

# %%
subset.to_csv('subsetOffiles.csv')

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# Find [here](https://github.com/CopernicusMarineInsitu/downloadFilesFromCSV) and example about how to read and download the content of the files listed in the 'subsetOffiles.csv'.<br>**Remember**!: change the column_name to 'file_name'

# %% [markdown]
# ### 4.3. Downloading

# %% [markdown]
# After you have created your own subset (see above examples about how-to), we will loop over the files in such subset and download each of them from the FTP server thanks to the `file_name` column, field that contains the ftp link to the file.<br> Run the next cells:

# %%
output_directory = os.getcwd()# Defaults to the current working directory; change it as you please

# %%
treshold = 10 #Please set a file number maxima to download. 
#This is just an example and we do not wanna trigger the download of too many files!

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# If wanna download the whole subset and not just a sample, set `treshold = float('inf')`

# %%
with ftputil.FTPHost(dataset['host'], usr, pas) as ftp_host:  # connect to CMEMS FTP
    for i in range(0, len(subset)):
        if i<treshold:
            filepath = subset.iloc[i]['file_name'].split(dataset['host'])[1]
            ncdf_file_name = filepath.split('/')[-1]
            if ftp_host.path.isfile(filepath):
                print('.....Downloading ' + ncdf_file_name)
                cwd = os.getcwd()
                os.chdir(output_directory)
                try:
                    ftp_host.download(filepath, ncdf_file_name)  # remote, local
                    print('Done!')
                except Exception as e:
                    print('error!: FTP download failed ...')
                os.chdir(cwd)
# Out:
# .....Downloading GL_TS_TS_A8RH6.nc
# Done!
# .....Downloading GL_TS_TS_FNAV.nc
# Done!
# .....Downloading GL_TS_TS_FNHO.nc
# Done!
# .....Downloading GL_TS_TS_SHIP.nc
# Done!

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To check if the files have been donwloaded just check if you find them in the directory specified as <i>output directory</i>.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# FTP download might be forbidden in the remote server for security reasons. <br>If you experience an error please run this jupyter notebook locally for being able to actually download the files. Steps:
# 1. [Install anaconda](https://www.anaconda.com/distribution/): according to your OS (Windows,Linux,Mac...)
# 2. Navigate to the folder containing the notebooks (.ipynb files)
# 3. Run the following command at the Terminal (Mac/Linux) or Command Prompt (Windows): jupyter notebook

# %% [markdown]
# ---
#
# # 5. Wrap-up
#
# So far you should already know how to subset the product/dataset by several subsetting criterias as well as exporting and downloading the resulting subset of files.<br> `If you don't please ask us! it is the moment!`
# <br>In the next tutorial we will see how to open and visualize some of the files donloaded. Ready? Let's go!

# %% [markdown]
# ---
#
# # 6. Next Tutorial
#
# _Click on one of the hyperlinks below to continue the training_
# <br>
# [**13-03-NearRealTime-product-managing-files-tideGauges.ipynb**](13-03-NearRealTime-product-managing-files-tideGauges.ipynb)<br>
# [**13-04-NearRealTime-product-managing-files-profilers.ipynb**](13-04-NearRealTime-product-managing-files-profilers.ipynb)<br>
# [**13-05-NearRealTime-product-managing-files-thermosal.ipynb**](13-05-NearRealTime-product-managing-files-thermosal.ipynb)<br>
