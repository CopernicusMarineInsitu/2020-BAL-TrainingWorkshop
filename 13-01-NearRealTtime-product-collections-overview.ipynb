# %% [markdown]
# ![header](https://i.imgur.com/I4ake6d.jpg)

# %% [markdown]
# # IN SITU BALTIC SEA TRAINING

# %% [markdown]
# <div style="text-align: right"><i> 13-01-Part-one-out-of-five </i></div>

# %% [markdown]
# ***
# # BAL `NRT` product/dataset overview

# %% [markdown]
# ***
# **General Note 1**: Execute each cell through the <button class="btn btn-default btn-xs"><i class="icon-play fa fa-play"></i></button> button from the top MENU (or keyboard shortcut `Shift` + `Enter`).<br>
# <br>
# **General Note 2**: If, for any reason, the kernel is not working anymore, in the top MENU, click on the <button class="btn btn-default btn-xs"><i class="fa fa-repeat icon-repeat"></i></button> button. Then, in the top MENU, click on "Cell" and select "Run All Above Selected Cell".<br>
# ***

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc">
#     <ul class="toc-item">
#         <li><span><a href="#1.-Introduction" data-toc-modified-id="1.-Introduction">1. Introduction</a></span></li>
#         <li>
#             <span><a href="#2.-Setup" data-toc-modified-id="2.-Setup">2. Setup</a></span>
#             <ul>
#                 <li><span><a href="#2.1.-Python-packages" data-toc-modified-id="2.1.-Python-packages">2.1. Python packages</a></span></li>
#                 <li><span><a href="#2.2.-Copernicus-Database" data-toc-modified-id="2.2.-Copernicus-Database">2.2. Copernicus database</a></span></li>
#                 <li><span><a href="#2.3.-Auxiliary-functions" data-toc-modified-id="2.3.-Auxiliary-functions">2.3. Auxiliary functions</a></span></li>
#             </ul>
#         </li>
#         <li>
#             <span><a href="#3.-COLLECTION-OVERVIEW" data-toc-modified-id="3.-COLLECTION-OVERVIEW">3. Collection overview</a></span>
#             <ul>
#                 <li><span><a href="#3.1.-Getting-started" data-toc-modified-id="3.1.-Getting-started-packages">3.1. Getting started</a></span></li>
#                 <li><span><a href="#3.2.-Choosing-collection" data-toc-modified-id="3.2.-Chosing-collection">3.2. Choosing collection</a></span></li>
#                 <li>
#                     <span><a href="#3.3.-Overview" data-toc-modified-id="3.3.-Overview">3.3. Overview</a></span>
#                     <ul>
#                 <li><span><a href="#3.3.1.-Platforms" data-toc-modified-id="3.3.1.-Platforms">3.3.1. Platforms</a></span></li>
#                 <li><span><a href="#3.3.2.-Source-types" data-toc-modified-id="3.3.2.-Source-types">3.3.2. Source types (data types)</a></span></li>
#                 <li><span><a href="#3.3.3.-Feature-types" data-toc-modified-id="3.3.3.-Feature-types">3.3.3. Feature types (file types)</a></span></li>
#                 <li><span><a href="#3.3.4.-Parameters" data-toc-modified-id="3.3.4.-Parameters">3.3.4. Parameters</a></span></li>
#                 <li><span><a href="#3.3.5.-Providers" data-toc-modified-id="3.3.5.-Providers">3.3.5. Providers</a></span></li>
#             </ul>
#                 </li>
#             </ul>
#         </li>
#         <li><span><a href="#4.-Wrap-up" data-toc-modified-id="4.-Wrap-up">4. Wrap-up</a></span></li>
#         <li><span><a href="#5.-Next-tutorial" data-toc-modified-id="5.-Next-tutorial">5. Next tutorial</a></span></li>
#     </ul>
# </div>

# %% [markdown]
# ***

# %% [markdown]
# ## 1. Introduction
#
# This notebook focus on getting an overview of the files available in the different collections (`latest`, `monthly` and `history`) available within the In Situ Near Real Time product/dataset covering the Baltic Sea: `INSITU_BAL_NRT_OBSERVATIONS_013_032`. Click [here](https://resources.marine.copernicus.eu/?option=com_csw&task=results?option=com_csw&view=details&product_id=INSITU_BAL_NRT_OBSERVATIONS_013_032) to  view the dedicated section of this product within the [CMEMS Catalog](http://marine.copernicus.eu/services-portfolio/access-to-products/).

# %% [markdown]
# Any In Situ NRT product/dataset is just a bunch of netcdf files produced by the platforms (*drifters, profilers, gliders, moorings, HF-radars, vessels etc*) deployed in a certain seas (in this case, the Baltic Sea); so many files that navigation/subsetting can be challenging.

# %% [markdown]
# | ![BAL.gif](img/BAL.gif)|
# |:--:|
# | *GIF of the location (point or trajectory) of the platforms providing near real time data in the BAL area since 1860* |

# %% [markdown]
# To smooth the process of data discovery to users, the In Situ TAC provides a set of `index files` that describe the aforementioned file collections. In addition to these index files, it is also possible to find further info regarding each platform contributting with files on the `index_platform.txt`.

# %% [markdown]
# | Index |  Description |
# | ------- | ----------- |
# | `index_latest.txt`  |  List of available files within the latest collection + metadata |
# | `index_monthly.txt`   | List of available files within the monthly collection + metadata |
# | `index_history.txt`   |  List of available files within the history collection + metadata |
# | `index_platform.txt`   | Full list of platforms + metadata |

# %% [markdown]
# Check more about these files in the <a href="https://archimer.ifremer.fr/doc/00324/43494/" target="_blank">Product User Manual</a>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>OBJECTIVE</b>
#
# ***
# To discover which platforms, file types, data types, parameters and providers are to be expected in a specific collection of the BAL NRT product/dataset by using the aforementioned index files.

# %% [markdown]
# ## 2. Setup

# %% [markdown]
# ### 2.1. Python packages

# %% [markdown]
# For the notebook to properly run we need to first load the next packages available from the Jupyter Notebook Ecosystem. Please run the `next cell`:

# %%
import warnings
warnings.filterwarnings("ignore")
import IPython
from shapely.geometry import box 
from urllib.parse import urlparse
import ftputil
import os
import pandas as pd
import folium
from folium import plugins
import json2html
from json2html import *
# %matplotlib inline

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# If any of them raises any error it means you need to install the module first. For doing so please:
# 1. Open a new cell int he notebook
# 2. Run <i>`!conda install packageName --yes`</i> or <i>`!conda install -c conda-forge packageName --yes`</i> or <i>`!pip install packageName`</i>
# 3. Import again!
# <br><br>
# Example: <i>how-to-solve import error for json2html module </i>
#
# ![region.png](img/errorImporting.gif)

# %% [markdown]
# ### 2.2. Copernicus Database

# %% [markdown]
# Please `set next your CMEMS User credentials` in the next cell and `run the cell` afterwards:

# %%
usr = 'inputHereYourCMEMSUser'
pas = 'InputHereYourCMEMSPassword'

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# **Don't you have credentials yet?**
# <br>Please go [here](https://resources.marine.copernicus.eu/?option=com_sla) to get the above credentials to be able to access CMEMS secured FTP servers hosting CMEMS data products.

# %% [markdown]
# As stated before, we will focus on the Near Real Time product/dataset covering the Black Sea so, please `run the next` to load the info defining such product/dataset:

# %%
dataset = {
    'host': 'nrt.cmems-du.eu',#ftp host => nrt.cmems-du.eu for Near Real Time products
    'product': 'INSITU_BAL_NRT_OBSERVATIONS_013_032',#name of the In Situ Near Real Time product in the BS area
    'name': 'bal_multiparameter_nrt',#name of the dataset available in the above In Situ Near Real Time product
    'index_files': ['index_latest.txt', 'index_monthly.txt', 'index_history.txt'],#files describing the content of the lastest, monthly and history netCDF file collections available withint he above dataset
    'index_platform': 'index_platform.txt',#files describing the netwotk of platforms contributting with files in the abve collections
}

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# In case you want to explore any other In Situ NRT product/dataset just set the above definitions accordingly and you will be able to reproduce the analysis we will perform next.

# %% [markdown]
# ### 2.3. Auxiliary functions

# %% [markdown]
# For exploring the product/dataset we will use a set of files called `index files` located in the CMEMS FTP server.

# %% [markdown]
# 1. **Download the index files**.
# In order to download the most updated version of these files we will use the next function. <br>Please `run the next cell` to load it (te funtion) in memory for later use:

# %%
def getIndexFiles(usr,pas,dataset,path2indexes):
    #Provides the index files available at the ftp server
    indexes = dataset['index_files'] + [dataset['index_platform']]
    with ftputil.FTPHost(dataset['host'], usr, pas) as ftp_host:  # connect to CMEMS FTP
        for index in indexes:
            remotefile= "/".join(['Core',dataset['product'],dataset['name'],index])
            print('.....Downloading ' + index)
            localfile = os.path.join(path2indexes,index)
            ftp_host.download(remotefile,localfile)  # remote, local
    print('Ready!')

# %% [markdown]
# 2. **Index files reader**.
# In order to load the information contained in *each* of the files we will use the next function. <br>Please `run the next cell` to load it in memory for later use:

# %%
def readIndexFileFromCWD(path2file):
    #Load as pandas dataframe the file in the provided path
    with open(path2file, 'rb') as f:
        filename = os.path.basename(path2file)
        print('...Loading info from: '+filename)
        raw_index_info = pd.read_csv(path2file, skiprows=5)
    return raw_index_info

# %% [markdown]
# 3. **Index files merger**.
# In order to load the information contained in *all* the indexes in a one single entity we will use the next function. <br>Please `run the next cell` to load it in memory for later use:

# %%
def getIndexFilesInfo(usr, pas, dataset,path2indexes):
    # Load and merge in a single entity all the information contained on each file descriptor of a given dataset
    # 1) Loading the index platform info as dataframe
    path2file = os.path.join(path2indexes, dataset['index_platform'])
    indexPlatform = readIndexFileFromCWD(path2file)
    indexPlatform.rename(columns={indexPlatform.columns[0]: "platform_code" }, inplace = True)
    indexPlatform = indexPlatform.drop_duplicates(subset='platform_code', keep="first")
    # 2) Loading the index files info as dataframes
    netcdf_collections = []
    for filename in dataset['index_files']:
        path2file = os.path.join(path2indexes,filename)
        indexFile = readIndexFileFromCWD(path2file)
        netcdf_collections.append(indexFile)
    netcdf_collections = pd.concat(netcdf_collections)
    # 3) creating new columns: derived info
    netcdf_collections['netcdf'] = netcdf_collections['file_name'].str.split('/').str[-1]
    netcdf_collections['file_type'] = netcdf_collections['netcdf'].str.split('.').str[0].str.split('_').str[1]
    netcdf_collections['data_type'] = netcdf_collections['netcdf'].str.split('.').str[0].str.split('_').str[2]
    netcdf_collections['platform_code'] = netcdf_collections['netcdf'].str.split('.').str[0].str.split('_').str[3]
    # 4) Merging the information of all files
    headers = ['platform_code','wmo_platform_code', 'institution_edmo_code', 'last_latitude_observation', 'last_longitude_observation','last_date_observation']
    result = pd.merge(netcdf_collections,indexPlatform[headers],on='platform_code')
    print('Ready!')
    return result

# %% [markdown]
# ## 3. COLLECTION OVERVIEW

# %% [markdown]
# ### 3.1. Getting started

# %% [markdown]
# For the analysis to be carried out we need the most recent version of the index files. By default we will save them into the `index_files` folder available in the `data` folder. Nevertheless if you rather use a different one set it next:

# %%
path2indexes= os.path.join(os.getcwd(),'data','index_files')#default path to save the files

# %% [markdown]
# Although in such folder we have provided already a copy of the files, **if you are running this notebook later than April 2020**  please `Run the next` cell and download again the index files:

# %%
getIndexFiles(usr,pas,dataset,path2indexes)
# Out:
# .....Downloading index_latest.txt
# .....Downloading index_monthly.txt
# .....Downloading index_history.txt
# .....Downloading index_platform.txt
# Ready!

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# **Are you getting a `permission denied` error?**
# <br>Please be aware that no `writes` are authorized in the 'shared_notebook' folder. Make sure you run this on you own space after copying the notebooks form shared_notebooks. If you are still facing a problem contact us trough [Mattermost](https://chat-cmems.mercator-ocean.fr/).

# %% [markdown]
# Let's load now into a dataframe the info contained in such files: `run the next cell!`

# %%
info = getIndexFilesInfo(usr, pas, dataset, path2indexes)
# Out:
# ...Loading info from: index_platform.txt
# ...Loading info from: index_latest.txt
# ...Loading info from: index_monthly.txt
# ...Loading info from: index_history.txt
# Ready!

# %% [markdown]
# `Run now the next cell` to see the information just loaded above:

# %%
info.transpose()
# Out:
#                                                                         0      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3877
# geospatial_lat_max                                                    58.3877
# geospatial_lon_min                                                    11.6267
# geospatial_lon_max                                                    11.6267
# time_coverage_start                                      2021-01-12T16:02:00Z
# time_coverage_end                                        2021-01-12T16:02:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:28Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                   BO_PR_CT_SMHIBJORKHOLMEN_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                 SMHIBJORKHOLMEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3877
# last_longitude_observation                                            11.6267
# last_date_observation                                    2021-02-07T01:09:58Z
#
#                                                                         1      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3877
# geospatial_lat_max                                                    58.3877
# geospatial_lon_min                                                    11.6267
# geospatial_lon_max                                                    11.6267
# time_coverage_start                                      2004-03-03T08:12:00Z
# time_coverage_end                                        2020-11-30T15:30:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:09:58Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                            BO_PR_CT_SMHIBJORKHOLMEN.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                 SMHIBJORKHOLMEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3877
# last_longitude_observation                                            11.6267
# last_date_observation                                    2021-02-07T01:09:58Z
#
#                                                                         2      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    57.3147
# geospatial_lat_max                                                    57.3147
# geospatial_lon_min                                                    20.0803
# geospatial_lon_max                                                    20.0803
# time_coverage_start                                      2021-01-12T00:51:00Z
# time_coverage_end                                        2021-01-12T00:51:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:28Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 PRES SVEL LGHT DOX1
# netcdf                                          BO_PR_CT_SMHIBY15_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY15
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             57.2938
# last_longitude_observation                                            19.9077
# last_date_observation                                    2021-02-07T01:11:06Z
#
#                                                                         3      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    57.2938
# geospatial_lat_max                                                    57.3345
# geospatial_lon_min                                                    19.9077
# geospatial_lon_max                                                    20.0873
# time_coverage_start                                      1978-11-22T00:20:00Z
# time_coverage_end                                        2020-12-11T05:21:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:11:06Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_SMHIBY15.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY15
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             57.2938
# last_longitude_observation                                            19.9077
# last_date_observation                                    2021-02-07T01:11:06Z
#
#                                                                         4      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.8815
# geospatial_lat_max                                                    58.8815
# geospatial_lon_min                                                    20.3282
# geospatial_lon_max                                                    20.3282
# time_coverage_start                                      2021-01-12T12:11:00Z
# time_coverage_end                                        2021-01-12T12:11:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:28Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 PRES SVEL LGHT DOX1
# netcdf                                          BO_PR_CT_SMHIBY29_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY29
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.8748
# last_longitude_observation                                            20.3100
# last_date_observation                                    2021-02-07T01:12:08Z
#
#                                                                         5      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.8748
# geospatial_lat_max                                                    58.8855
# geospatial_lon_min                                                    20.3100
# geospatial_lon_max                                                    20.3358
# time_coverage_start                                      1978-11-21T08:20:00Z
# time_coverage_end                                        2020-12-10T17:55:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:12:08Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_SMHIBY29.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY29
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.8748
# last_longitude_observation                                            20.3100
# last_date_observation                                    2021-02-07T01:12:08Z
#
#                                                                         6      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.5937
# geospatial_lat_max                                                    58.5937
# geospatial_lon_min                                                    18.2363
# geospatial_lon_max                                                    18.2363
# time_coverage_start                                      2021-01-12T19:50:00Z
# time_coverage_end                                        2021-01-12T19:50:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:29Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 PRES SVEL LGHT DOX1
# netcdf                                          BO_PR_CT_SMHIBY31_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY31
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.5772
# last_longitude_observation                                            18.2263
# last_date_observation                                    2021-02-07T01:12:43Z
#
#                                                                         7      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.5772
# geospatial_lat_max                                                    58.6100
# geospatial_lon_min                                                    18.2263
# geospatial_lon_max                                                    18.2387
# time_coverage_start                                      1978-11-16T17:00:00Z
# time_coverage_end                                        2020-12-04T17:04:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:12:43Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_SMHIBY31.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY31
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.5772
# last_longitude_observation                                            18.2263
# last_date_observation                                    2021-02-07T01:12:43Z
#
#                                                                         8      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3333
# geospatial_lat_max                                                    58.3333
# geospatial_lon_min                                                    11.8833
# geospatial_lon_max                                                    11.8833
# time_coverage_start                                      2021-01-12T12:45:00Z
# time_coverage_end                                        2021-01-12T12:45:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:00:29Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                     BO_PR_CT_SMHIBYFJORDEN_20210112.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                   SMHIBYFJORDEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3333
# last_longitude_observation                                            11.8833
# last_date_observation                                    2021-02-08T19:00:46Z
#
#                                                                         9      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3333
# geospatial_lat_max                                                    58.3333
# geospatial_lon_min                                                    11.8833
# geospatial_lon_max                                                    11.8833
# time_coverage_start                                      2021-02-02T12:33:00Z
# time_coverage_end                                        2021-02-02T12:33:00Z
# institution                                                              SMHI
# date_update                                              2021-02-08T19:00:46Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                     BO_PR_CT_SMHIBYFJORDEN_20210202.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                   SMHIBYFJORDEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3333
# last_longitude_observation                                            11.8833
# last_date_observation                                    2021-02-08T19:00:46Z
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
#
#                                                                         22747  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      56.11
# geospatial_lat_max                                                      56.11
# geospatial_lon_min                                                      16.53
# geospatial_lon_max                                                      16.53
# time_coverage_start                                      1996-08-20T18:50:00Z
# time_coverage_end                                        1997-08-22T17:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:49:13Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SHPF.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SHPF
# wmo_platform_code                                                        SHPF
# institution_edmo_code
# last_latitude_observation                                               56.11
# last_longitude_observation                                              16.53
# last_date_observation                                    2019-10-06T06:49:13Z
#
#                                                                         22748  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      58.03
# geospatial_lat_max                                                      58.03
# geospatial_lon_min                                                      17.07
# geospatial_lon_max                                                      17.07
# time_coverage_start                                      1996-08-10T10:30:00Z
# time_coverage_end                                        1998-02-12T13:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:49:13Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SHQP.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SHQP
# wmo_platform_code                                                        SHQP
# institution_edmo_code
# last_latitude_observation                                               58.03
# last_longitude_observation                                              17.07
# last_date_observation                                    2019-10-06T06:49:13Z
#
#                                                                         22749  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      56.66
# geospatial_lat_max                                                      56.66
# geospatial_lon_min                                                      12.11
# geospatial_lon_max                                                      12.11
# time_coverage_start                                      1996-03-02T17:00:00Z
# time_coverage_end                                        1996-03-02T17:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:45Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SJIB.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SJIB
# wmo_platform_code                                                        SJIB
# institution_edmo_code
# last_latitude_observation                                               56.66
# last_longitude_observation                                              12.11
# last_date_observation                                    2019-10-06T06:52:45Z
#
#                                                                         22750  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      62.13
# geospatial_lat_max                                                      62.13
# geospatial_lon_min                                                      17.86
# geospatial_lon_max                                                      17.86
# time_coverage_start                                      1997-07-04T16:30:00Z
# time_coverage_end                                        1997-07-04T16:30:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:45Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SKUP.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SKUP
# wmo_platform_code                                                        SKUP
# institution_edmo_code
# last_latitude_observation                                               62.13
# last_longitude_observation                                              17.86
# last_date_observation                                    2019-10-06T06:52:45Z
#
#                                                                         22751  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      62.13
# geospatial_lat_max                                                      62.13
# geospatial_lon_min                                                      17.86
# geospatial_lon_max                                                      17.86
# time_coverage_start                                      1996-10-25T10:00:00Z
# time_coverage_end                                        1997-09-27T15:45:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:45Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SKVP.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SKVP
# wmo_platform_code                                                        SKVP
# institution_edmo_code
# last_latitude_observation                                               62.13
# last_longitude_observation                                              17.86
# last_date_observation                                    2019-10-06T06:52:45Z
#
#                                                                         22752  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      55.00
# geospatial_lat_max                                                      56.97
# geospatial_lon_min                                                     -60.00
# geospatial_lon_max                                                      14.83
# time_coverage_start                                      1999-07-20T11:00:00Z
# time_coverage_end                                        1999-09-22T11:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:45Z
# data_mode                                                                   R
# parameters                    DC_REFERENCE DATA_MODE DIRECTION DEPH PRES TEMP
# netcdf                                                       GL_PR_XX_SMTZ.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SMTZ
# wmo_platform_code                                                        SMTZ
# institution_edmo_code
# last_latitude_observation                                               55.00
# last_longitude_observation                                             -60.00
# last_date_observation                                    2019-10-06T06:52:45Z
#
#                                                                         22753  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      57.20
# geospatial_lat_max                                                      57.20
# geospatial_lon_min                                                      11.66
# geospatial_lon_max                                                      11.66
# time_coverage_start                                      1996-08-20T12:20:00Z
# time_coverage_end                                        1996-08-20T12:20:00Z
# institution                                               Unknown institution
# date_update                                              2019-10-06T06:52:44Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SMZG.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SMZG
# wmo_platform_code                                                        SMZG
# institution_edmo_code
# last_latitude_observation                                               57.20
# last_longitude_observation                                              11.66
# last_date_observation                                    2019-10-06T06:52:44Z
#
#                                                                         22754  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      56.66
# geospatial_lat_max                                                      57.18
# geospatial_lon_min                                                      11.66
# geospatial_lon_max                                                      12.11
# time_coverage_start                                      1996-01-17T14:15:00Z
# time_coverage_end                                        1998-05-16T13:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:44Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SMZQ.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SMZQ
# wmo_platform_code                                                        SMZQ
# institution_edmo_code
# last_latitude_observation                                               56.66
# last_longitude_observation                                              11.66
# last_date_observation                                    2019-10-06T06:52:44Z
#
#                                                                         22755  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      55.00
# geospatial_lat_max                                                      62.13
# geospatial_lon_min                                                      11.66
# geospatial_lon_max                                                      17.86
# time_coverage_start                                      1996-06-02T18:20:00Z
# time_coverage_end                                        1999-09-07T12:45:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:44Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SMZT.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SMZT
# wmo_platform_code                                                        SMZT
# institution_edmo_code
# last_latitude_observation                                               55.00
# last_longitude_observation                                              11.66
# last_date_observation                                    2019-10-06T06:52:44Z
#
#                                                                         22756
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     57.717
# geospatial_lat_max                                                     65.025
# geospatial_lon_min                                                    -12.979
# geospatial_lon_max                                                      8.983
# time_coverage_start                                      2013-09-21T15:14:00Z
# time_coverage_end                                        2013-10-25T05:34:00Z
# institution                                               Unknown institution
# date_update                                              2019-10-06T08:07:25Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION DEPH TEMP
# netcdf                                                    GL_PR_XX_VOZ2040.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                         VOZ2040
# wmo_platform_code                                                     VOZ2040
# institution_edmo_code
# last_latitude_observation                                              57.717
# last_longitude_observation                                            -12.979
# last_date_observation                                    2019-10-06T08:07:25Z
#
# [21 rows x 22757 columns]

# %% [markdown]
# Above you can see, on the left hand side, a number of metadata fields that describes the files available in each collection (latest, monthly and history) of the product, such as: ftplink to download it (file_name), geospatial bounding box (geospatial_lat/lon_min/max), temporal coverage (time_coverage_start/end) etc.
#
# You can also see a dedicated column for each file with its corresponding values for the aforementioned descriptive metadata fields.

# %% [markdown]
# We will use all this information next to have a glimpse to the content of one of the product/dataset netCDF files collections.

# %% [markdown]
# ### 3.2. Choosing collection

# %% [markdown]
# `Set in the next cell the collection` you wanna get an overview of and `run it` afterwards. <br> We have selected the 'history' by default but please feel free to change it:

# %%
targeted_collection = 'history'
targeted_collection_info = info[info['file_name'].str.contains(targeted_collection)]
targeted_collection_info.transpose()
# Out:
#                                                                         1      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3877
# geospatial_lat_max                                                    58.3877
# geospatial_lon_min                                                    11.6267
# geospatial_lon_max                                                    11.6267
# time_coverage_start                                      2004-03-03T08:12:00Z
# time_coverage_end                                        2020-11-30T15:30:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:09:58Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                            BO_PR_CT_SMHIBJORKHOLMEN.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                 SMHIBJORKHOLMEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3877
# last_longitude_observation                                            11.6267
# last_date_observation                                    2021-02-07T01:09:58Z
#
#                                                                         3      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    57.2938
# geospatial_lat_max                                                    57.3345
# geospatial_lon_min                                                    19.9077
# geospatial_lon_max                                                    20.0873
# time_coverage_start                                      1978-11-22T00:20:00Z
# time_coverage_end                                        2020-12-11T05:21:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:11:06Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_SMHIBY15.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY15
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             57.2938
# last_longitude_observation                                            19.9077
# last_date_observation                                    2021-02-07T01:11:06Z
#
#                                                                         5      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.8748
# geospatial_lat_max                                                    58.8855
# geospatial_lon_min                                                    20.3100
# geospatial_lon_max                                                    20.3358
# time_coverage_start                                      1978-11-21T08:20:00Z
# time_coverage_end                                        2020-12-10T17:55:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:12:08Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_SMHIBY29.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY29
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.8748
# last_longitude_observation                                            20.3100
# last_date_observation                                    2021-02-07T01:12:08Z
#
#                                                                         7      \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.5772
# geospatial_lat_max                                                    58.6100
# geospatial_lon_min                                                    18.2263
# geospatial_lon_max                                                    18.2387
# time_coverage_start                                      1978-11-16T17:00:00Z
# time_coverage_end                                        2020-12-04T17:04:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:12:43Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                   BO_PR_CT_SMHIBY31.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                        SMHIBY31
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.5772
# last_longitude_observation                                            18.2263
# last_date_observation                                    2021-02-07T01:12:43Z
#
#                                                                         10     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3333
# geospatial_lat_max                                                    58.3333
# geospatial_lon_min                                                    11.8833
# geospatial_lon_max                                                    11.8833
# time_coverage_start                                      2004-02-03T16:20:00Z
# time_coverage_end                                        2020-11-30T12:16:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:14:04Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                              BO_PR_CT_SMHIBYFJORDEN.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                   SMHIBYFJORDEN
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3333
# last_longitude_observation                                            11.8833
# last_date_observation                                    2021-02-08T19:00:46Z
#
#                                                                         13     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    57.6675
# geospatial_lat_max                                                    57.6675
# geospatial_lon_min                                                    11.6867
# geospatial_lon_max                                                    11.6867
# time_coverage_start                                      2004-02-03T08:55:00Z
# time_coverage_end                                        2020-11-30T07:48:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:14:10Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                              BO_PR_CT_SMHIDANAFJORD.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                   SMHIDANAFJORD
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             57.6675
# last_longitude_observation                                            11.6867
# last_date_observation                                    2021-02-08T19:00:46Z
#
#                                                                         16     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.1097
# geospatial_lat_max                                                    58.1097
# geospatial_lon_min                                                    11.8100
# geospatial_lon_max                                                    11.8100
# time_coverage_start                                      2004-02-03T14:20:00Z
# time_coverage_end                                        2020-11-30T10:42:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:14:44Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                                BO_PR_CT_SMHIGALTERO.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                     SMHIGALTERO
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.1097
# last_longitude_observation                                            11.8100
# last_date_observation                                    2021-02-08T19:00:46Z
#
#                                                                         18     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    58.3125
# geospatial_lat_max                                                    58.3125
# geospatial_lon_min                                                    11.7733
# geospatial_lon_max                                                    11.7733
# time_coverage_start                                      2004-02-03T17:45:00Z
# time_coverage_end                                        2020-11-30T12:53:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:15:01Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                          BO_PR_CT_SMHIHAVSTENSFJORD.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                               SMHIHAVSTENSFJORD
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             58.3125
# last_longitude_observation                                            11.7733
# last_date_observation                                    2021-02-07T01:15:01Z
#
#                                                                         21     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                    57.9017
# geospatial_lat_max                                                    57.9017
# geospatial_lon_min                                                    11.6667
# geospatial_lon_max                                                    11.6667
# time_coverage_start                                      2004-02-03T10:25:00Z
# time_coverage_end                                        2020-11-30T09:20:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:15:07Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                             BO_PR_CT_SMHIINSTORANNA.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                  SMHIINSTORANNA
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                             57.9017
# last_longitude_observation                                            11.6667
# last_date_observation                                    2021-02-08T19:00:46Z
#
#                                                                         23     \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      53.23
# geospatial_lat_max                                                      58.23
# geospatial_lon_min                                                      11.58
# geospatial_lon_max                                                      11.58
# time_coverage_start                                      2004-02-03T19:15:00Z
# time_coverage_end                                        2020-11-30T14:03:00Z
# institution                                                              SMHI
# date_update                                              2021-02-07T01:15:15Z
# data_mode                                                                   R
# parameters                            PSAL TEMP TUR4 FLU2 DEPH SVEL LGHT DOX1
# netcdf                                             BO_PR_CT_SMHIKOLJOFJORD.nc
# file_type                                                                  PR
# data_type                                                                  CT
# platform_code                                                  SMHIKOLJOFJORD
# wmo_platform_code                                                         NaN
# institution_edmo_code                                                     545
# last_latitude_observation                                               53.23
# last_longitude_observation                                              11.58
# last_date_observation                                    2021-02-07T01:15:15Z
#
#                             ...  \
# # product_id                ...
# file_name                   ...
# geospatial_lat_min          ...
# geospatial_lat_max          ...
# geospatial_lon_min          ...
# geospatial_lon_max          ...
# time_coverage_start         ...
# time_coverage_end           ...
# institution                 ...
# date_update                 ...
# data_mode                   ...
# parameters                  ...
# netcdf                      ...
# file_type                   ...
# data_type                   ...
# platform_code               ...
# wmo_platform_code           ...
# institution_edmo_code       ...
# last_latitude_observation   ...
# last_longitude_observation  ...
# last_date_observation       ...
#
#                                                                         22747  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      56.11
# geospatial_lat_max                                                      56.11
# geospatial_lon_min                                                      16.53
# geospatial_lon_max                                                      16.53
# time_coverage_start                                      1996-08-20T18:50:00Z
# time_coverage_end                                        1997-08-22T17:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:49:13Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SHPF.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SHPF
# wmo_platform_code                                                        SHPF
# institution_edmo_code
# last_latitude_observation                                               56.11
# last_longitude_observation                                              16.53
# last_date_observation                                    2019-10-06T06:49:13Z
#
#                                                                         22748  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      58.03
# geospatial_lat_max                                                      58.03
# geospatial_lon_min                                                      17.07
# geospatial_lon_max                                                      17.07
# time_coverage_start                                      1996-08-10T10:30:00Z
# time_coverage_end                                        1998-02-12T13:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:49:13Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SHQP.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SHQP
# wmo_platform_code                                                        SHQP
# institution_edmo_code
# last_latitude_observation                                               58.03
# last_longitude_observation                                              17.07
# last_date_observation                                    2019-10-06T06:49:13Z
#
#                                                                         22749  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      56.66
# geospatial_lat_max                                                      56.66
# geospatial_lon_min                                                      12.11
# geospatial_lon_max                                                      12.11
# time_coverage_start                                      1996-03-02T17:00:00Z
# time_coverage_end                                        1996-03-02T17:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:45Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SJIB.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SJIB
# wmo_platform_code                                                        SJIB
# institution_edmo_code
# last_latitude_observation                                               56.66
# last_longitude_observation                                              12.11
# last_date_observation                                    2019-10-06T06:52:45Z
#
#                                                                         22750  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      62.13
# geospatial_lat_max                                                      62.13
# geospatial_lon_min                                                      17.86
# geospatial_lon_max                                                      17.86
# time_coverage_start                                      1997-07-04T16:30:00Z
# time_coverage_end                                        1997-07-04T16:30:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:45Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SKUP.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SKUP
# wmo_platform_code                                                        SKUP
# institution_edmo_code
# last_latitude_observation                                               62.13
# last_longitude_observation                                              17.86
# last_date_observation                                    2019-10-06T06:52:45Z
#
#                                                                         22751  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      62.13
# geospatial_lat_max                                                      62.13
# geospatial_lon_min                                                      17.86
# geospatial_lon_max                                                      17.86
# time_coverage_start                                      1996-10-25T10:00:00Z
# time_coverage_end                                        1997-09-27T15:45:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:45Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SKVP.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SKVP
# wmo_platform_code                                                        SKVP
# institution_edmo_code
# last_latitude_observation                                               62.13
# last_longitude_observation                                              17.86
# last_date_observation                                    2019-10-06T06:52:45Z
#
#                                                                         22752  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      55.00
# geospatial_lat_max                                                      56.97
# geospatial_lon_min                                                     -60.00
# geospatial_lon_max                                                      14.83
# time_coverage_start                                      1999-07-20T11:00:00Z
# time_coverage_end                                        1999-09-22T11:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:45Z
# data_mode                                                                   R
# parameters                    DC_REFERENCE DATA_MODE DIRECTION DEPH PRES TEMP
# netcdf                                                       GL_PR_XX_SMTZ.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SMTZ
# wmo_platform_code                                                        SMTZ
# institution_edmo_code
# last_latitude_observation                                               55.00
# last_longitude_observation                                             -60.00
# last_date_observation                                    2019-10-06T06:52:45Z
#
#                                                                         22753  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      57.20
# geospatial_lat_max                                                      57.20
# geospatial_lon_min                                                      11.66
# geospatial_lon_max                                                      11.66
# time_coverage_start                                      1996-08-20T12:20:00Z
# time_coverage_end                                        1996-08-20T12:20:00Z
# institution                                               Unknown institution
# date_update                                              2019-10-06T06:52:44Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SMZG.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SMZG
# wmo_platform_code                                                        SMZG
# institution_edmo_code
# last_latitude_observation                                               57.20
# last_longitude_observation                                              11.66
# last_date_observation                                    2019-10-06T06:52:44Z
#
#                                                                         22754  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      56.66
# geospatial_lat_max                                                      57.18
# geospatial_lon_min                                                      11.66
# geospatial_lon_max                                                      12.11
# time_coverage_start                                      1996-01-17T14:15:00Z
# time_coverage_end                                        1998-05-16T13:00:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:44Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SMZQ.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SMZQ
# wmo_platform_code                                                        SMZQ
# institution_edmo_code
# last_latitude_observation                                               56.66
# last_longitude_observation                                              11.66
# last_date_observation                                    2019-10-06T06:52:44Z
#
#                                                                         22755  \
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                      55.00
# geospatial_lat_max                                                      62.13
# geospatial_lon_min                                                      11.66
# geospatial_lon_max                                                      17.86
# time_coverage_start                                      1996-06-02T18:20:00Z
# time_coverage_end                                        1999-09-07T12:45:00Z
# institution                                                  Sweden (Unknown)
# date_update                                              2019-10-06T06:52:44Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION PRES TEMP
# netcdf                                                       GL_PR_XX_SMZT.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                            SMZT
# wmo_platform_code                                                        SMZT
# institution_edmo_code
# last_latitude_observation                                               55.00
# last_longitude_observation                                              11.66
# last_date_observation                                    2019-10-06T06:52:44Z
#
#                                                                         22756
# # product_id                                                        COP-BO-01
# file_name                   ftp://nrt.cmems-du.eu/Core/INSITU_BAL_NRT_OBSE...
# geospatial_lat_min                                                     57.717
# geospatial_lat_max                                                     65.025
# geospatial_lon_min                                                    -12.979
# geospatial_lon_max                                                      8.983
# time_coverage_start                                      2013-09-21T15:14:00Z
# time_coverage_end                                        2013-10-25T05:34:00Z
# institution                                               Unknown institution
# date_update                                              2019-10-06T08:07:25Z
# data_mode                                                                   R
# parameters                         DC_REFERENCE DATA_MODE DIRECTION DEPH TEMP
# netcdf                                                    GL_PR_XX_VOZ2040.nc
# file_type                                                                  PR
# data_type                                                                  XX
# platform_code                                                         VOZ2040
# wmo_platform_code                                                     VOZ2040
# institution_edmo_code
# last_latitude_observation                                              57.717
# last_longitude_observation                                            -12.979
# last_date_observation                                    2019-10-06T08:07:25Z
#
# [21 rows x 2503 columns]

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>IMPORTANT</b>
#
# ***
# Please remember available options:
# <ul>
#     <li><i>latest</i>: daily files from platforms (last 30 days of data)</li>
#     <li><i>monthly</i>: monthly files from platforms (last 5 years of data)</li>
#     <li><i>history</i>: one file per platform (all platform data)</li>
# </ul>

# %% [markdown]
# ### 3.3. Overview

# %% [markdown]
# #### 3.3.1. Platforms

# %% [markdown]
# Any Situ NRT products/datasets collections are composed by files reported by a network of platforms located in the area.

# %% [markdown]
# Let's `run the next cell` to know how many platforms are contributting to this product/dataset collection with files:

# %%
len(targeted_collection_info.groupby('platform_code').groups)
# Out:
# 1914

# %% [markdown]
# Let's get a closer look to this list of platforms: `run the next cells`:

# %%
data_platforms = [{
    'code':code, 
    'provider(s)': files['institution_edmo_code'].iloc[0],
    'files': {
        'nfiles': len(files), 
        'feature(s)': [{'code': ftype, 'nfiles':len(files.groupby('file_type').get_group(ftype)),'sources(s)': [{'code': dtype, 'nfiles': len(files.groupby('file_type').get_group(ftype).groupby('data_type').get_group(dtype)), 'parameters': [param for param in sum([files.groupby('file_type').get_group(ftype).groupby('data_type').get_group(dtype)['parameters'].unique().tolist()],[])[0].split(' ') if '_' not in param and param not in ['DEPH', 'PRES'] and param != '']} for dtype in files[files['file_type']==ftype]['data_type'].unique().tolist()]} for ftype in files['file_type'].unique().tolist()]}
} for code,files in targeted_collection_info.groupby(['platform_code'])]

# %%
IPython.display.HTML(json2html.convert(data_platforms))
# Out:
# <table border="1"><thead><tr><th>code</th><th>provider(s)</th><th>files</th></tr></thead><tbody><tr><td>10005</td><td> </td><td><table border="1"><tr><th>nfiles</th><td>1</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>XX</td><td>1</td><td><ul><li>DIRECTION</li><li>TEMP</li></ul></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr><tr><td>18189002</td><td> </td><td><table border="1"><tr><th>nfiles</th><td>1</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>XB</td><td>1</td><td><ul><li>DIRECTION</li><li>TEMP</li><li>SVEL</li></ul></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr><tr><td>18189100</td><td> </td><td><table border="1"><tr><th>nfiles</th><td>1</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>XB</td><td>1</td><td><ul><li>DIRECTION</li><li>TEMP</li><li>SVEL</li></ul></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr><tr><td>18189102</td><td> </td><td><table border="1"><tr><th>nfiles</th><td>1</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>XB</td><td>1</td><td><ul><li>DIRECTION</li><li>TEMP</li><li>SVEL</li></ul></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr><tr><td>18189203</td><td> </td><td><table border="1"><tr><th>nfiles</th><td>1</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>XB</td><td>1</td><td><ul><li>DIRECTION</li><li>TEMP</li></ul></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr><tr><td>18IS0600</td><td> </td><td><table border="1"><tr><th>nfiles</th><td>1</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>XB</td><td>1</td><td><ul><li>DIRECTION</li><li>TEMP</li></ul></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr><tr><td>18MP0500</td><td> </td><td><table border="1"><tr><th>nfiles</th><td>1</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>XB</td><td>1</td><td><ul><li>DIRECTION</li><li>TEMP</li></ul></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr><tr><td>18MP9800</td><td> </td><td><table border="1"><tr><th>nfiles</th><td>1</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>XB</td><td>1</td><td><ul><li>DIRECTION</li><li>TEMP</li></ul></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td>< ...

# %% [markdown]
# Too much info? Let's see one in particular! `Run the next cells`:
# <a id='platform_selected'></a>

# %%
code = 'FNFP'

# %%
selection = [platform for platform in data_platforms if platform['code'] == code]
IPython.display.HTML(json2html.convert(selection))
# Out:
# <table border="1"><thead><tr><th>code</th><th>provider(s)</th><th>files</th></tr></thead><tbody><tr><td>FNFP</td><td>1054</td><td><table border="1"><tr><th>nfiles</th><td>46</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>17</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>BO</td><td>3</td><td><ul><li>PSAL</li></ul></td></tr><tr><td>TS</td><td>14</td><td><ul><li>PSAL</li><li>TEMP</li><li>CNDC</li><li>SSJT</li></ul></td></tr></tbody></table></td></tr><tr><td>PR</td><td>29</td><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>parameters</th></tr></thead><tbody><tr><td>CT</td><td>29</td><td><ul><li>DIRECTION</li><li>TEMP</li><li>PSAL</li></ul></td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></tbody></table>

# %% [markdown]
# So far we can see that each platform:
# * Can have one or more providers - identified by a blank-separated-list of one or more codes: the so called *edmo code* (we will see more about this later).
# * Produces different type of files (see above `PR` and `TS` *feature* bigram) from one or more data sources (see above `BO`,`TS`and `CT` *source* bigram) and containing more or less parameters (see *parameters* codes). We will see next more about this!

# %% [markdown]
# Ok but...where is it located? There are some geographical references that we can use to infer the location of the platform:
# * the bounding box of the produced files (this is, the spatial coverage - a rectangular simplification actually - of the data measured by the platform)
# * the last position reported.

# %% [markdown]
# Let's draw all them on a map to get an idea!: `run the next cell`

# %%
#initializing map
m = folium.Map(location=[39.0, 0], zoom_start=4)
#Looping over each file produced by the platform above
for idx,file in targeted_collection_info[targeted_collection_info['platform_code'] == code].iterrows():
    #Bounding-box of each file to map as polygon
    upper_left = [file['geospatial_lat_max'], file['geospatial_lon_min']]
    upper_right = [file['geospatial_lat_max'], file['geospatial_lon_max']]
    lower_right = [file['geospatial_lat_min'], file['geospatial_lon_max']]
    lower_left = [file['geospatial_lat_min'], file['geospatial_lon_min']]
    edges = [upper_left, upper_right, lower_right, lower_left]
    m.add_child(folium.vector_layers.Polygon(locations=edges, popup='file bbox: '+file['netcdf']))
#Last reported position to map as marker
m.add_child(folium.Marker([file['last_latitude_observation'], file['last_longitude_observation']], popup=file['platform_code']+' last position' ))
#Zooming closer
m.fit_bounds(edges, max_zoom=6)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a963dfff8f8e4572a567e7aa335819b0%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a963dfff8f8e4572a567e7aa335819b0%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a963dfff8f8e4572a567e7aa335819b0%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_a963dfff8f8e4572a567e7aa335819b0%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.0%2C%200.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs ...

# %% [markdown]
# On the next tutorial we will see how to use this very same geographical info to select only those files covering a specific area.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>WARNING</b>
#
# ***
# **Don't you see the map?** Please open the notebook in a different browser (i.e Chrome!) as some have problems rendering folium maps.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b style="margin-right: 2em">IMPORTANT</b>
#
# ***
# **Are you a provider?**
# If you have a platform (or know about one) producing data in the area and it does not appear ont he list please **contact us** by emailing the corresponding Regional CMEMS In Situ TAC Service Desk [here](http://www.marineinsitu.eu/submit-data/) **or let the speaker know**!

# %% [markdown]
# #### 3.3.2. Source types

# %% [markdown]
# `Data sources` represents the elements that report oceanographic data. <br>So far the In Situ TAC distinguishes:

# %% [markdown]
# | code | description |
# | ------- | ------- |
# |BO | Bottle |
# |BA | Data from Bathy messages on GTS |
# |DB | Drifting buoys |
# |DC | Drifting buoy reporting calculated sea water current |
# |FB | FerryBox |
# |MO | Fixed buoys or mooring time series |
# |TG | Tide gauges |
# |GL | Gliders |
# |ML | Mini logger |
# |CT | Oceanographic CTD profiles | //historic index file el data_type es "oceanographic CTD profiles"
# |PF | Profiling floats vertical profiles |
# |RE | Recopesca |
# |RF | River flows |
# |SF | Scanfish profiles |
# |TS | Thermosalinograph data |
# |XB | XBT or XCTD profiles |
# |TE | Data from TESAC messages on GTS |
# |SM | Sea-mammals |
# |HF | High Frequency Radar |
# |SD | Saildrone |
# |VA | Vessel mounted ADCP |
# |XX | Unknown |

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To find the updated catalog of possible codes for data sources (`data types` in documentation) please check the <a href="https://archimer.ifremer.fr/doc/00324/43494/" target="_blank">Product User Manual</a>.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b style="margin-right: 2em">CHALLENGE</b> Do you find in there the data types of <a href="#platform_selected">the platform</a> we were looking at in the platform section?
#
# ***
# In the end the platform (a vesselfor sure!) is equiped with:
# * A thermosalinograph
# * A CTD or Conductivity
# * Bottles
# <br>providing respectively the Thermosal data, CTD data and Bottle samples

# %% [markdown]
# Ok, this is the full list but; which ones are actually available in this product/dataset/collection?<br> `Run the next cell` to discover them:

# %%
targeted_collection_info['data_type'].unique().tolist()
# Out:
# ['CT',
#  'FB',
#  'MO',
#  'XX',
#  'TG',
#  'PF',
#  'HF',
#  'RF',
#  'TS',
#  'BO',
#  'DB',
#  'GL',
#  'ML',
#  'SM',
#  'XB']

# %% [markdown]
# And, How many of each? `Run the next cells`...

# %%
data_types = [{
    'code':code,
    'platforms': {'nplatforms': len(files.groupby('platform_code')),'files': {'nfiles': len(files), 'features(s)': [{'code':ftype, 'nfiles': len(files.groupby('data_type').get_group(code).groupby('file_type').get_group(ftype)), 'nplatforms': len(files.groupby('data_type').get_group(code).groupby('platform_code'))} for ftype in files[files['data_type']==code]['file_type'].unique().tolist()]}}
} for code,files in targeted_collection_info.groupby(['data_type'])]

# %%
IPython.display.HTML(json2html.convert(data_types))
# Out:
# <table border="1"><thead><tr><th>code</th><th>platforms</th></tr></thead><tbody><tr><td>BO</td><td><table border="1"><tr><th>nplatforms</th><td>153</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>165</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>TS</td><td>154</td><td>153</td></tr><tr><td>PR</td><td>11</td><td>153</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>CT</td><td><table border="1"><tr><th>nplatforms</th><td>1307</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>1637</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>PR</td><td>1637</td><td>1307</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>DB</td><td><table border="1"><tr><th>nplatforms</th><td>12</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>12</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>TS</td><td>12</td><td>12</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>FB</td><td><table border="1"><tr><th>nplatforms</th><td>46</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>225</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>TS</td><td>225</td><td>46</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>GL</td><td><table border="1"><tr><th>nplatforms</th><td>3</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>3</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>PR</td><td>3</td><td>3</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>HF</td><td><table border="1"><tr><th>nplatforms</th><td>7</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>7</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>RV</td><td>5</td><td>7</td></tr><tr><td>TV</td><td>2</td><td>7</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>ML</td><td><table border="1"><tr><th>nplatforms</th><td>4</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>4</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>PR</td><td>4</td><td>4</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>MO</td><td><table border="1"><tr><th>nplatforms</th><td>113</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>113</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>TS</td><td>113</td><td>113</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>PF</td><td><table border="1"><tr><th>nplatforms</th><td>40</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>40</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>PR</td><td>40</td><td>40</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>RF</td><td><table border="1"><tr><th>nplatforms</th><td>1</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>1</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>TS</td><td>1</td><td>1</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>SM</td><td><table border="1"><tr><th> ...

# %% [markdown]
# Too much info? Choose just one! `Run the next cell`:

# %%
code = 'CT'

# %%
selection = [dtype for dtype in data_types if dtype['code'] == code]
IPython.display.HTML(json2html.convert(selection))
# Out:
# <table border="1"><thead><tr><th>code</th><th>platforms</th></tr></thead><tbody><tr><td>CT</td><td><table border="1"><tr><th>nplatforms</th><td>1307</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>1637</td></tr><tr><th>features(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>PR</td><td>1637</td><td>1307</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr></tbody></table>

# %% [markdown]
# #### 3.3.3. Feature types

# %% [markdown]
# `Feature types` represents the shape of the data reported by a given platform data source. <br>So far the In Situ TAC distinguishes 4 feature types:

# %% [markdown]
# | code | description |
# | ------- | ------- |
# |TS | Time Serie |
# |PR | Profile |
# |TV | Grided data - High Frequency Radar total velocity fields |
# |RV | Grided data - High Frequency Radar radial velocity fields |
# |WS | Wave spectra |

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To find the updated catalog of possible codes for feature types (`file types` in documentation) please check the <a href="https://archimer.ifremer.fr/doc/00324/43494/" target="_blank">Product User Manual</a>.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b style="margin-right: 2em">CHALLENGE</b>Do you find in there the feature types of <a href="#platform_selected">the platform</a> we were looking at in the platform section?
#
# ***
# * Profiles (vertical measurements along the water column) of certain oceanographic variables
# * Time series (measurements over time) of certain ocenographic variables

# %% [markdown]
# Ok, this is the full list but; which ones are actually available in this product/dataset/collection?<br> `Run the next cell`to know!

# %%
targeted_collection_info['file_type'].unique().tolist()
# Out:
# ['PR', 'TS', 'RV', 'TV']

# %% [markdown]
# And, How many of each? `Run the next cells`...

# %%
file_types = [{
    'code':code,
    'platforms': {'nplatforms': len(files.groupby('platform_code')),'files': {'nfiles': len(files), 'sources(s)': [{'code':dtype, 'nfiles': len(files.groupby('file_type').get_group(code).groupby('data_type').get_group(dtype)), 'nplatforms': len(files.groupby('file_type').get_group(code).groupby('data_type').get_group(dtype).groupby('platform_code'))} for dtype in files[files['file_type']==code]['data_type'].unique().tolist()]}}
} for code,files in targeted_collection_info.groupby(['file_type'])]

# %%
IPython.display.HTML(json2html.convert(file_types))
# Out:
# <table border="1"><thead><tr><th>code</th><th>platforms</th></tr></thead><tbody><tr><td>PR</td><td><table border="1"><tr><th>nplatforms</th><td>1401</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>1741</td></tr><tr><th>sources(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>CT</td><td>1637</td><td>1307</td></tr><tr><td>XX</td><td>35</td><td>35</td></tr><tr><td>PF</td><td>40</td><td>40</td></tr><tr><td>BO</td><td>11</td><td>11</td></tr><tr><td>GL</td><td>3</td><td>3</td></tr><tr><td>ML</td><td>4</td><td>4</td></tr><tr><td>SM</td><td>3</td><td>3</td></tr><tr><td>XB</td><td>8</td><td>8</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>RV</td><td><table border="1"><tr><th>nplatforms</th><td>5</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>5</td></tr><tr><th>sources(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>HF</td><td>5</td><td>5</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>TS</td><td><table border="1"><tr><th>nplatforms</th><td>519</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>755</td></tr><tr><th>sources(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>FB</td><td>225</td><td>46</td></tr><tr><td>MO</td><td>113</td><td>113</td></tr><tr><td>TG</td><td>176</td><td>176</td></tr><tr><td>RF</td><td>1</td><td>1</td></tr><tr><td>TS</td><td>74</td><td>36</td></tr><tr><td>BO</td><td>154</td><td>142</td></tr><tr><td>DB</td><td>12</td><td>12</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>TV</td><td><table border="1"><tr><th>nplatforms</th><td>2</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>2</td></tr><tr><th>sources(s)</th><td><table border="1"><thead><tr><th>code</th><th>nfiles</th><th>nplatforms</th></tr></thead><tbody><tr><td>HF</td><td>2</td><td>2</td></tr></tbody></table></td></tr></table></td></tr></table></td></tr></tbody></table>

# %% [markdown]
# #### 3.3.4. Parameters
# `parameters` represents the oceanographic variables measured by the platform and therefore present in its files. <br>So Far the In Situ TAC distinguishes the next ones (zoom with the -|+ controls if you do not see it properly): `run the next cell`

# %%
IPython.display.IFrame('https://archimer.ifremer.fr/doc/00422/53381/72333.pdf', width='100%', height=350)
# Out:
#         <iframe
#             width="100%"
#             height="350"
#             src="https://archimer.ifremer.fr/doc/00422/53381/72333.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>TIP</b>
#
# ***
# To find the updated catalog of parameters please check <a href="https://archimer.ifremer.fr/doc/00422/53381/" target="_blank">this</a>.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b style="margin-right: 2em">CHALLENGE</b> Do you find in there the feature types of <a href="#platform_selected">the platform</a> we were looking at in the platform section?
#
# ***
# In the end the platform we are checking is a vessel reporting:
# * Profiles of Temperature, Salinity and Oxygen variables along the water column reported by the CTD
# * Time Series of Salinity (reported by both Bottle samples and Thermosalinograph), Temperature and Conductivity reported by the Thermosalinograph

# %% [markdown]
# Ok, this is the full list but; which ones are actually available in this product/dataset collection? `Run the next cell`and discover it!:

# %%
parameter_list = [param for param in list(set(sum([parameter.split(' ') for parameter in targeted_collection_info['parameters'].tolist()],[]))) if '_' not in param and param not in ['DEPH', 'PRES'] and param != '']
parameter_list
# Out:
# ['GDOP',
#  'VAVH',
#  'TEMP',
#  'MINV',
#  'VPSP',
#  'UDOX',
#  'SLTR',
#  'ETMP',
#  'EACC',
#  'WBFO',
#  'DOX2',
#  'C14D',
#  'VPED',
#  'VEMH',
#  'C13D',
#  'HCDT',
#  'BBP700',
#  'VGTA',
#  'LONGITUDE',
#  'CDOM',
#  'TP',
#  'VHM0',
#  'RDVA',
#  'FLUO',
#  'WETT',
#  'SCDT',
#  'NSCT',
#  'O18D',
#  'VZMX',
#  'HCSS',
#  'CNDC',
#  'RVFL',
#  'VGHS',
#  'LATITUDE',
#  'DOXY',
#  'NEON',
#  'DRYT',
#  'AMON',
#  'TRANSMISSIVITY',
#  'ATPT',
#  'VTZA',
#  'CHLT',
#  'ERSC',
#  'PHOS',
#  'OSAT',
#  'PHPH',
#  'WSPD',
#  'SLNR',
#  'NTRZ',
#  'SSJT',
#  'XDST',
#  'SLTT',
#  'CCOV',
#  'WDIR',
#  'NSCS',
#  'HELD',
#  'SLCA',
#  'ATMS',
#  'ESPC',
#  'QCflag',
#  'VACC',
#  'SVEL',
#  'TRIW',
#  'TUR2',
#  'CFC113',
#  'EWCT',
#  'CFC12',
#  'LGHT',
#  'CFC11',
#  'SCDR',
#  'EWCS',
#  'TN',
#  'ATMP',
#  'NTRA',
#  'MAXV',
#  'ERTC',
#  'PHYC',
#  'PCO2',
#  'DRVA',
#  'DOX1',
#  'VMDR',
#  'RELH',
#  'YDST',
#  'SLNT',
#  'TUR4',
#  'FLU2',
#  'NATX',
#  'TCO2',
#  'NARX',
#  'VTZM',
#  'TUR3',
#  'PSAL',
#  'DIRECTION',
#  'SLEV',
#  'HCSP',
#  'SPRC',
#  'CPHL',
#  'ALK3',
#  'crs',
#  'VTPK',
#  'HELM',
#  'UACC',
#  'GSPD']

# %% [markdown]
# And, How many of each? `Run the next cells`...

# %%
parameters = [{
    'code':code,
    'platforms':{
        'nplatforms': len(targeted_collection_info[targeted_collection_info['parameters'].str.contains(code)].groupby('platform_code')),
        'files':{
            'nfiles': len(targeted_collection_info[targeted_collection_info['parameters'].str.contains(code)]), 
            'feature(s)': [{'code': ftype, 'nplatforms': len(targeted_collection_info[targeted_collection_info['parameters'].str.contains(code)].groupby('file_type').get_group(ftype).groupby('platform_code')), 'nfiles':len(targeted_collection_info[targeted_collection_info['parameters'].str.contains(code)].groupby('file_type').get_group(ftype)),'sources(s)': [{'code': dtype, 'nplatforms' : len(targeted_collection_info[targeted_collection_info['parameters'].str.contains(code)].groupby('file_type').get_group(ftype).groupby('data_type').get_group(dtype).groupby('platform_code')) ,'nfiles': len(targeted_collection_info[targeted_collection_info['parameters'].str.contains(code)].groupby('file_type').get_group(ftype).groupby('data_type').get_group(dtype))} for dtype in targeted_collection_info[targeted_collection_info['parameters'].str.contains(code)][targeted_collection_info['file_type']==ftype]['data_type'].unique().tolist()]} for ftype in targeted_collection_info[targeted_collection_info['parameters'].str.contains(code)]['file_type'].unique().tolist()]
        }
    }
} for code in parameter_list]

# %%
IPython.display.HTML(json2html.convert(parameters))
# Out:
# <table border="1"><thead><tr><th>code</th><th>platforms</th></tr></thead><tbody><tr><td>GDOP</td><td><table border="1"><tr><th>nplatforms</th><td>2</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>2</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TV</td><td>2</td><td>2</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>HF</td><td>2</td><td>2</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>VAVH</td><td><table border="1"><tr><th>nplatforms</th><td>1</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>1</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>1</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>TS</td><td>1</td><td>1</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>TEMP</td><td><table border="1"><tr><th>nplatforms</th><td>1735</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>2255</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>1400</td><td>1739</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>CT</td><td>1306</td><td>1635</td></tr><tr><td>XX</td><td>35</td><td>35</td></tr><tr><td>PF</td><td>40</td><td>40</td></tr><tr><td>BO</td><td>11</td><td>11</td></tr><tr><td>GL</td><td>3</td><td>3</td></tr><tr><td>ML</td><td>4</td><td>4</td></tr><tr><td>SM</td><td>3</td><td>3</td></tr><tr><td>XB</td><td>8</td><td>8</td></tr></tbody></table></td></tr><tr><td>TS</td><td>348</td><td>516</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>FB</td><td>35</td><td>173</td></tr><tr><td>MO</td><td>90</td><td>90</td></tr><tr><td>TG</td><td>53</td><td>53</td></tr><tr><td>TS</td><td>24</td><td>54</td></tr><tr><td>DB</td><td>11</td><td>11</td></tr><tr><td>BO</td><td>135</td><td>135</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>MINV</td><td><table border="1"><tr><th>nplatforms</th><td>2</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>2</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>RV</td><td>2</td><td>2</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>HF</td><td>2</td><td>2</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>VPSP</td><td><table border="1"><tr><th>nplatforms</th><td>16</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>16</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>16</td><td>16</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>MO</td><td>16</td><td>16</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>UDOX</td><td><table border="1"><tr><th>nplatforms</th><td>1</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>1</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>1</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></ ...

# %% [markdown]
# Too much info? Choose one! `Run the next cells`...

# %%
code = 'TEMP'

# %%
selection = [param for param in parameters if param['code'] == code]
IPython.display.HTML(json2html.convert(selection))
# Out:
# <table border="1"><thead><tr><th>code</th><th>platforms</th></tr></thead><tbody><tr><td>TEMP</td><td><table border="1"><tr><th>nplatforms</th><td>1735</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>2255</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>1400</td><td>1739</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>CT</td><td>1306</td><td>1635</td></tr><tr><td>XX</td><td>35</td><td>35</td></tr><tr><td>PF</td><td>40</td><td>40</td></tr><tr><td>BO</td><td>11</td><td>11</td></tr><tr><td>GL</td><td>3</td><td>3</td></tr><tr><td>ML</td><td>4</td><td>4</td></tr><tr><td>SM</td><td>3</td><td>3</td></tr><tr><td>XB</td><td>8</td><td>8</td></tr></tbody></table></td></tr><tr><td>TS</td><td>348</td><td>516</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>FB</td><td>35</td><td>173</td></tr><tr><td>MO</td><td>90</td><td>90</td></tr><tr><td>TG</td><td>53</td><td>53</td></tr><tr><td>TS</td><td>24</td><td>54</td></tr><tr><td>DB</td><td>11</td><td>11</td></tr><tr><td>BO</td><td>135</td><td>135</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr></tbody></table>

# %% [markdown]
# #### 3.3.5. Providers

# %% [markdown]
# Any Situ NRT products/datasets collections are composed by the files reported by a network of platforms located in the area. It is interesting always to know who are procuring these platforms and to aknowledge them!

# %% [markdown]
# Let's `run the next cell` to know how many *known* providers are contributting to this product/dataset collection with files:

# %%
providers_list = list(set(sum([str(provider).split(' ') for provider in targeted_collection_info['institution_edmo_code'].tolist() if str(provider).isdigit()],[])))
providers_list
# Out:
# ['1484',
#  '1979',
#  '1366',
#  '1156',
#  '1212',
#  '680',
#  '1054',
#  '1850',
#  '196',
#  '3400',
#  '1799',
#  '1390',
#  '1351',
#  '353',
#  '1190',
#  '5231',
#  '4755',
#  '540',
#  '756',
#  '520',
#  '4614',
#  '1463',
#  '1778',
#  '100',
#  '440',
#  '3323',
#  '2710',
#  '469',
#  '1218',
#  '911',
#  '3839',
#  '3138',
#  '713',
#  '1852',
#  '892',
#  '4476',
#  '195',
#  '3037',
#  '1241',
#  '3497',
#  '1537',
#  '2842',
#  '698',
#  '545',
#  '193',
#  '1725',
#  '1104']

# %% [markdown]
# Not clear at all, right? These numbers are identifiers provided by [SeaDatanet]('https://www.seadatanet.org/'). <br>
# Just check who is who by using SeaDataNet services: `run the next cell`!

# %%
code = '1850' #change it by any other!
IPython.display.IFrame('https://edmo.seadatanet.org/report/'+code, width='100%', height=350)
# Out:
#         <iframe
#             width="100%"
#             height="350"
#             src="https://edmo.seadatanet.org/report/1850"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# How much are they contributting to the product/datasetcollection?<br>`Run the next cells` to discover it!:

# %%
targeted_collection_info['institution_edmo_code'] = ' ' +targeted_collection_info['institution_edmo_code'].str.strip()+ ' '

# %%
providers = [{
    'code':code,
    'platforms':{
        'nplatforms': len(targeted_collection_info[targeted_collection_info['institution_edmo_code'].str.contains(' '+code+' ', na=False)].groupby('platform_code').groups.keys()),
        'files':{'nfiles': len(targeted_collection_info[targeted_collection_info['institution_edmo_code'].str.contains(' '+code+' ', na=False)]), 
        'feature(s)': [{'code': ftype, 'nplatforms':len(targeted_collection_info[targeted_collection_info['institution_edmo_code'].str.contains(' '+code+' ', na=False)].groupby('file_type').get_group(ftype).groupby('platform_code')), 'nfiles':len(targeted_collection_info[targeted_collection_info['institution_edmo_code'].str.contains(' '+code+' ', na=False)].groupby('file_type').get_group(ftype)),'sources(s)': [{'code': dtype, 'nplatforms': len(targeted_collection_info[targeted_collection_info['institution_edmo_code'].str.contains(' '+code+' ', na=False)].groupby('file_type').get_group(ftype).groupby('data_type').get_group(dtype).groupby('platform_code')), 'nfiles': len(targeted_collection_info[targeted_collection_info['institution_edmo_code'].str.contains(' '+code+' ', na=False)].groupby('file_type').get_group(ftype).groupby('data_type').get_group(dtype))} for dtype in targeted_collection_info[targeted_collection_info['institution_edmo_code'].str.contains(' '+code+' ', na=False)][targeted_collection_info['file_type']==ftype]['data_type'].unique().tolist()]} for ftype in targeted_collection_info[targeted_collection_info['institution_edmo_code'].str.contains(' '+code+' ', na=False)]['file_type'].unique().tolist()]}
    }
} for code in providers_list]

# %%
IPython.display.HTML(json2html.convert(providers))
# Out:
# <table border="1"><thead><tr><th>code</th><th>platforms</th></tr></thead><tbody><tr><td>1484</td><td><table border="1"><tr><th>nplatforms</th><td>1</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>2</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>1</td><td>2</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>CT</td><td>1</td><td>2</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>1979</td><td><table border="1"><tr><th>nplatforms</th><td>1</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>1</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>1</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>CT</td><td>1</td><td>1</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>1366</td><td><table border="1"><tr><th>nplatforms</th><td>1</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>1</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>1</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>TS</td><td>1</td><td>1</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>1156</td><td><table border="1"><tr><th>nplatforms</th><td>1</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>1</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>1</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>PF</td><td>1</td><td>1</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>1212</td><td><table border="1"><tr><th>nplatforms</th><td>4</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>4</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>RV</td><td>2</td><td>2</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>HF</td><td>2</td><td>2</td></tr></tbody></table></td></tr><tr><td>TV</td><td>1</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>HF</td><td>1</td><td>1</td></tr></tbody></table></td></tr><tr><td>TS</td><td>1</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>TG</td><td>1</td><td>1</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr><tr><td>680</td><td><table border="1"><tr><th>nplatforms</th><td>20</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>20</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>PR</td><td>19</td><td>19</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>CT</td><td>19</td><td>19</td></tr></tbody></table></td></tr><tr><td>TS</td><td>1</td><td>1</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>TG</td><td>1</td><td>1</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td ...

# %% [markdown]
# Too much info? Choose one! `Run the next cells`...

# %%
code = '1850'

# %%
selection = [provider for provider in providers if provider['code'] == code]
IPython.display.HTML(json2html.convert(selection))
# Out:
# <table border="1"><thead><tr><th>code</th><th>platforms</th></tr></thead><tbody><tr><td>1850</td><td><table border="1"><tr><th>nplatforms</th><td>47</td></tr><tr><th>files</th><td><table border="1"><tr><th>nfiles</th><td>51</td></tr><tr><th>feature(s)</th><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th><th>sources(s)</th></tr></thead><tbody><tr><td>TS</td><td>44</td><td>44</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>MO</td><td>17</td><td>17</td></tr><tr><td>TG</td><td>26</td><td>26</td></tr><tr><td>RF</td><td>1</td><td>1</td></tr></tbody></table></td></tr><tr><td>PR</td><td>7</td><td>7</td><td><table border="1"><thead><tr><th>code</th><th>nplatforms</th><th>nfiles</th></tr></thead><tbody><tr><td>XX</td><td>5</td><td>5</td></tr><tr><td>PF</td><td>1</td><td>1</td></tr><tr><td>CT</td><td>1</td><td>1</td></tr></tbody></table></td></tr></tbody></table></td></tr></table></td></tr></table></td></tr></tbody></table>

# %% [markdown]
# ---
#
# # 4. Wrap-up
#
# So far you should already know what to expect about this product/dataset/collection: platform network, file types, source types, parameters and providers.<br> `If you don't please ask us! it is the moment!`
# <br>In the next tutorial we will see how to retrieve the files comming from a certain platform, source, provider, matching a certain type of file or/and containing certain parameter. Ready? Let's go!

# %% [markdown]
# ---
#
# # 5. Next tutorial
#
# _Click on the hyperlink below to continue the training_
#
# [**13-02-NearRealTtime-product-subsetting-download.ipynb**](13-02-NearRealTtime-product-subsetting-download.ipynb)
